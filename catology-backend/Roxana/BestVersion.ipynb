# %% [markdown]
# ### 1. Data preprocessing

# %%
import pandas as pd
import sys
import os

def create_dataframe(path):
    df = pd.read_excel(path)
    return df

def delete_duplicates(df):
    # Stergerea duplicatelor
    df.drop_duplicates(inplace = True) # inplace = True indica faptul ca fuctia va sterge duplicate din dataframe-ul dat si nu va return unul nou
    return df

def remove_unknown_gender_instances(df):
    # Eliminăm rândurile unde 'Gender' are valoarea 'Unknown'
    return df[df['Gender'] != 'Unknown']

def remove_unknown_race_instances(df):
    # Eliminăm rândurile unde 'Race' are valoarea 'Unknown'
    return df[df['Race'] != 'Unknown']

def replace_unknown_with_median(x):
    # Înlocuiește "Unknown" cu mediană, după ce valorile sunt convertite în numeric
    median_value = pd.to_numeric(x[x != "Unknown"]).median()
    return x.replace("Unknown", median_value)

# Funcția pentru aplicarea pe grupuri
def edit_unknown_values_for_natural_area(df):
    df["The abundance of natural areas"] = df.groupby("Race")["The abundance of natural areas"].transform(
        lambda x: replace_unknown_with_median(x)
    )

    # Convertim în int
    df["The abundance of natural areas"] = df["The abundance of natural areas"].astype(int)
    return df

def encode_age(df):
    # Create a copy of the DataFrame
    df_transformed = df.copy()
    
    # Age mapping
    age_mapping = {
        'Less than 1 year': 0.5,
        '1-2 years': 1.5,
        '2-10 years': 6,
        'More than 10 years': 12
    }
    
    # Apply age mapping
    df_transformed['Age'] = df_transformed['Age'].map(age_mapping)
    
    return df_transformed

def encode_categorical_columns(df, categorical_columns):
    # Create one-hot encoded columns
    for column in categorical_columns:
        one_hot = pd.get_dummies(df[column], prefix=column)
        
        # Add one-hot encoded columns to the transformed DataFrame
        df = pd.concat([df, one_hot], axis=1)
        
        # Drop the original categorical column
        df = df.drop(column, axis=1)
    
    return df


def preprocessing():
    # Crearea dataframe-ului
    df = create_dataframe('./Dataset/Dataset.xlsx')

    #stergerea duplicatelor
    df = delete_duplicates(df)

    # Stergerea instantelor unde Gender = Unknown (6 instante)
    df = remove_unknown_gender_instances(df)

    # Stergerea instantelor unde Race = Unknown (79 instante)
    df = remove_unknown_race_instances(df)

    # modificam instantele ce au valori 'Unknown' pentru coloana 'The abundance of natural areas' in mediana pentru fiecare rasa (240 de instante)
    df = edit_unknown_values_for_natural_area(df)

    # encodam coloana 'Age'
    df = encode_age(df)

    return df

df = preprocessing()
df.info()
# Print current path
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3055 entries, 0 to 3142
# Data columns (total 26 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Gender                              3055 non-null   object
#  1   Age                                 3055 non-null   float64
#  2   Race                                3055 non-null   object
#  3   Number of cats in the household     3055 non-null   int64
#  4   Type of housing                     3055 non-null   object
#  5   Zone                                3055 non-null   object
#  6   Time spent outside each day         3055 non-null   int64
#  7   Time spent with the owner each day  3055 non-null   int64
#  8   Shy                                 3055 non-null   int64
#  9   Calm                                3055 non-null   int64
#  10  Skittish                            3055 non-null   int64
#  11  Intelligent                         3055 non-null   int64
#  12  Vigilant                            3055 non-null   int64
#  13  Tenacious                           3055 non-null   int64
#  14  Affectionate                        3055 non-null   int64
#  15  Friendly                            3055 non-null   int64
#  16  Loner                               3055 non-null   int64
#  17  Ferocious                           3055 non-null   int64
#  18  Territorial                         3055 non-null   int64
#  19  Aggressive                          3055 non-null   int64
#  20  Impulsive                           3055 non-null   int64
#  21  Predictable                         3055 non-null   int64
#  22  Inattentive                         3055 non-null   int64
#  23  The abundance of natural areas      3055 non-null   int32
#  24  Frequency of Bird Captures          3055 non-null   int64
#  25  Frequency of Small Mammal Captures  3055 non-null   int64
# dtypes: float64(1), int32(1), int64(20), object(4)
# memory usage: 632.5+ KB

# %% [markdown]
# ### 2. Data splitting

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

def create_single_race_column(df):
    """
    Convert one-hot encoded race columns into a single categorical column.
    Returns the race column and the original dataframe.
    """
    # Get all race column names
    race_columns = [col for col in df.columns if col.startswith('Race_')]
    
    # Create a single race column
    race_series = pd.Series('Unknown', index=df.index)
    for col in race_columns:
        # For each True value, set the race name (removing 'Race_' prefix)
        race_series[df[col]] = col.replace('Race_', '')
    
    return race_series

def split_cat_dataset(df, test_size=0.1, random_state=42):
    """
    Perform stratified split on the cat dataset based on races.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        Input dataframe containing cat data
    test_size : float
        Proportion of the dataset to include in the test split
    random_state : int
        Random state for reproducibility
    
    Returns:
    --------
    train_df, test_df : tuple of pandas.DataFrame
        The split datasets
    """
    # Create single race column for stratification
    race_column = create_single_race_column(df)
    
    # Perform stratified split
    train_idx, test_idx = train_test_split(
        np.arange(len(df)),
        test_size=test_size,
        random_state=random_state,
        stratify=race_column
    )
    
    # Split the dataframe
    train_df = df.iloc[train_idx].copy()
    test_df = df.iloc[test_idx].copy()
    
    # Print split information
    print(f"Training set size: {len(train_df)} ({(1-test_size)*100:.1f}%)")
    print(f"Test set size: {len(test_df)} ({test_size*100:.1f}%)")
    
    # Verify stratification
    print("\nRace distribution in original dataset:")
    original_dist = race_column.value_counts(normalize=True)
    print(original_dist)
    
    print("\nRace distribution in training set:")
    train_dist = create_single_race_column(train_df).value_counts(normalize=True)
    print(train_dist)
    
    print("\nRace distribution in test set:")
    test_dist = create_single_race_column(test_df).value_counts(normalize=True)
    print(test_dist)
    
    return train_df, test_df

# One-hot encode categorical variables
categorical_columns = ['Type of housing', 'Zone', 'Race', 'Gender']
df = encode_categorical_columns(df, categorical_columns)

# Split the dataset
train_df, test_df = split_cat_dataset(df, test_size=0.1, random_state=42)
# Out:
# Training set size: 2749 (90.0%)
# Test set size: 306 (10.0%)
#
# Race distribution in original dataset:
# European             0.333224
# No breed             0.157774
# Bengal               0.077905
# Ragdoll              0.070704
# Maine coon           0.064484
# Birman               0.062848
# Persian              0.062848
# British Shorthair    0.054337
# Other                0.044190
# Sphynx               0.024877
# Siamese              0.018985
# Chartreux            0.010147
# Turkish angora       0.009165
# Savannah             0.008511
# Name: proportion, dtype: float64
#
# Race distribution in training set:
# European             0.333212
# No breed             0.157876
# Bengal               0.077846
# Ragdoll              0.070571
# Maine coon           0.064387
# Birman               0.062932
# Persian              0.062932
# British Shorthair    0.054202
# Other                0.044380
# Sphynx               0.024736
# Siamese              0.018916
# Chartreux            0.010186
# Turkish angora       0.009094
# Savannah             0.008730
# Name: proportion, dtype: float64
#
# Race distribution in test set:
# European             0.333333
# No breed             0.156863
# Bengal               0.078431
# Ragdoll              0.071895
# Maine coon           0.065359
# Persian              0.062092
# Birman               0.062092
# British Shorthair    0.055556
# Other                0.042484
# Sphynx               0.026144
# Siamese              0.019608
# Chartreux            0.009804
# Turkish angora       0.009804
# Savannah             0.006536
# Name: proportion, dtype: float64

# %% [markdown]
# ### 3. Training the model

# %% [markdown]
# > Antrenarea pe setul de date cu modificări minime.

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold
import matplotlib.pyplot as plt

class Dropout:
    def __init__(self, dropout_rate):
        self.dropout_rate = dropout_rate
        self.mask = None
        
    def forward(self, input_data, training=True):
        if training:
            self.mask = np.random.binomial(1, 1 - self.dropout_rate, input_data.shape) / (1 - self.dropout_rate)
            return input_data * self.mask
        return input_data
    
    def backward(self, grad_output):
        return grad_output * self.mask

class Layer:
    def __init__(self, input_size, output_size, activation='relu', l2_lambda=0.005, dropout_rate=0.2):
        self.weights = np.random.randn(input_size, output_size) * np.sqrt(2.0/input_size)
        self.bias = np.zeros((1, output_size))
        self.activation = activation
        self.l2_lambda = l2_lambda
        self.dropout = Dropout(dropout_rate)
        self.input = None
        self.output = None
        self.z = None
    
    def get_weights(self):
        return {
            'weights': self.weights.copy(),
            'bias': self.bias.copy()
        }
    
    def set_weights(self, weights):
        self.weights = weights['weights'].copy()
        self.bias = weights['bias'].copy()
        
    def forward(self, input_data, training=True):
        self.input = input_data
        self.z = np.dot(input_data, self.weights) + self.bias
        
        if self.activation == 'relu':
            self.output = np.maximum(0, self.z)
        elif self.activation == 'softmax':
            exp_values = np.exp(self.z - np.max(self.z, axis=1, keepdims=True))
            self.output = exp_values / np.sum(exp_values, axis=1, keepdims=True)
        
        if self.activation != 'softmax':
            self.output = self.dropout.forward(self.output, training)
            
        return self.output
    
    def backward(self, grad_output, learning_rate):
        if self.activation != 'softmax':
            grad_output = self.dropout.backward(grad_output)
        
        if self.activation == 'relu':
            grad_z = grad_output * (self.z > 0)
        elif self.activation == 'softmax':
            grad_z = grad_output
            
        grad_weights = np.dot(self.input.T, grad_z) + self.l2_lambda * self.weights
        grad_bias = np.sum(grad_z, axis=0, keepdims=True)
        grad_input = np.dot(grad_z, self.weights.T)
        
        self.weights -= learning_rate * grad_weights
        self.bias -= learning_rate * grad_bias
        
        return grad_input

class NeuralNetwork:
    def __init__(self, input_dim, output_dim, l2_lambda=0.005):
        self.layers = [
            Layer(input_dim, 128, 'relu', l2_lambda, dropout_rate=0.1),
            Layer(128, 64, 'relu', l2_lambda, dropout_rate=0.1),
            Layer(64, output_dim, 'softmax', l2_lambda, dropout_rate=0.0)
        ]
    
    def get_weights(self):
        return [layer.get_weights() for layer in self.layers]
    
    def set_weights(self, weights):
        for layer, w in zip(self.layers, weights):
            layer.set_weights(w)
    
    def forward(self, X, training=True):
        current_output = X
        for layer in self.layers:
            current_output = layer.forward(current_output, training)
        return current_output
    
    def backward(self, X, y, learning_rate):
        grad_output = self.layers[-1].output - y
        for layer in reversed(self.layers):
            grad_output = layer.backward(grad_output, learning_rate)
    
    def train_step(self, X_batch, y_batch, learning_rate):
        predictions = self.forward(X_batch, training=True)
        self.backward(X_batch, y_batch, learning_rate)
        loss = self.compute_loss(predictions, y_batch)
        return loss, predictions
    
    def predict(self, X):
        return self.forward(X, training=False)
    
    def compute_loss(self, predictions, y_true):
        epsilon = 1e-15
        predictions = np.clip(predictions, epsilon, 1 - epsilon)
        return -np.mean(np.sum(y_true * np.log(predictions), axis=1))
    
    def compute_accuracy(self, predictions, y_true):
        return np.mean(np.argmax(predictions, axis=1) == np.argmax(y_true, axis=1))

def plot_training_history(histories, n_splits):
    plt.figure(figsize=(15, 10))
    
    # Plot training loss
    plt.subplot(2, 1, 1)
    for fold in range(n_splits):
        plt.plot(histories[fold]['train_loss'], label=f'Fold {fold+1}')
    plt.title('Training Loss per Fold')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    # Plot validation accuracy
    plt.subplot(2, 1, 2)
    for fold in range(n_splits):
        plt.plot(histories[fold]['val_acc'], label=f'Fold {fold+1}')
    plt.title('Validation Accuracy per Fold')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()
    
def train_and_evaluate_model(X, y, n_splits=6, epochs=1000, batch_size=32, learning_rate=0.0001, patience=100):
    y_encoded = y.values
    scaler = StandardScaler()
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    
    fold_results = []
    histories = []
    
    n_classes = y_encoded.shape[1]
    
    for fold, (train_idx, val_idx) in enumerate(skf.split(X, np.argmax(y_encoded, axis=1)), 1):
        print(f"\nFold {fold}/{n_splits}")
        
        X_train, X_val = X.iloc[train_idx].values, X.iloc[val_idx].values
        y_train, y_val = y_encoded[train_idx], y_encoded[val_idx]
        
        X_train_scaled = scaler.fit_transform(X_train)
        X_val_scaled = scaler.transform(X_val)
        
        model = NeuralNetwork(X_train.shape[1], n_classes, 0.001)
        
        history = {
            'train_loss': [],
            'train_acc': [],
            'val_loss': [],
            'val_acc': []
        }
        
        best_val_accuracy = 0
        best_weights = None
        best_epoch = 0
        patience_counter = 0
        
        for epoch in range(epochs):
            indices = np.random.permutation(len(X_train_scaled))
            X_train_shuffled = X_train_scaled[indices]
            y_train_shuffled = y_train[indices]
            
            epoch_train_loss = 0
            epoch_train_acc = 0
            n_batches = 0
            
            for i in range(0, len(X_train_scaled), batch_size):
                X_batch = X_train_shuffled[i:i+batch_size]
                y_batch = y_train_shuffled[i:i+batch_size]
                
                loss, predictions = model.train_step(X_batch, y_batch, learning_rate)
                accuracy = model.compute_accuracy(predictions, y_batch)
                
                epoch_train_loss += loss
                epoch_train_acc += accuracy
                n_batches += 1
            
            avg_train_loss = epoch_train_loss / n_batches
            avg_train_acc = epoch_train_acc / n_batches
            
            val_predictions = model.predict(X_val_scaled)
            val_loss = model.compute_loss(val_predictions, y_val)
            val_accuracy = model.compute_accuracy(val_predictions, y_val)
            
            history['train_loss'].append(avg_train_loss)
            history['train_acc'].append(avg_train_acc)
            history['val_loss'].append(val_loss)
            history['val_acc'].append(val_accuracy)
            
            # Early stopping logic
            if val_accuracy > best_val_accuracy:
                best_val_accuracy = val_accuracy
                best_weights = model.get_weights()
                best_epoch = epoch
                patience_counter = 0
            else:
                patience_counter += 1
                
            if patience_counter >= patience:
                print(f"\nEarly stopping triggered at epoch {epoch + 1}")
                print(f"No improvement in validation accuracy for {patience} epochs")
                break
            
            if (epoch + 1) % 5 == 0:
                print(f"Epoch {epoch + 1}/{epochs}")
                print(f"Train Loss: {avg_train_loss:.4f}, Train Acc: {avg_train_acc:.4f}")
                print(f"Val Loss: {val_loss:.4f}, Val Acc: {val_accuracy:.4f}")
        
        # Restore best weights for this fold
        model.set_weights(best_weights)
        histories.append(history)
        
        fold_results.append({
            'fold': fold,
            'best_val_accuracy': best_val_accuracy,
            'best_epoch': best_epoch,
            'model': model
        })
        
        print(f"\nFold {fold} Best Results:")
        print(f"Best Epoch: {best_epoch}")
        print(f"Best Validation Accuracy: {best_val_accuracy:.4f}")
    
    # Find the best overall model
    best_fold = max(fold_results, key=lambda x: x['best_val_accuracy'])
    
    print("\nOverall Cross-validation results:")
    print(f"Mean validation accuracy: {np.mean([r['best_val_accuracy'] for r in fold_results]):.4f}")
    print(f"Standard deviation: {np.std([r['best_val_accuracy'] for r in fold_results]):.4f}")
    print(f"\nBest model from fold {best_fold['fold']} at epoch {best_fold['best_epoch']}")
    print(f"Best validation accuracy: {best_fold['best_val_accuracy']:.4f}")
    
    # Plot training history
    plot_training_history(histories, n_splits)
    
    return best_fold['model'], fold_results, histories



def prepare_data(data):
    race_columns = [col for col in data.columns if col.startswith('Race_')]
    X = data.drop(columns=race_columns)
    y = data[race_columns]
    return X, y

def main(data):
    X, y = prepare_data(data)
    best_model, fold_results, histories = train_and_evaluate_model(X, y)
    return best_model, fold_results, histories

best_model, accuracies, histories = main(train_df)
# Out:
# Fold 1/6
# Epoch 5/1000
# Train Loss: 2.3409, Train Acc: 0.2860
# Val Loss: 2.3097, Val Acc: 0.2941
# Epoch 10/1000
# Train Loss: 2.2030, Train Acc: 0.3111
# Val Loss: 2.2118, Val Acc: 0.3028
# Epoch 15/1000
# Train Loss: 2.1427, Train Acc: 0.3139
# Val Loss: 2.1686, Val Acc: 0.2985
# Epoch 20/1000
# Train Loss: 2.0865, Train Acc: 0.3195
# Val Loss: 2.1410, Val Acc: 0.3094
# Epoch 25/1000
# Train Loss: 2.0622, Train Acc: 0.3318
# Val Loss: 2.1266, Val Acc: 0.3137
# Epoch 30/1000
# Train Loss: 2.0286, Train Acc: 0.3517
# Val Loss: 2.1162, Val Acc: 0.3072
# Epoch 35/1000
# Train Loss: 2.0156, Train Acc: 0.3456
# Val Loss: 2.1084, Val Acc: 0.3181
# Epoch 40/1000
# Train Loss: 1.9889, Train Acc: 0.3525
# Val Loss: 2.1028, Val Acc: 0.3224
# Epoch 45/1000
# Train Loss: 1.9688, Train Acc: 0.3610
# Val Loss: 2.0994, Val Acc: 0.3224
# Epoch 50/1000
# Train Loss: 1.9504, Train Acc: 0.3628
# Val Loss: 2.0960, Val Acc: 0.3181
# Epoch 55/1000
# Train Loss: 1.9427, Train Acc: 0.3616
# Val Loss: 2.0936, Val Acc: 0.3159
# Epoch 60/1000
# Train Loss: 1.9275, Train Acc: 0.3626
# Val Loss: 2.0918, Val Acc: 0.3181
# Epoch 65/1000
# Train Loss: 1.9193, Train Acc: 0.3707
# Val Loss: 2.0919, Val Acc: 0.3224
# Epoch 70/1000
# Train Loss: 1.9076, Train Acc: 0.3610
# Val Loss: 2.0942, Val Acc: 0.3203
# Epoch 75/1000
# Train Loss: 1.8850, Train Acc: 0.3786
# Val Loss: 2.0940, Val Acc: 0.3224
# Epoch 80/1000
# Train Loss: 1.8922, Train Acc: 0.3834
# Val Loss: 2.0945, Val Acc: 0.3224
# Epoch 85/1000
# Train Loss: 1.8782, Train Acc: 0.3686
# Val Loss: 2.0960, Val Acc: 0.3290
# Epoch 90/1000
# Train Loss: 1.8617, Train Acc: 0.3789
# Val Loss: 2.0967, Val Acc: 0.3268
# Epoch 95/1000
# Train Loss: 1.8605, Train Acc: 0.3723
# Val Loss: 2.0983, Val Acc: 0.3312
# Epoch 100/1000
# Train Loss: 1.8536, Train Acc: 0.3790
# Val Loss: 2.0998, Val Acc: 0.3312
# Epoch 105/1000
# Train Loss: 1.8400, Train Acc: 0.3861
# Val Loss: 2.1004, Val Acc: 0.3312
# Epoch 110/1000
# Train Loss: 1.8352, Train Acc: 0.3827
# Val Loss: 2.1034, Val Acc: 0.3290
# Epoch 115/1000
# Train Loss: 1.8392, Train Acc: 0.3852
# Val Loss: 2.1037, Val Acc: 0.3312
# Epoch 120/1000
# Train Loss: 1.8155, Train Acc: 0.3861
# Val Loss: 2.1052, Val Acc: 0.3268
# Epoch 125/1000
# Train Loss: 1.8145, Train Acc: 0.3912
# Val Loss: 2.1070, Val Acc: 0.3268
# Epoch 130/1000
# Train Loss: 1.7819, Train Acc: 0.4018
# Val Loss: 2.1080, Val Acc: 0.3290
# Epoch 135/1000
# Train Loss: 1.7974, Train Acc: 0.3936
# Val Loss: 2.1093, Val Acc: 0.3246
# Epoch 140/1000
# Train Loss: 1.7947, Train Acc: 0.4001
# Val Loss: 2.1098, Val Acc: 0.3203
# Epoch 145/1000
# Train Loss: 1.7968, Train Acc: 0.4028
# Val Loss: 2.1122, Val Acc: 0.3181
# Epoch 150/1000
# Train Loss: 1.7848, Train Acc: 0.4083
# Val Loss: 2.1136, Val Acc: 0.3159
# Epoch 155/1000
# Train Loss: 1.7757, Train Acc: 0.4011
# Val Loss: 2.1157, Val Acc: 0.3159
# Epoch 160/1000
# Train Loss: 1.7735, Train Acc: 0.4048
# Val Loss: 2.1183, Val Acc: 0.3181
# Epoch 165/1000
# Train Loss: 1.7587, Train Acc: 0.3995
# Val Loss: 2.1193, Val Acc: 0.3137
# Epoch 170/1000
# Train Loss: 1.7477, Train Acc: 0.4062
# Val Loss: 2.1222, Val Acc: 0.3137
# Epoch 175/1000
# Train Loss: 1.7544, Train Acc: 0.4020
# Val Loss: 2.1240, Val Acc: 0.3137
# Epoch 180/1000
# Train Loss: 1.7436, Train Acc: 0.4090
# Val Loss: 2.1275, Val Acc: 0.3137
# Epoch 185/1000
# Train Loss: 1.7426, Train Acc: 0.4053
# Val Loss: 2.1306, Val Acc: 0.3159
# Epoch 190/1000
# Train Loss: 1.7327, Train Acc: 0.4006
# Val Loss: 2.1341, Val Acc: 0.3137
# Epoch 195/1000
# Train Loss: 1.7269, Train Acc: 0.4063
# Val Loss: 2.1356, Val Acc: 0.3181
# Epoch 200/1000
# Train Loss: 1.7183, Train Acc: 0.4220
# Val Loss: 2.1392, Val Acc: 0.3115
#
# Early stopping triggered at epoch 204
# No improvement in validation accuracy for 100 epochs
#
# Fold 1 Best Results:
# Best Epoch: 103
# Best Validation Accuracy: 0.3355
#
# Fold 2/6
# Epoch 5/1000
# Train Loss: 2.3666, Train Acc: 0.2815
# Val Loss: 2.3117, Val Acc: 0.3144
# Epoch 10/1000
# Train Loss: 2.2163, Train Acc: 0.2992
# Val Loss: 2.2361, Val Acc: 0.3210
# Epoch 15/1000
# Train Loss: 2.1531, Train Acc: 0.3182
# Val Loss: 2.2028, Val Acc: 0.3231
# Epoch 20/1000
# Train Loss: 2.1301, Train Acc: 0.3208
# Val Loss: 2.1821, Val Acc: 0.3319
# Epoch 25/1000
# Train Loss: 2.0876, Train Acc: 0.3270
# Val Loss: 2.1694, Val Acc: 0.3406
# Epoch 30/1000
# Train Loss: 2.0574, Train Acc: 0.3328
# Val Loss: 2.1575, Val Acc: 0.3406
# Epoch 35/1000
# Train Loss: 2.0367, Train Acc: 0.3374
# Val Loss: 2.1467, Val Acc: 0.3428
# Epoch 40/1000
# Train Loss: 2.0135, Train Acc: 0.3463
# Val Loss: 2.1399, Val Acc: 0.3493
# Epoch 45/1000
# Train Loss: 1.9996, Train Acc: 0.3440
# Val Loss: 2.1333, Val Acc: 0.3450
# Epoch 50/1000
# Train Loss: 1.9780, Train Acc: 0.3557
# Val Loss: 2.1277, Val Acc: 0.3472
# Epoch 55/1000
# Train Loss: 1.9660, Train Acc: 0.3542
# Val Loss: 2.1231, Val Acc: 0.3493
# Epoch 60/1000
# Train Loss: 1.9537, Train Acc: 0.3596
# Val Loss: 2.1187, Val Acc: 0.3515
# Epoch 65/1000
# Train Loss: 1.9388, Train Acc: 0.3738
# Val Loss: 2.1145, Val Acc: 0.3515
# Epoch 70/1000
# Train Loss: 1.9398, Train Acc: 0.3607
# Val Loss: 2.1112, Val Acc: 0.3559
# Epoch 75/1000
# Train Loss: 1.9366, Train Acc: 0.3654
# Val Loss: 2.1085, Val Acc: 0.3581
# Epoch 80/1000
# Train Loss: 1.9106, Train Acc: 0.3665
# Val Loss: 2.1068, Val Acc: 0.3581
# Epoch 85/1000
# Train Loss: 1.8976, Train Acc: 0.3792
# Val Loss: 2.1049, Val Acc: 0.3581
# Epoch 90/1000
# Train Loss: 1.8952, Train Acc: 0.3779
# Val Loss: 2.1031, Val Acc: 0.3581
# Epoch 95/1000
# Train Loss: 1.8865, Train Acc: 0.3620
# Val Loss: 2.1025, Val Acc: 0.3603
# Epoch 100/1000
# Train Loss: 1.8762, Train Acc: 0.3803
# Val Loss: 2.1029, Val Acc: 0.3603
# Epoch 105/1000
# Train Loss: 1.8809, Train Acc: 0.3678
# Val Loss: 2.1018, Val Acc: 0.3603
# Epoch 110/1000
# Train Loss: 1.8655, Train Acc: 0.3746
# Val Loss: 2.0997, Val Acc: 0.3603
# Epoch 115/1000
# Train Loss: 1.8534, Train Acc: 0.3823
# Val Loss: 2.0994, Val Acc: 0.3581
# Epoch 120/1000
# Train Loss: 1.8427, Train Acc: 0.3820
# Val Loss: 2.0982, Val Acc: 0.3603
# Epoch 125/1000
# Train Loss: 1.8318, Train Acc: 0.3865
# Val Loss: 2.0988, Val Acc: 0.3581
# Epoch 130/1000
# Train Loss: 1.8267, Train Acc: 0.3953
# Val Loss: 2.0988, Val Acc: 0.3603
# Epoch 135/1000
# Train Loss: 1.8262, Train Acc: 0.3941
# Val Loss: 2.0982, Val Acc: 0.3559
# Epoch 140/1000
# Train Loss: 1.8276, Train Acc: 0.3882
# Val Loss: 2.0969, Val Acc: 0.3559
# Epoch 145/1000
# Train Loss: 1.8201, Train Acc: 0.3960
# Val Loss: 2.0969, Val Acc: 0.3581
# Epoch 150/1000
# Train Loss: 1.8036, Train Acc: 0.3980
# Val Loss: 2.0992, Val Acc: 0.3537
# Epoch 155/1000
# Train Loss: 1.8041, Train Acc: 0.3908
# Val Loss: 2.1005, Val Acc: 0.3515
# Epoch 160/1000
# Train Loss: 1.7868, Train Acc: 0.3969
# Val Loss: 2.1023, Val Acc: 0.3581
# Epoch 165/1000
# Train Loss: 1.7830, Train Acc: 0.4081
# Val Loss: 2.1035, Val Acc: 0.3559
# Epoch 170/1000
# Train Loss: 1.7785, Train Acc: 0.4050
# Val Loss: 2.1039, Val Acc: 0.3515
# Epoch 175/1000
# Train Loss: 1.7732, Train Acc: 0.3989
# Val Loss: 2.1043, Val Acc: 0.3515
# Epoch 180/1000
# Train Loss: 1.7707, Train Acc: 0.4020
# Val Loss: 2.1056, Val Acc: 0.3428
#
# Early stopping triggered at epoch 184
# No improvement in validation accuracy for 100 epochs
#
# Fold 2 Best Results:
# Best Epoch: 83
# Best Validation Accuracy: 0.3624
#
# Fold 3/6
# Epoch 5/1000
# Train Loss: 2.3241, Train Acc: 0.2783
# Val Loss: 2.2023, Val Acc: 0.3297
# Epoch 10/1000
# Train Loss: 2.2089, Train Acc: 0.2959
# Val Loss: 2.1325, Val Acc: 0.3406
# Epoch 15/1000
# Train Loss: 2.1367, Train Acc: 0.3202
# Val Loss: 2.1030, Val Acc: 0.3362
# Epoch 20/1000
# Train Loss: 2.0849, Train Acc: 0.3324
# Val Loss: 2.0875, Val Acc: 0.3362
# Epoch 25/1000
# Train Loss: 2.0511, Train Acc: 0.3344
# Val Loss: 2.0756, Val Acc: 0.3362
# Epoch 30/1000
# Train Loss: 2.0360, Train Acc: 0.3384
# Val Loss: 2.0681, Val Acc: 0.3406
# Epoch 35/1000
# Train Loss: 2.0170, Train Acc: 0.3351
# Val Loss: 2.0621, Val Acc: 0.3450
# Epoch 40/1000
# Train Loss: 1.9956, Train Acc: 0.3519
# Val Loss: 2.0565, Val Acc: 0.3406
# Epoch 45/1000
# Train Loss: 1.9769, Train Acc: 0.3520
# Val Loss: 2.0528, Val Acc: 0.3384
# Epoch 50/1000
# Train Loss: 1.9715, Train Acc: 0.3551
# Val Loss: 2.0506, Val Acc: 0.3362
# Epoch 55/1000
# Train Loss: 1.9590, Train Acc: 0.3540
# Val Loss: 2.0497, Val Acc: 0.3341
# Epoch 60/1000
# Train Loss: 1.9230, Train Acc: 0.3696
# Val Loss: 2.0476, Val Acc: 0.3428
# Epoch 65/1000
# Train Loss: 1.9313, Train Acc: 0.3607
# Val Loss: 2.0464, Val Acc: 0.3428
# Epoch 70/1000
# Train Loss: 1.9218, Train Acc: 0.3632
# Val Loss: 2.0453, Val Acc: 0.3406
# Epoch 75/1000
# Train Loss: 1.9137, Train Acc: 0.3596
# Val Loss: 2.0450, Val Acc: 0.3450
# Epoch 80/1000
# Train Loss: 1.8933, Train Acc: 0.3559
# Val Loss: 2.0452, Val Acc: 0.3428
# Epoch 85/1000
# Train Loss: 1.8967, Train Acc: 0.3716
# Val Loss: 2.0450, Val Acc: 0.3450
# Epoch 90/1000
# Train Loss: 1.8786, Train Acc: 0.3679
# Val Loss: 2.0458, Val Acc: 0.3384
# Epoch 95/1000
# Train Loss: 1.8766, Train Acc: 0.3706
# Val Loss: 2.0477, Val Acc: 0.3384
# Epoch 100/1000
# Train Loss: 1.8543, Train Acc: 0.3810
# Val Loss: 2.0483, Val Acc: 0.3384
# Epoch 105/1000
# Train Loss: 1.8609, Train Acc: 0.3753
# Val Loss: 2.0490, Val Acc: 0.3341
# Epoch 110/1000
# Train Loss: 1.8486, Train Acc: 0.3827
# Val Loss: 2.0509, Val Acc: 0.3362
# Epoch 115/1000
# Train Loss: 1.8404, Train Acc: 0.3882
# Val Loss: 2.0515, Val Acc: 0.3384
# Epoch 120/1000
# Train Loss: 1.8259, Train Acc: 0.3930
# Val Loss: 2.0525, Val Acc: 0.3406
# Epoch 125/1000
# Train Loss: 1.8278, Train Acc: 0.3829
# Val Loss: 2.0529, Val Acc: 0.3406
# Epoch 130/1000
# Train Loss: 1.8118, Train Acc: 0.3923
# Val Loss: 2.0541, Val Acc: 0.3341
# Epoch 135/1000
# Train Loss: 1.8090, Train Acc: 0.3963
# Val Loss: 2.0550, Val Acc: 0.3384
# Epoch 140/1000
# Train Loss: 1.7957, Train Acc: 0.3911
# Val Loss: 2.0590, Val Acc: 0.3319
# Epoch 145/1000
# Train Loss: 1.7911, Train Acc: 0.3983
# Val Loss: 2.0609, Val Acc: 0.3341
# Epoch 150/1000
# Train Loss: 1.8088, Train Acc: 0.3885
# Val Loss: 2.0611, Val Acc: 0.3297
# Epoch 155/1000
# Train Loss: 1.7736, Train Acc: 0.3972
# Val Loss: 2.0644, Val Acc: 0.3253
# Epoch 160/1000
# Train Loss: 1.7686, Train Acc: 0.3957
# Val Loss: 2.0662, Val Acc: 0.3210
# Epoch 165/1000
# Train Loss: 1.7577, Train Acc: 0.4101
# Val Loss: 2.0684, Val Acc: 0.3188
# Epoch 170/1000
# Train Loss: 1.7522, Train Acc: 0.4099
# Val Loss: 2.0709, Val Acc: 0.3297
#
# Early stopping triggered at epoch 172
# No improvement in validation accuracy for 100 epochs
#
# Fold 3 Best Results:
# Best Epoch: 71
# Best Validation Accuracy: 0.3515
#
# Fold 4/6
# Epoch 5/1000
# Train Loss: 2.3077, Train Acc: 0.2920
# Val Loss: 2.2450, Val Acc: 0.3057
# Epoch 10/1000
# Train Loss: 2.1934, Train Acc: 0.3040
# Val Loss: 2.1712, Val Acc: 0.3057
# Epoch 15/1000
# Train Loss: 2.1410, Train Acc: 0.3205
# Val Loss: 2.1310, Val Acc: 0.3210
# Epoch 20/1000
# Train Loss: 2.0855, Train Acc: 0.3366
# Val Loss: 2.1078, Val Acc: 0.3231
# Epoch 25/1000
# Train Loss: 2.0637, Train Acc: 0.3358
# Val Loss: 2.0933, Val Acc: 0.3210
# Epoch 30/1000
# Train Loss: 2.0395, Train Acc: 0.3424
# Val Loss: 2.0822, Val Acc: 0.3210
# Epoch 35/1000
# Train Loss: 2.0159, Train Acc: 0.3461
# Val Loss: 2.0735, Val Acc: 0.3210
# Epoch 40/1000
# Train Loss: 1.9923, Train Acc: 0.3434
# Val Loss: 2.0666, Val Acc: 0.3166
# Epoch 45/1000
# Train Loss: 1.9857, Train Acc: 0.3519
# Val Loss: 2.0619, Val Acc: 0.3188
# Epoch 50/1000
# Train Loss: 1.9662, Train Acc: 0.3617
# Val Loss: 2.0576, Val Acc: 0.3122
# Epoch 55/1000
# Train Loss: 1.9539, Train Acc: 0.3623
# Val Loss: 2.0541, Val Acc: 0.3210
# Epoch 60/1000
# Train Loss: 1.9468, Train Acc: 0.3612
# Val Loss: 2.0528, Val Acc: 0.3166
# Epoch 65/1000
# Train Loss: 1.9420, Train Acc: 0.3590
# Val Loss: 2.0483, Val Acc: 0.3231
# Epoch 70/1000
# Train Loss: 1.9247, Train Acc: 0.3594
# Val Loss: 2.0458, Val Acc: 0.3188
# Epoch 75/1000
# Train Loss: 1.9137, Train Acc: 0.3813
# Val Loss: 2.0443, Val Acc: 0.3188
# Epoch 80/1000
# Train Loss: 1.9061, Train Acc: 0.3649
# Val Loss: 2.0413, Val Acc: 0.3166
# Epoch 85/1000
# Train Loss: 1.8998, Train Acc: 0.3733
# Val Loss: 2.0400, Val Acc: 0.3188
# Epoch 90/1000
# Train Loss: 1.8809, Train Acc: 0.3827
# Val Loss: 2.0396, Val Acc: 0.3253
# Epoch 95/1000
# Train Loss: 1.8804, Train Acc: 0.3746
# Val Loss: 2.0400, Val Acc: 0.3210
# Epoch 100/1000
# Train Loss: 1.8713, Train Acc: 0.3803
# Val Loss: 2.0381, Val Acc: 0.3231
# Epoch 105/1000
# Train Loss: 1.8630, Train Acc: 0.3810
# Val Loss: 2.0370, Val Acc: 0.3253
# Epoch 110/1000
# Train Loss: 1.8371, Train Acc: 0.3936
# Val Loss: 2.0377, Val Acc: 0.3188
# Epoch 115/1000
# Train Loss: 1.8480, Train Acc: 0.3874
# Val Loss: 2.0386, Val Acc: 0.3231
# Epoch 120/1000
# Train Loss: 1.8421, Train Acc: 0.3903
# Val Loss: 2.0396, Val Acc: 0.3231
# Epoch 125/1000
# Train Loss: 1.8169, Train Acc: 0.4026
# Val Loss: 2.0401, Val Acc: 0.3100
# Epoch 130/1000
# Train Loss: 1.8303, Train Acc: 0.3994
# Val Loss: 2.0407, Val Acc: 0.3100
# Epoch 135/1000
# Train Loss: 1.8126, Train Acc: 0.4041
# Val Loss: 2.0399, Val Acc: 0.3166
# Epoch 140/1000
# Train Loss: 1.8088, Train Acc: 0.3953
# Val Loss: 2.0404, Val Acc: 0.3122
# Epoch 145/1000
# Train Loss: 1.8063, Train Acc: 0.4002
# Val Loss: 2.0406, Val Acc: 0.3035
# Epoch 150/1000
# Train Loss: 1.8012, Train Acc: 0.3998
# Val Loss: 2.0419, Val Acc: 0.3057
# Epoch 155/1000
# Train Loss: 1.8005, Train Acc: 0.4017
# Val Loss: 2.0414, Val Acc: 0.3079
# Epoch 160/1000
# Train Loss: 1.7805, Train Acc: 0.3920
# Val Loss: 2.0426, Val Acc: 0.3035
#
# Early stopping triggered at epoch 164
# No improvement in validation accuracy for 100 epochs
#
# Fold 4 Best Results:
# Best Epoch: 63
# Best Validation Accuracy: 0.3275
#
# Fold 5/6
# Epoch 5/1000
# Train Loss: 2.3472, Train Acc: 0.2820
# Val Loss: 2.2303, Val Acc: 0.3057
# Epoch 10/1000
# Train Loss: 2.2126, Train Acc: 0.3118
# Val Loss: 2.1523, Val Acc: 0.3275
# Epoch 15/1000
# Train Loss: 2.1389, Train Acc: 0.3265
# Val Loss: 2.1177, Val Acc: 0.3253
# Epoch 20/1000
# Train Loss: 2.1125, Train Acc: 0.3240
# Val Loss: 2.0955, Val Acc: 0.3297
# Epoch 25/1000
# Train Loss: 2.0655, Train Acc: 0.3403
# Val Loss: 2.0792, Val Acc: 0.3362
# Epoch 30/1000
# Train Loss: 2.0225, Train Acc: 0.3414
# Val Loss: 2.0680, Val Acc: 0.3362
# Epoch 35/1000
# Train Loss: 2.0246, Train Acc: 0.3393
# Val Loss: 2.0580, Val Acc: 0.3384
# Epoch 40/1000
# Train Loss: 1.9890, Train Acc: 0.3502
# Val Loss: 2.0496, Val Acc: 0.3384
# Epoch 45/1000
# Train Loss: 1.9841, Train Acc: 0.3525
# Val Loss: 2.0430, Val Acc: 0.3450
# Epoch 50/1000
# Train Loss: 1.9760, Train Acc: 0.3528
# Val Loss: 2.0363, Val Acc: 0.3428
# Epoch 55/1000
# Train Loss: 1.9623, Train Acc: 0.3603
# Val Loss: 2.0307, Val Acc: 0.3406
# Epoch 60/1000
# Train Loss: 1.9494, Train Acc: 0.3626
# Val Loss: 2.0273, Val Acc: 0.3384
# Epoch 65/1000
# Train Loss: 1.9290, Train Acc: 0.3710
# Val Loss: 2.0229, Val Acc: 0.3341
# Epoch 70/1000
# Train Loss: 1.9243, Train Acc: 0.3687
# Val Loss: 2.0190, Val Acc: 0.3297
# Epoch 75/1000
# Train Loss: 1.9092, Train Acc: 0.3678
# Val Loss: 2.0165, Val Acc: 0.3297
# Epoch 80/1000
# Train Loss: 1.9142, Train Acc: 0.3670
# Val Loss: 2.0133, Val Acc: 0.3362
# Epoch 85/1000
# Train Loss: 1.8880, Train Acc: 0.3715
# Val Loss: 2.0101, Val Acc: 0.3297
# Epoch 90/1000
# Train Loss: 1.8889, Train Acc: 0.3723
# Val Loss: 2.0083, Val Acc: 0.3297
# Epoch 95/1000
# Train Loss: 1.8763, Train Acc: 0.3697
# Val Loss: 2.0070, Val Acc: 0.3319
# Epoch 100/1000
# Train Loss: 1.8558, Train Acc: 0.3824
# Val Loss: 2.0062, Val Acc: 0.3319
# Epoch 105/1000
# Train Loss: 1.8596, Train Acc: 0.3785
# Val Loss: 2.0057, Val Acc: 0.3384
# Epoch 110/1000
# Train Loss: 1.8515, Train Acc: 0.3803
# Val Loss: 2.0054, Val Acc: 0.3472
# Epoch 115/1000
# Train Loss: 1.8294, Train Acc: 0.3924
# Val Loss: 2.0053, Val Acc: 0.3472
# Epoch 120/1000
# Train Loss: 1.8264, Train Acc: 0.3888
# Val Loss: 2.0061, Val Acc: 0.3472
# Epoch 125/1000
# Train Loss: 1.8283, Train Acc: 0.3827
# Val Loss: 2.0050, Val Acc: 0.3472
# Epoch 130/1000
# Train Loss: 1.8216, Train Acc: 0.3894
# Val Loss: 2.0039, Val Acc: 0.3472
# Epoch 135/1000
# Train Loss: 1.8094, Train Acc: 0.3862
# Val Loss: 2.0046, Val Acc: 0.3515
# Epoch 140/1000
# Train Loss: 1.8134, Train Acc: 0.3930
# Val Loss: 2.0034, Val Acc: 0.3537
# Epoch 145/1000
# Train Loss: 1.7939, Train Acc: 0.3977
# Val Loss: 2.0047, Val Acc: 0.3493
# Epoch 150/1000
# Train Loss: 1.7871, Train Acc: 0.3924
# Val Loss: 2.0042, Val Acc: 0.3537
# Epoch 155/1000
# Train Loss: 1.7762, Train Acc: 0.4031
# Val Loss: 2.0055, Val Acc: 0.3537
# Epoch 160/1000
# Train Loss: 1.7719, Train Acc: 0.3980
# Val Loss: 2.0054, Val Acc: 0.3581
# Epoch 165/1000
# Train Loss: 1.7851, Train Acc: 0.3914
# Val Loss: 2.0044, Val Acc: 0.3581
# Epoch 170/1000
# Train Loss: 1.7614, Train Acc: 0.4047
# Val Loss: 2.0048, Val Acc: 0.3515
# Epoch 175/1000
# Train Loss: 1.7725, Train Acc: 0.4025
# Val Loss: 2.0046, Val Acc: 0.3537
# Epoch 180/1000
# Train Loss: 1.7494, Train Acc: 0.4036
# Val Loss: 2.0071, Val Acc: 0.3559
# Epoch 185/1000
# Train Loss: 1.7290, Train Acc: 0.4110
# Val Loss: 2.0085, Val Acc: 0.3537
# Epoch 190/1000
# Train Loss: 1.7512, Train Acc: 0.4056
# Val Loss: 2.0091, Val Acc: 0.3559
# Epoch 195/1000
# Train Loss: 1.7233, Train Acc: 0.4195
# Val Loss: 2.0103, Val Acc: 0.3559
# Epoch 200/1000
# Train Loss: 1.7328, Train Acc: 0.4098
# Val Loss: 2.0112, Val Acc: 0.3581
# Epoch 205/1000
# Train Loss: 1.7236, Train Acc: 0.4169
# Val Loss: 2.0121, Val Acc: 0.3515
# Epoch 210/1000
# Train Loss: 1.7128, Train Acc: 0.4102
# Val Loss: 2.0142, Val Acc: 0.3537
# Epoch 215/1000
# Train Loss: 1.7106, Train Acc: 0.4310
# Val Loss: 2.0149, Val Acc: 0.3515
# Epoch 220/1000
# Train Loss: 1.7015, Train Acc: 0.4188
# Val Loss: 2.0177, Val Acc: 0.3515
# Epoch 225/1000
# Train Loss: 1.6812, Train Acc: 0.4219
# Val Loss: 2.0201, Val Acc: 0.3515
# Epoch 230/1000
# Train Loss: 1.6850, Train Acc: 0.4237
# Val Loss: 2.0208, Val Acc: 0.3559
# Epoch 235/1000
# Train Loss: 1.6975, Train Acc: 0.4112
# Val Loss: 2.0223, Val Acc: 0.3493
# Epoch 240/1000
# Train Loss: 1.6758, Train Acc: 0.4157
# Val Loss: 2.0245, Val Acc: 0.3537
# Epoch 245/1000
# Train Loss: 1.6733, Train Acc: 0.4202
# Val Loss: 2.0255, Val Acc: 0.3493
# Epoch 250/1000
# Train Loss: 1.6743, Train Acc: 0.4339
# Val Loss: 2.0275, Val Acc: 0.3493
# Epoch 255/1000
# Train Loss: 1.6333, Train Acc: 0.4258
# Val Loss: 2.0319, Val Acc: 0.3472
# Epoch 260/1000
# Train Loss: 1.6468, Train Acc: 0.4280
# Val Loss: 2.0353, Val Acc: 0.3472
# Epoch 265/1000
# Train Loss: 1.6521, Train Acc: 0.4237
# Val Loss: 2.0360, Val Acc: 0.3428
# Epoch 270/1000
# Train Loss: 1.6489, Train Acc: 0.4341
# Val Loss: 2.0379, Val Acc: 0.3472
#
# Early stopping triggered at epoch 273
# No improvement in validation accuracy for 100 epochs
#
# Fold 5 Best Results:
# Best Epoch: 172
# Best Validation Accuracy: 0.3603
#
# Fold 6/6
# Epoch 5/1000
# Train Loss: 2.3550, Train Acc: 0.2910
# Val Loss: 2.3008, Val Acc: 0.2795
# Epoch 10/1000
# Train Loss: 2.2153, Train Acc: 0.3029
# Val Loss: 2.2235, Val Acc: 0.2948
# Epoch 15/1000
# Train Loss: 2.1577, Train Acc: 0.3050
# Val Loss: 2.1870, Val Acc: 0.2991
# Epoch 20/1000
# Train Loss: 2.0913, Train Acc: 0.3298
# Val Loss: 2.1660, Val Acc: 0.3079
# Epoch 25/1000
# Train Loss: 2.0689, Train Acc: 0.3337
# Val Loss: 2.1540, Val Acc: 0.3188
# Epoch 30/1000
# Train Loss: 2.0320, Train Acc: 0.3469
# Val Loss: 2.1440, Val Acc: 0.3166
# Epoch 35/1000
# Train Loss: 2.0149, Train Acc: 0.3448
# Val Loss: 2.1355, Val Acc: 0.3231
# Epoch 40/1000
# Train Loss: 1.9924, Train Acc: 0.3431
# Val Loss: 2.1291, Val Acc: 0.3188
# Epoch 45/1000
# Train Loss: 1.9921, Train Acc: 0.3582
# Val Loss: 2.1242, Val Acc: 0.3275
# Epoch 50/1000
# Train Loss: 1.9708, Train Acc: 0.3593
# Val Loss: 2.1189, Val Acc: 0.3319
# Epoch 55/1000
# Train Loss: 1.9405, Train Acc: 0.3651
# Val Loss: 2.1152, Val Acc: 0.3341
# Epoch 60/1000
# Train Loss: 1.9288, Train Acc: 0.3693
# Val Loss: 2.1124, Val Acc: 0.3384
# Epoch 65/1000
# Train Loss: 1.9334, Train Acc: 0.3669
# Val Loss: 2.1089, Val Acc: 0.3362
# Epoch 70/1000
# Train Loss: 1.9215, Train Acc: 0.3814
# Val Loss: 2.1062, Val Acc: 0.3428
# Epoch 75/1000
# Train Loss: 1.9103, Train Acc: 0.3719
# Val Loss: 2.1032, Val Acc: 0.3406
# Epoch 80/1000
# Train Loss: 1.8968, Train Acc: 0.3625
# Val Loss: 2.1007, Val Acc: 0.3406
# Epoch 85/1000
# Train Loss: 1.8808, Train Acc: 0.3772
# Val Loss: 2.0993, Val Acc: 0.3428
# Epoch 90/1000
# Train Loss: 1.8670, Train Acc: 0.3790
# Val Loss: 2.0976, Val Acc: 0.3450
# Epoch 95/1000
# Train Loss: 1.8627, Train Acc: 0.3756
# Val Loss: 2.0959, Val Acc: 0.3450
# Epoch 100/1000
# Train Loss: 1.8554, Train Acc: 0.3891
# Val Loss: 2.0966, Val Acc: 0.3450
# Epoch 105/1000
# Train Loss: 1.8562, Train Acc: 0.3887
# Val Loss: 2.0959, Val Acc: 0.3406
# Epoch 110/1000
# Train Loss: 1.8454, Train Acc: 0.3952
# Val Loss: 2.0969, Val Acc: 0.3406
# Epoch 115/1000
# Train Loss: 1.8252, Train Acc: 0.3968
# Val Loss: 2.0966, Val Acc: 0.3450
# Epoch 120/1000
# Train Loss: 1.8300, Train Acc: 0.3813
# Val Loss: 2.0948, Val Acc: 0.3515
# Epoch 125/1000
# Train Loss: 1.8154, Train Acc: 0.3884
# Val Loss: 2.0943, Val Acc: 0.3537
# Epoch 130/1000
# Train Loss: 1.8018, Train Acc: 0.3982
# Val Loss: 2.0960, Val Acc: 0.3537
# Epoch 135/1000
# Train Loss: 1.8009, Train Acc: 0.3915
# Val Loss: 2.0958, Val Acc: 0.3515
# Epoch 140/1000
# Train Loss: 1.7899, Train Acc: 0.3994
# Val Loss: 2.0950, Val Acc: 0.3493
# Epoch 145/1000
# Train Loss: 1.7852, Train Acc: 0.3943
# Val Loss: 2.0953, Val Acc: 0.3493
# Epoch 150/1000
# Train Loss: 1.7614, Train Acc: 0.4049
# Val Loss: 2.0973, Val Acc: 0.3537
# Epoch 155/1000
# Train Loss: 1.7634, Train Acc: 0.3977
# Val Loss: 2.0991, Val Acc: 0.3472
# Epoch 160/1000
# Train Loss: 1.7601, Train Acc: 0.4018
# Val Loss: 2.0999, Val Acc: 0.3537
# Epoch 165/1000
# Train Loss: 1.7483, Train Acc: 0.4109
# Val Loss: 2.1025, Val Acc: 0.3428
# Epoch 170/1000
# Train Loss: 1.7657, Train Acc: 0.3998
# Val Loss: 2.1030, Val Acc: 0.3537
# Epoch 175/1000
# Train Loss: 1.7498, Train Acc: 0.4105
# Val Loss: 2.1036, Val Acc: 0.3515
# Epoch 180/1000
# Train Loss: 1.7453, Train Acc: 0.3987
# Val Loss: 2.1051, Val Acc: 0.3559
# Epoch 185/1000
# Train Loss: 1.7367, Train Acc: 0.4091
# Val Loss: 2.1050, Val Acc: 0.3515
# Epoch 190/1000
# Train Loss: 1.7277, Train Acc: 0.4276
# Val Loss: 2.1065, Val Acc: 0.3537
# Epoch 195/1000
# Train Loss: 1.7168, Train Acc: 0.4183
# Val Loss: 2.1092, Val Acc: 0.3515
# Epoch 200/1000
# Train Loss: 1.7152, Train Acc: 0.4246
# Val Loss: 2.1119, Val Acc: 0.3515
# Epoch 205/1000
# Train Loss: 1.7125, Train Acc: 0.4189
# Val Loss: 2.1128, Val Acc: 0.3472
# Epoch 210/1000
# Train Loss: 1.7111, Train Acc: 0.4221
# Val Loss: 2.1135, Val Acc: 0.3472
# Epoch 215/1000
# Train Loss: 1.7039, Train Acc: 0.4133
# Val Loss: 2.1147, Val Acc: 0.3493
# Epoch 220/1000
# Train Loss: 1.6845, Train Acc: 0.4331
# Val Loss: 2.1165, Val Acc: 0.3472
# Epoch 225/1000
# Train Loss: 1.6854, Train Acc: 0.4310
# Val Loss: 2.1188, Val Acc: 0.3428
# Epoch 230/1000
# Train Loss: 1.6771, Train Acc: 0.4267
# Val Loss: 2.1197, Val Acc: 0.3450
# Epoch 235/1000
# Train Loss: 1.6642, Train Acc: 0.4370
# Val Loss: 2.1214, Val Acc: 0.3428
# Epoch 240/1000
# Train Loss: 1.6486, Train Acc: 0.4413
# Val Loss: 2.1241, Val Acc: 0.3472
# Epoch 245/1000
# Train Loss: 1.6637, Train Acc: 0.4283
# Val Loss: 2.1278, Val Acc: 0.3472
# Epoch 250/1000
# Train Loss: 1.6428, Train Acc: 0.4529
# Val Loss: 2.1285, Val Acc: 0.3472
# Epoch 255/1000
# Train Loss: 1.6456, Train Acc: 0.4292
# Val Loss: 2.1315, Val Acc: 0.3384
# Epoch 260/1000
# Train Loss: 1.6339, Train Acc: 0.4380
# Val Loss: 2.1312, Val Acc: 0.3428
#
# Early stopping triggered at epoch 262
# No improvement in validation accuracy for 100 epochs
#
# Fold 6 Best Results:
# Best Epoch: 161
# Best Validation Accuracy: 0.3581
#
# Overall Cross-validation results:
# Mean validation accuracy: 0.3492
# Standard deviation: 0.0132
#
# Best model from fold 2 at epoch 83
# Best validation accuracy: 0.3624

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

def test_model(best_model, test_df):
    """
    Test the trained model on a new test dataset.
    
    Parameters:
    best_model: trained Keras model
    test_df: pandas DataFrame containing test data
    
    Returns:
    dict containing test accuracy, predictions, and evaluation metrics
    """
    # Prepare test data
    race_columns = [col for col in test_df.columns if col.startswith('Race_')]
    X_test = test_df.drop(columns=race_columns)
    y_test = test_df[race_columns]
    
    # Scale features using the same approach as training
    scaler = StandardScaler()
    X_test_scaled = scaler.fit_transform(X_test)
    
    # Make predictions
    y_pred_proba = best_model.predict(X_test_scaled)
    y_pred = np.argmax(y_pred_proba, axis=1)
    y_test_classes = np.argmax(y_test.values, axis=1)
    
    # Calculate accuracy
    test_accuracy = np.mean(y_pred == y_test_classes)
    
    # Generate classification report
    class_names = [col.replace('Race_', '') for col in race_columns]
    report = classification_report(y_test_classes, y_pred, target_names=class_names)
    
    # Generate confusion matrix
    cm = confusion_matrix(y_test_classes, y_pred)
    
    # Plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names,
                yticklabels=class_names)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.tight_layout()
    
    # Calculate per-class metrics
    per_class_metrics = {}
    for i, class_name in enumerate(class_names):
        true_class = (y_test_classes == i)
        pred_class = (y_pred == i)
        
        true_positives = np.sum(true_class & pred_class)
        false_positives = np.sum(~true_class & pred_class)
        false_negatives = np.sum(true_class & ~pred_class)
        
        precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) > 0 else 0
        recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
        
        per_class_metrics[class_name] = {
            'precision': precision,
            'recall': recall,
            'f1_score': f1
        }
    
    return {
        'test_accuracy': test_accuracy,
        'classification_report': report,
        'confusion_matrix': cm,
        'per_class_metrics': per_class_metrics,
        'predictions': y_pred,
        'prediction_probabilities': y_pred_proba
    }

# Example usage
def evaluate_test_results(test_df, best_model):
    """
    Evaluate and print test results in a readable format.
    """
    results = test_model(best_model, test_df)
    
    print("\n=== Model Evaluation on Test Data ===")
    print(f"\nOverall Test Accuracy: {results['test_accuracy']:.4f}")
    
    print("\nClassification Report:")
    print(results['classification_report'])
    
    print("\nPer-Class Metrics:")
    for class_name, metrics in results['per_class_metrics'].items():
        print(f"\n{class_name}:")
        for metric_name, value in metrics.items():
            print(f"  {metric_name}: {value:.4f}")
    
    return results

# To use the testing script:
results = evaluate_test_results(test_df, best_model)
# Out:
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# === Model Evaluation on Test Data ===
#
# Overall Test Accuracy: 0.3529
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#            Bengal       0.29      0.17      0.21        24
#            Birman       0.33      0.05      0.09        19
# British Shorthair       0.00      0.00      0.00        17
#         Chartreux       0.00      0.00      0.00         3
#          European       0.38      0.95      0.55       102
#        Maine coon       0.00      0.00      0.00        20
#          No breed       0.00      0.00      0.00        48
#             Other       0.00      0.00      0.00        13
#           Persian       0.00      0.00      0.00        19
#           Ragdoll       0.30      0.27      0.29        22
#          Savannah       0.00      0.00      0.00         2
#           Siamese       0.00      0.00      0.00         6
#            Sphynx       0.00      0.00      0.00         8
#    Turkish angora       0.00      0.00      0.00         3
#
#          accuracy                           0.35       306
#         macro avg       0.09      0.10      0.08       306
#      weighted avg       0.19      0.35      0.22       306
#
#
# Per-Class Metrics:
#
# Bengal:
#   precision: 0.2857
#   recall: 0.1667
#   f1_score: 0.2105
#
# Birman:
#   precision: 0.3333
#   recall: 0.0526
#   f1_score: 0.0909
#
# British Shorthair:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Chartreux:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# European:
#   precision: 0.3834
#   recall: 0.9510
#   f1_score: 0.5465
#
# Maine coon:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# No breed:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Other:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Persian:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Ragdoll:
#   precision: 0.3000
#   recall: 0.2727
#   f1_score: 0.2857
#
# Savannah:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Siamese:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Sphynx:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Turkish angora:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000

# %%
import numpy as np

# Definim lungimi posibile ale părului pentru fiecare categorie
hair_length_mapping = {
    'Sphynx': ['No hair'],
    'Siamese': ['Short hair', 'Medium hair'],
    'British Shorthair': ['Short hair'],
    'Bengal': ['Short hair'],
    'Chartreux': ['Short hair'],
    'Savannah': ['Short hair'],
    'European': ['Short hair', 'Medium hair'],
    'Birman': ['Medium hair', 'Long hair'],
    'Turkish angora': ['Medium hair', 'Long hair'],
    'Persian': ['Long hair'],
    'Maine coon': ['Long hair'],
    'Ragdoll': ['Medium hair', 'Long hair'],
    'No breed': ['Short hair', 'Medium hair'],
    'Other': ['Short hair', 'Medium hair']
}

# Funcție pentru a selecta aleator lungimea părului bazat pe rasa specifică
def assign_coat_length(race):
    if race in hair_length_mapping:
        return np.random.choice(hair_length_mapping[race])
    return "Unknown"  # Default, în cazul în care rasa nu este cunoscută

# Aplicăm funcția pentru fiecare instanță
df['Coat Length'] = df['Race'].apply(assign_coat_length)

# %%
# Definirea caracteristicilor legate de coat pattern pentru fiecare rasă
coat_patterns = {
    "European": ["Tabby", "Solid", "Bicolor", "Tortoiseshell"],
    "Bengal": ["Tabby"],
    "Ragdoll": ["Colorpoint"],
    "Maine coon": ["Tabby", "Bicolor"],
    "Birman": ["Colorpoint"],
    "Persian": ["Colorpoint"],
    "British Shorthair": ["Solid", "Tabby", "Tortoiseshell"],
    "Sphynx": ["Solid", "Tabby"],
    "Siamese": ["Colorpoint"],
    "Chartreux": ["Solid"],
    "Turkish angora": ["Solid", "Tabby"],
    "Savannah": ["Tabby"],
    "No breed": ["Tabby", "Solid", "Bicolor", "Tricolor", "Tortoiseshell"],
    "Other": ["Tabby", "Solid", "Bicolor"]
}

# Adăugarea caracteristicilor în mod uniform
df["Coat Pattern"] = df["Race"].apply(
    lambda breed: np.random.choice(coat_patterns[breed])  # Atribuim aleatoriu un pattern din lista corespunzătoare
)

print(df)
# Out:
#      Gender   Age        Race  Number of cats in the household  \
# 0         F   0.5      Birman                                3
# 1         F   0.5      Birman                                1
# 2         F   6.0    European                                4
# 3         F   0.5    European                                1
# 4         F   1.5      Birman                                2
# ...     ...   ...         ...                              ...
# 3138      F   6.0     Persian                                1
# 3139      F   0.5  Maine coon                                3
# 3140      M  12.0       Other                                1
# 3141      M   0.5      Bengal                                1
# 3142      F   0.5      Bengal                                5
#
#                         Type of housing       Zone  \
# 0             Apartment without balcony      Urban
# 1     Apartment with balcony or terrace      Urban
# 2                House in a subdivision      Urban
# 3                House in a subdivision      Rural
# 4                 Individual house zone      Rural
# ...                                 ...        ...
# 3138              Individual house zone      Rural
# 3139              Individual house zone      Rural
# 3140              Individual house zone  Periurban
# 3141             House in a subdivision      Rural
# 3142             House in a subdivision  Periurban
#
#       Time spent outside each day  Time spent with the owner each day  Shy  \
# 0                               0                                   0    1
# 1                               0                                   2    1
# 2                               0                                   2    4
# 3                               2                                   2    3
# 4                               1                                   2    1
# ...                           ...                                 ...  ...
# 3138                            0                                   3    4
# 3139                            0                                   3    2
# 3140                            2                                   3    1
# 3141                            0                                   2    2
# 3142                            0                                   2    2
#
#       Calm  ...  Territorial  Aggressive  Impulsive  Predictable  Inattentive  \
# 0        1  ...            1           1          1            1            1
# 1        1  ...            2           3          4            4            3
# 2        4  ...            1           1          2            4            2
# 3        2  ...            3           3          3            4            4
# 4        4  ...            4           1          4            3            3
# ...    ...  ...          ...         ...        ...          ...          ...
# 3138     2  ...            1           1          1            3            4
# 3139     2  ...            2           1          2            2            2
# 3140     4  ...            4           4          3            4            2
# 3141     4  ...            2           3          1            3            5
# 3142     2  ...            5           4          5            2            3
#
#       The abundance of natural areas  Frequency of Bird Captures  \
# 0                                  2                           4
# 1                                  2                           0
# 2                                  3                           0
# 3                                  3                           0
# 4                                  3                           0
# ...                              ...                         ...
# 3138                               3                           0
# 3139                               3                           0
# 3140                               3                           0
# 3141                               3                           0
# 3142                               3                           0
#
#       Frequency of Small Mammal Captures  Coat Length   Coat Pattern
# 0                                      4  Medium hair     Colorpoint
# 1                                      0    Long hair     Colorpoint
# 2                                      0   Short hair        Bicolor
# 3                                      0   Short hair  Tortoiseshell
# 4                                      0    Long hair     Colorpoint
# ...                                  ...          ...            ...
# 3138                                   0    Long hair     Colorpoint
# 3139                                   0    Long hair          Tabby
# 3140                                   1   Short hair          Tabby
# 3141                                   0   Short hair          Tabby
# 3142                                   0   Short hair          Tabby
#
# [3055 rows x 28 columns]

# %%
# One-hot encode categorical variables
categorical_columns = ['Type of housing', 'Zone', 'Race', 'Gender', 'Coat Length', 'Coat Pattern']
df = encode_categorical_columns(df, categorical_columns)

# Add FlatFace attribute (True for Persian cats)
df['FlatFace'] = df['Race_Persian']

# Split the dataset
train_df, test_df = split_cat_dataset(df, test_size=0.1, random_state=42)
# Out:
# Training set size: 2749 (90.0%)
# Test set size: 306 (10.0%)
#
# Race distribution in original dataset:
# European             0.333224
# No breed             0.157774
# Bengal               0.077905
# Ragdoll              0.070704
# Maine coon           0.064484
# Birman               0.062848
# Persian              0.062848
# British Shorthair    0.054337
# Other                0.044190
# Sphynx               0.024877
# Siamese              0.018985
# Chartreux            0.010147
# Turkish angora       0.009165
# Savannah             0.008511
# Name: proportion, dtype: float64
#
# Race distribution in training set:
# European             0.333212
# No breed             0.157876
# Bengal               0.077846
# Ragdoll              0.070571
# Maine coon           0.064387
# Birman               0.062932
# Persian              0.062932
# British Shorthair    0.054202
# Other                0.044380
# Sphynx               0.024736
# Siamese              0.018916
# Chartreux            0.010186
# Turkish angora       0.009094
# Savannah             0.008730
# Name: proportion, dtype: float64
#
# Race distribution in test set:
# European             0.333333
# No breed             0.156863
# Bengal               0.078431
# Ragdoll              0.071895
# Maine coon           0.065359
# Persian              0.062092
# Birman               0.062092
# British Shorthair    0.055556
# Other                0.042484
# Sphynx               0.026144
# Siamese              0.019608
# Chartreux            0.009804
# Turkish angora       0.009804
# Savannah             0.006536
# Name: proportion, dtype: float64

# %%
# Train the model
best_model, accuracies, histories = main(train_df)
# Out:
# Fold 1/6
# Epoch 5/1000
# Train Loss: 1.8826, Train Acc: 0.4105
# Val Loss: 1.7532, Val Acc: 0.4466
# Epoch 10/1000
# Train Loss: 1.5825, Train Acc: 0.4947
# Val Loss: 1.4684, Val Acc: 0.5599
# Epoch 15/1000
# Train Loss: 1.3888, Train Acc: 0.5508
# Val Loss: 1.3044, Val Acc: 0.6078
# Epoch 20/1000
# Train Loss: 1.2495, Train Acc: 0.6024
# Val Loss: 1.1963, Val Acc: 0.6405
# Epoch 25/1000
# Train Loss: 1.1682, Train Acc: 0.6122
# Val Loss: 1.1190, Val Acc: 0.6449
# Epoch 30/1000
# Train Loss: 1.0989, Train Acc: 0.6189
# Val Loss: 1.0629, Val Acc: 0.6471
# Epoch 35/1000
# Train Loss: 1.0658, Train Acc: 0.6289
# Val Loss: 1.0204, Val Acc: 0.6492
# Epoch 40/1000
# Train Loss: 1.0239, Train Acc: 0.6277
# Val Loss: 0.9898, Val Acc: 0.6732
# Epoch 45/1000
# Train Loss: 0.9841, Train Acc: 0.6451
# Val Loss: 0.9661, Val Acc: 0.6688
# Epoch 50/1000
# Train Loss: 0.9616, Train Acc: 0.6535
# Val Loss: 0.9473, Val Acc: 0.6645
# Epoch 55/1000
# Train Loss: 0.9272, Train Acc: 0.6503
# Val Loss: 0.9310, Val Acc: 0.6688
# Epoch 60/1000
# Train Loss: 0.9131, Train Acc: 0.6551
# Val Loss: 0.9174, Val Acc: 0.6776
# Epoch 65/1000
# Train Loss: 0.9101, Train Acc: 0.6628
# Val Loss: 0.9069, Val Acc: 0.6732
# Epoch 70/1000
# Train Loss: 0.8898, Train Acc: 0.6562
# Val Loss: 0.9002, Val Acc: 0.6688
# Epoch 75/1000
# Train Loss: 0.8667, Train Acc: 0.6600
# Val Loss: 0.8946, Val Acc: 0.6688
# Epoch 80/1000
# Train Loss: 0.8676, Train Acc: 0.6685
# Val Loss: 0.8885, Val Acc: 0.6710
# Epoch 85/1000
# Train Loss: 0.8597, Train Acc: 0.6706
# Val Loss: 0.8828, Val Acc: 0.6710
# Epoch 90/1000
# Train Loss: 0.8489, Train Acc: 0.6751
# Val Loss: 0.8781, Val Acc: 0.6667
# Epoch 95/1000
# Train Loss: 0.8428, Train Acc: 0.6705
# Val Loss: 0.8731, Val Acc: 0.6688
# Epoch 100/1000
# Train Loss: 0.8252, Train Acc: 0.6758
# Val Loss: 0.8719, Val Acc: 0.6688
# Epoch 105/1000
# Train Loss: 0.8272, Train Acc: 0.6751
# Val Loss: 0.8708, Val Acc: 0.6688
# Epoch 110/1000
# Train Loss: 0.8105, Train Acc: 0.6726
# Val Loss: 0.8645, Val Acc: 0.6645
# Epoch 115/1000
# Train Loss: 0.7945, Train Acc: 0.6840
# Val Loss: 0.8628, Val Acc: 0.6732
# Epoch 120/1000
# Train Loss: 0.7914, Train Acc: 0.6868
# Val Loss: 0.8629, Val Acc: 0.6645
# Epoch 125/1000
# Train Loss: 0.7843, Train Acc: 0.6895
# Val Loss: 0.8619, Val Acc: 0.6645
# Epoch 130/1000
# Train Loss: 0.7863, Train Acc: 0.6828
# Val Loss: 0.8624, Val Acc: 0.6645
# Epoch 135/1000
# Train Loss: 0.7825, Train Acc: 0.6907
# Val Loss: 0.8587, Val Acc: 0.6688
# Epoch 140/1000
# Train Loss: 0.7745, Train Acc: 0.6943
# Val Loss: 0.8573, Val Acc: 0.6688
# Epoch 145/1000
# Train Loss: 0.7598, Train Acc: 0.6970
# Val Loss: 0.8604, Val Acc: 0.6688
# Epoch 150/1000
# Train Loss: 0.7581, Train Acc: 0.6989
# Val Loss: 0.8577, Val Acc: 0.6688
# Epoch 155/1000
# Train Loss: 0.7593, Train Acc: 0.6953
# Val Loss: 0.8571, Val Acc: 0.6710
#
# Early stopping triggered at epoch 160
# No improvement in validation accuracy for 100 epochs
#
# Fold 1 Best Results:
# Best Epoch: 59
# Best Validation Accuracy: 0.6776
#
# Fold 2/6
# Epoch 5/1000
# Train Loss: 1.9976, Train Acc: 0.3674
# Val Loss: 1.9081, Val Acc: 0.3668
# Epoch 10/1000
# Train Loss: 1.6653, Train Acc: 0.4582
# Val Loss: 1.6019, Val Acc: 0.4803
# Epoch 15/1000
# Train Loss: 1.4422, Train Acc: 0.5361
# Val Loss: 1.4090, Val Acc: 0.5349
# Epoch 20/1000
# Train Loss: 1.3102, Train Acc: 0.5738
# Val Loss: 1.2795, Val Acc: 0.5830
# Epoch 25/1000
# Train Loss: 1.2029, Train Acc: 0.5934
# Val Loss: 1.1947, Val Acc: 0.6004
# Epoch 30/1000
# Train Loss: 1.1388, Train Acc: 0.6077
# Val Loss: 1.1359, Val Acc: 0.6135
# Epoch 35/1000
# Train Loss: 1.0690, Train Acc: 0.6313
# Val Loss: 1.0949, Val Acc: 0.6245
# Epoch 40/1000
# Train Loss: 1.0283, Train Acc: 0.6353
# Val Loss: 1.0626, Val Acc: 0.6332
# Epoch 45/1000
# Train Loss: 0.9920, Train Acc: 0.6442
# Val Loss: 1.0383, Val Acc: 0.6332
# Epoch 50/1000
# Train Loss: 0.9582, Train Acc: 0.6482
# Val Loss: 1.0186, Val Acc: 0.6397
# Epoch 55/1000
# Train Loss: 0.9460, Train Acc: 0.6559
# Val Loss: 1.0024, Val Acc: 0.6441
# Epoch 60/1000
# Train Loss: 0.9168, Train Acc: 0.6633
# Val Loss: 0.9929, Val Acc: 0.6397
# Epoch 65/1000
# Train Loss: 0.8996, Train Acc: 0.6666
# Val Loss: 0.9861, Val Acc: 0.6485
# Epoch 70/1000
# Train Loss: 0.8768, Train Acc: 0.6689
# Val Loss: 0.9784, Val Acc: 0.6485
# Epoch 75/1000
# Train Loss: 0.8571, Train Acc: 0.6850
# Val Loss: 0.9704, Val Acc: 0.6463
# Epoch 80/1000
# Train Loss: 0.8518, Train Acc: 0.6780
# Val Loss: 0.9671, Val Acc: 0.6485
# Epoch 85/1000
# Train Loss: 0.8396, Train Acc: 0.6746
# Val Loss: 0.9617, Val Acc: 0.6507
# Epoch 90/1000
# Train Loss: 0.8316, Train Acc: 0.6731
# Val Loss: 0.9548, Val Acc: 0.6485
# Epoch 95/1000
# Train Loss: 0.8320, Train Acc: 0.6795
# Val Loss: 0.9533, Val Acc: 0.6485
# Epoch 100/1000
# Train Loss: 0.8290, Train Acc: 0.6827
# Val Loss: 0.9512, Val Acc: 0.6507
# Epoch 105/1000
# Train Loss: 0.8033, Train Acc: 0.6934
# Val Loss: 0.9499, Val Acc: 0.6463
# Epoch 110/1000
# Train Loss: 0.7844, Train Acc: 0.6977
# Val Loss: 0.9468, Val Acc: 0.6376
# Epoch 115/1000
# Train Loss: 0.7813, Train Acc: 0.6898
# Val Loss: 0.9458, Val Acc: 0.6463
# Epoch 120/1000
# Train Loss: 0.7788, Train Acc: 0.6939
# Val Loss: 0.9427, Val Acc: 0.6441
# Epoch 125/1000
# Train Loss: 0.7685, Train Acc: 0.7052
# Val Loss: 0.9459, Val Acc: 0.6397
# Epoch 130/1000
# Train Loss: 0.7567, Train Acc: 0.6986
# Val Loss: 0.9425, Val Acc: 0.6397
# Epoch 135/1000
# Train Loss: 0.7623, Train Acc: 0.7037
# Val Loss: 0.9415, Val Acc: 0.6441
# Epoch 140/1000
# Train Loss: 0.7554, Train Acc: 0.7116
# Val Loss: 0.9406, Val Acc: 0.6397
# Epoch 145/1000
# Train Loss: 0.7495, Train Acc: 0.7022
# Val Loss: 0.9393, Val Acc: 0.6419
# Epoch 150/1000
# Train Loss: 0.7385, Train Acc: 0.7067
# Val Loss: 0.9401, Val Acc: 0.6419
# Epoch 155/1000
# Train Loss: 0.7374, Train Acc: 0.7039
# Val Loss: 0.9409, Val Acc: 0.6397
# Epoch 160/1000
# Train Loss: 0.7274, Train Acc: 0.7099
# Val Loss: 0.9418, Val Acc: 0.6419
# Epoch 165/1000
# Train Loss: 0.7267, Train Acc: 0.7045
# Val Loss: 0.9426, Val Acc: 0.6419
# Epoch 170/1000
# Train Loss: 0.7223, Train Acc: 0.7145
# Val Loss: 0.9425, Val Acc: 0.6397
#
# Early stopping triggered at epoch 171
# No improvement in validation accuracy for 100 epochs
#
# Fold 2 Best Results:
# Best Epoch: 70
# Best Validation Accuracy: 0.6528
#
# Fold 3/6
# Epoch 5/1000
# Train Loss: 1.9529, Train Acc: 0.3772
# Val Loss: 1.7953, Val Acc: 0.4760
# Epoch 10/1000
# Train Loss: 1.5974, Train Acc: 0.4972
# Val Loss: 1.5087, Val Acc: 0.5502
# Epoch 15/1000
# Train Loss: 1.4070, Train Acc: 0.5594
# Val Loss: 1.3559, Val Acc: 0.5786
# Epoch 20/1000
# Train Loss: 1.2695, Train Acc: 0.5863
# Val Loss: 1.2551, Val Acc: 0.5895
# Epoch 25/1000
# Train Loss: 1.1777, Train Acc: 0.5963
# Val Loss: 1.1859, Val Acc: 0.5939
# Epoch 30/1000
# Train Loss: 1.1056, Train Acc: 0.6242
# Val Loss: 1.1362, Val Acc: 0.5983
# Epoch 35/1000
# Train Loss: 1.0530, Train Acc: 0.6338
# Val Loss: 1.0997, Val Acc: 0.6070
# Epoch 40/1000
# Train Loss: 1.0303, Train Acc: 0.6458
# Val Loss: 1.0723, Val Acc: 0.6092
# Epoch 45/1000
# Train Loss: 0.9968, Train Acc: 0.6400
# Val Loss: 1.0529, Val Acc: 0.6048
# Epoch 50/1000
# Train Loss: 0.9597, Train Acc: 0.6483
# Val Loss: 1.0333, Val Acc: 0.6114
# Epoch 55/1000
# Train Loss: 0.9314, Train Acc: 0.6589
# Val Loss: 1.0196, Val Acc: 0.6201
# Epoch 60/1000
# Train Loss: 0.9111, Train Acc: 0.6553
# Val Loss: 1.0084, Val Acc: 0.6179
# Epoch 65/1000
# Train Loss: 0.8894, Train Acc: 0.6589
# Val Loss: 0.9998, Val Acc: 0.6354
# Epoch 70/1000
# Train Loss: 0.8865, Train Acc: 0.6656
# Val Loss: 0.9931, Val Acc: 0.6332
# Epoch 75/1000
# Train Loss: 0.8719, Train Acc: 0.6678
# Val Loss: 0.9877, Val Acc: 0.6332
# Epoch 80/1000
# Train Loss: 0.8625, Train Acc: 0.6737
# Val Loss: 0.9831, Val Acc: 0.6419
# Epoch 85/1000
# Train Loss: 0.8460, Train Acc: 0.6841
# Val Loss: 0.9777, Val Acc: 0.6397
# Epoch 90/1000
# Train Loss: 0.8364, Train Acc: 0.6744
# Val Loss: 0.9730, Val Acc: 0.6266
# Epoch 95/1000
# Train Loss: 0.8250, Train Acc: 0.6860
# Val Loss: 0.9703, Val Acc: 0.6376
# Epoch 100/1000
# Train Loss: 0.8198, Train Acc: 0.6892
# Val Loss: 0.9678, Val Acc: 0.6354
# Epoch 105/1000
# Train Loss: 0.8045, Train Acc: 0.6935
# Val Loss: 0.9688, Val Acc: 0.6376
# Epoch 110/1000
# Train Loss: 0.7958, Train Acc: 0.6885
# Val Loss: 0.9642, Val Acc: 0.6354
# Epoch 115/1000
# Train Loss: 0.7827, Train Acc: 0.6996
# Val Loss: 0.9622, Val Acc: 0.6288
# Epoch 120/1000
# Train Loss: 0.7829, Train Acc: 0.6899
# Val Loss: 0.9627, Val Acc: 0.6354
# Epoch 125/1000
# Train Loss: 0.7616, Train Acc: 0.7008
# Val Loss: 0.9607, Val Acc: 0.6310
# Epoch 130/1000
# Train Loss: 0.7536, Train Acc: 0.7048
# Val Loss: 0.9607, Val Acc: 0.6332
# Epoch 135/1000
# Train Loss: 0.7642, Train Acc: 0.6989
# Val Loss: 0.9603, Val Acc: 0.6288
# Epoch 140/1000
# Train Loss: 0.7442, Train Acc: 0.7082
# Val Loss: 0.9601, Val Acc: 0.6332
# Epoch 145/1000
# Train Loss: 0.7362, Train Acc: 0.7155
# Val Loss: 0.9607, Val Acc: 0.6354
# Epoch 150/1000
# Train Loss: 0.7364, Train Acc: 0.7090
# Val Loss: 0.9608, Val Acc: 0.6288
# Epoch 155/1000
# Train Loss: 0.7411, Train Acc: 0.7099
# Val Loss: 0.9609, Val Acc: 0.6310
# Epoch 160/1000
# Train Loss: 0.7052, Train Acc: 0.7217
# Val Loss: 0.9630, Val Acc: 0.6354
# Epoch 165/1000
# Train Loss: 0.7304, Train Acc: 0.7113
# Val Loss: 0.9633, Val Acc: 0.6332
# Epoch 170/1000
# Train Loss: 0.7227, Train Acc: 0.7129
# Val Loss: 0.9641, Val Acc: 0.6310
# Epoch 175/1000
# Train Loss: 0.7147, Train Acc: 0.7152
# Val Loss: 0.9640, Val Acc: 0.6376
#
# Early stopping triggered at epoch 178
# No improvement in validation accuracy for 100 epochs
#
# Fold 3 Best Results:
# Best Epoch: 77
# Best Validation Accuracy: 0.6419
#
# Fold 4/6
# Epoch 5/1000
# Train Loss: 1.9416, Train Acc: 0.3879
# Val Loss: 1.7762, Val Acc: 0.4498
# Epoch 10/1000
# Train Loss: 1.5694, Train Acc: 0.5005
# Val Loss: 1.4622, Val Acc: 0.5590
# Epoch 15/1000
# Train Loss: 1.3724, Train Acc: 0.5572
# Val Loss: 1.2868, Val Acc: 0.6114
# Epoch 20/1000
# Train Loss: 1.2270, Train Acc: 0.5904
# Val Loss: 1.1837, Val Acc: 0.6266
# Epoch 25/1000
# Train Loss: 1.1480, Train Acc: 0.6121
# Val Loss: 1.1208, Val Acc: 0.6266
# Epoch 30/1000
# Train Loss: 1.0836, Train Acc: 0.6151
# Val Loss: 1.0778, Val Acc: 0.6354
# Epoch 35/1000
# Train Loss: 1.0379, Train Acc: 0.6231
# Val Loss: 1.0465, Val Acc: 0.6310
# Epoch 40/1000
# Train Loss: 1.0082, Train Acc: 0.6352
# Val Loss: 1.0238, Val Acc: 0.6397
# Epoch 45/1000
# Train Loss: 0.9865, Train Acc: 0.6344
# Val Loss: 1.0072, Val Acc: 0.6354
# Epoch 50/1000
# Train Loss: 0.9683, Train Acc: 0.6429
# Val Loss: 0.9943, Val Acc: 0.6288
# Epoch 55/1000
# Train Loss: 0.9380, Train Acc: 0.6522
# Val Loss: 0.9796, Val Acc: 0.6288
# Epoch 60/1000
# Train Loss: 0.9239, Train Acc: 0.6572
# Val Loss: 0.9701, Val Acc: 0.6245
# Epoch 65/1000
# Train Loss: 0.8991, Train Acc: 0.6565
# Val Loss: 0.9624, Val Acc: 0.6354
# Epoch 70/1000
# Train Loss: 0.8718, Train Acc: 0.6623
# Val Loss: 0.9565, Val Acc: 0.6310
# Epoch 75/1000
# Train Loss: 0.8622, Train Acc: 0.6656
# Val Loss: 0.9513, Val Acc: 0.6245
# Epoch 80/1000
# Train Loss: 0.8384, Train Acc: 0.6750
# Val Loss: 0.9464, Val Acc: 0.6288
# Epoch 85/1000
# Train Loss: 0.8450, Train Acc: 0.6786
# Val Loss: 0.9411, Val Acc: 0.6245
# Epoch 90/1000
# Train Loss: 0.8481, Train Acc: 0.6737
# Val Loss: 0.9390, Val Acc: 0.6288
# Epoch 95/1000
# Train Loss: 0.8431, Train Acc: 0.6719
# Val Loss: 0.9359, Val Acc: 0.6310
# Epoch 100/1000
# Train Loss: 0.8055, Train Acc: 0.6801
# Val Loss: 0.9338, Val Acc: 0.6354
# Epoch 105/1000
# Train Loss: 0.8144, Train Acc: 0.6795
# Val Loss: 0.9327, Val Acc: 0.6266
# Epoch 110/1000
# Train Loss: 0.8101, Train Acc: 0.6849
# Val Loss: 0.9293, Val Acc: 0.6332
# Epoch 115/1000
# Train Loss: 0.8021, Train Acc: 0.6854
# Val Loss: 0.9280, Val Acc: 0.6354
# Epoch 120/1000
# Train Loss: 0.7807, Train Acc: 0.6951
# Val Loss: 0.9267, Val Acc: 0.6354
# Epoch 125/1000
# Train Loss: 0.7611, Train Acc: 0.6942
# Val Loss: 0.9257, Val Acc: 0.6354
# Epoch 130/1000
# Train Loss: 0.7715, Train Acc: 0.6951
# Val Loss: 0.9259, Val Acc: 0.6288
# Epoch 135/1000
# Train Loss: 0.7688, Train Acc: 0.6941
# Val Loss: 0.9220, Val Acc: 0.6397
# Epoch 140/1000
# Train Loss: 0.7616, Train Acc: 0.6955
# Val Loss: 0.9230, Val Acc: 0.6310
# Epoch 145/1000
# Train Loss: 0.7400, Train Acc: 0.7007
# Val Loss: 0.9226, Val Acc: 0.6266
# Epoch 150/1000
# Train Loss: 0.7428, Train Acc: 0.7025
# Val Loss: 0.9224, Val Acc: 0.6310
# Epoch 155/1000
# Train Loss: 0.7420, Train Acc: 0.7047
# Val Loss: 0.9219, Val Acc: 0.6245
# Epoch 160/1000
# Train Loss: 0.7382, Train Acc: 0.7050
# Val Loss: 0.9235, Val Acc: 0.6201
# Epoch 165/1000
# Train Loss: 0.7262, Train Acc: 0.7016
# Val Loss: 0.9219, Val Acc: 0.6245
# Epoch 170/1000
# Train Loss: 0.7230, Train Acc: 0.7142
# Val Loss: 0.9246, Val Acc: 0.6288
# Epoch 175/1000
# Train Loss: 0.7102, Train Acc: 0.7216
# Val Loss: 0.9214, Val Acc: 0.6376
# Epoch 180/1000
# Train Loss: 0.7131, Train Acc: 0.7145
# Val Loss: 0.9248, Val Acc: 0.6179
# Epoch 185/1000
# Train Loss: 0.7038, Train Acc: 0.7086
# Val Loss: 0.9251, Val Acc: 0.6266
# Epoch 190/1000
# Train Loss: 0.7120, Train Acc: 0.7203
# Val Loss: 0.9256, Val Acc: 0.6245
# Epoch 195/1000
# Train Loss: 0.6925, Train Acc: 0.7207
# Val Loss: 0.9225, Val Acc: 0.6223
# Epoch 200/1000
# Train Loss: 0.6895, Train Acc: 0.7280
# Val Loss: 0.9296, Val Acc: 0.6157
# Epoch 205/1000
# Train Loss: 0.6923, Train Acc: 0.7306
# Val Loss: 0.9257, Val Acc: 0.6223
# Epoch 210/1000
# Train Loss: 0.6856, Train Acc: 0.7368
# Val Loss: 0.9274, Val Acc: 0.6245
# Epoch 215/1000
# Train Loss: 0.6786, Train Acc: 0.7298
# Val Loss: 0.9231, Val Acc: 0.6354
# Epoch 220/1000
# Train Loss: 0.6748, Train Acc: 0.7320
# Val Loss: 0.9246, Val Acc: 0.6266
# Epoch 225/1000
# Train Loss: 0.6844, Train Acc: 0.7171
# Val Loss: 0.9252, Val Acc: 0.6245
# Epoch 230/1000
# Train Loss: 0.6571, Train Acc: 0.7294
# Val Loss: 0.9281, Val Acc: 0.6201
# Epoch 235/1000
# Train Loss: 0.6574, Train Acc: 0.7371
# Val Loss: 0.9294, Val Acc: 0.6245
#
# Early stopping triggered at epoch 238
# No improvement in validation accuracy for 100 epochs
#
# Fold 4 Best Results:
# Best Epoch: 137
# Best Validation Accuracy: 0.6419
#
# Fold 5/6
# Epoch 5/1000
# Train Loss: 2.0035, Train Acc: 0.3823
# Val Loss: 1.8053, Val Acc: 0.4410
# Epoch 10/1000
# Train Loss: 1.6563, Train Acc: 0.4759
# Val Loss: 1.4914, Val Acc: 0.5306
# Epoch 15/1000
# Train Loss: 1.4723, Train Acc: 0.5284
# Val Loss: 1.3164, Val Acc: 0.5939
# Epoch 20/1000
# Train Loss: 1.3353, Train Acc: 0.5640
# Val Loss: 1.2012, Val Acc: 0.6026
# Epoch 25/1000
# Train Loss: 1.2331, Train Acc: 0.5934
# Val Loss: 1.1215, Val Acc: 0.6201
# Epoch 30/1000
# Train Loss: 1.1403, Train Acc: 0.6154
# Val Loss: 1.0640, Val Acc: 0.6266
# Epoch 35/1000
# Train Loss: 1.0960, Train Acc: 0.6200
# Val Loss: 1.0208, Val Acc: 0.6441
# Epoch 40/1000
# Train Loss: 1.0607, Train Acc: 0.6151
# Val Loss: 0.9881, Val Acc: 0.6441
# Epoch 45/1000
# Train Loss: 1.0367, Train Acc: 0.6274
# Val Loss: 0.9628, Val Acc: 0.6441
# Epoch 50/1000
# Train Loss: 0.9842, Train Acc: 0.6573
# Val Loss: 0.9413, Val Acc: 0.6485
# Epoch 55/1000
# Train Loss: 0.9554, Train Acc: 0.6491
# Val Loss: 0.9236, Val Acc: 0.6507
# Epoch 60/1000
# Train Loss: 0.9395, Train Acc: 0.6501
# Val Loss: 0.9108, Val Acc: 0.6463
# Epoch 65/1000
# Train Loss: 0.9277, Train Acc: 0.6526
# Val Loss: 0.8997, Val Acc: 0.6485
# Epoch 70/1000
# Train Loss: 0.9140, Train Acc: 0.6598
# Val Loss: 0.8903, Val Acc: 0.6463
# Epoch 75/1000
# Train Loss: 0.9069, Train Acc: 0.6691
# Val Loss: 0.8829, Val Acc: 0.6463
# Epoch 80/1000
# Train Loss: 0.8920, Train Acc: 0.6525
# Val Loss: 0.8757, Val Acc: 0.6441
# Epoch 85/1000
# Train Loss: 0.8604, Train Acc: 0.6727
# Val Loss: 0.8699, Val Acc: 0.6507
# Epoch 90/1000
# Train Loss: 0.8556, Train Acc: 0.6689
# Val Loss: 0.8652, Val Acc: 0.6485
# Epoch 95/1000
# Train Loss: 0.8502, Train Acc: 0.6788
# Val Loss: 0.8610, Val Acc: 0.6485
# Epoch 100/1000
# Train Loss: 0.8290, Train Acc: 0.6794
# Val Loss: 0.8575, Val Acc: 0.6463
# Epoch 105/1000
# Train Loss: 0.8282, Train Acc: 0.6727
# Val Loss: 0.8547, Val Acc: 0.6507
# Epoch 110/1000
# Train Loss: 0.8250, Train Acc: 0.6776
# Val Loss: 0.8513, Val Acc: 0.6528
# Epoch 115/1000
# Train Loss: 0.8129, Train Acc: 0.6915
# Val Loss: 0.8478, Val Acc: 0.6594
# Epoch 120/1000
# Train Loss: 0.7996, Train Acc: 0.6880
# Val Loss: 0.8470, Val Acc: 0.6572
# Epoch 125/1000
# Train Loss: 0.7858, Train Acc: 0.6902
# Val Loss: 0.8441, Val Acc: 0.6550
# Epoch 130/1000
# Train Loss: 0.7961, Train Acc: 0.6853
# Val Loss: 0.8424, Val Acc: 0.6594
# Epoch 135/1000
# Train Loss: 0.7908, Train Acc: 0.6859
# Val Loss: 0.8424, Val Acc: 0.6616
# Epoch 140/1000
# Train Loss: 0.7732, Train Acc: 0.6933
# Val Loss: 0.8402, Val Acc: 0.6572
# Epoch 145/1000
# Train Loss: 0.7604, Train Acc: 0.6935
# Val Loss: 0.8413, Val Acc: 0.6616
# Epoch 150/1000
# Train Loss: 0.7564, Train Acc: 0.7054
# Val Loss: 0.8383, Val Acc: 0.6572
# Epoch 155/1000
# Train Loss: 0.7671, Train Acc: 0.6899
# Val Loss: 0.8376, Val Acc: 0.6616
# Epoch 160/1000
# Train Loss: 0.7462, Train Acc: 0.7096
# Val Loss: 0.8359, Val Acc: 0.6594
# Epoch 165/1000
# Train Loss: 0.7458, Train Acc: 0.7076
# Val Loss: 0.8364, Val Acc: 0.6659
# Epoch 170/1000
# Train Loss: 0.7504, Train Acc: 0.7080
# Val Loss: 0.8364, Val Acc: 0.6616
# Epoch 175/1000
# Train Loss: 0.7361, Train Acc: 0.7016
# Val Loss: 0.8360, Val Acc: 0.6550
# Epoch 180/1000
# Train Loss: 0.7502, Train Acc: 0.6944
# Val Loss: 0.8362, Val Acc: 0.6638
# Epoch 185/1000
# Train Loss: 0.7186, Train Acc: 0.7119
# Val Loss: 0.8348, Val Acc: 0.6507
# Epoch 190/1000
# Train Loss: 0.7071, Train Acc: 0.7112
# Val Loss: 0.8340, Val Acc: 0.6507
# Epoch 195/1000
# Train Loss: 0.7152, Train Acc: 0.7060
# Val Loss: 0.8356, Val Acc: 0.6572
# Epoch 200/1000
# Train Loss: 0.6951, Train Acc: 0.7258
# Val Loss: 0.8343, Val Acc: 0.6550
# Epoch 205/1000
# Train Loss: 0.7052, Train Acc: 0.7138
# Val Loss: 0.8357, Val Acc: 0.6594
# Epoch 210/1000
# Train Loss: 0.7035, Train Acc: 0.7200
# Val Loss: 0.8357, Val Acc: 0.6594
# Epoch 215/1000
# Train Loss: 0.7030, Train Acc: 0.7142
# Val Loss: 0.8352, Val Acc: 0.6572
# Epoch 220/1000
# Train Loss: 0.6983, Train Acc: 0.7106
# Val Loss: 0.8352, Val Acc: 0.6594
# Epoch 225/1000
# Train Loss: 0.6749, Train Acc: 0.7174
# Val Loss: 0.8359, Val Acc: 0.6485
# Epoch 230/1000
# Train Loss: 0.6856, Train Acc: 0.7209
# Val Loss: 0.8372, Val Acc: 0.6463
# Epoch 235/1000
# Train Loss: 0.6828, Train Acc: 0.7281
# Val Loss: 0.8401, Val Acc: 0.6463
# Epoch 240/1000
# Train Loss: 0.6810, Train Acc: 0.7194
# Val Loss: 0.8375, Val Acc: 0.6507
# Epoch 245/1000
# Train Loss: 0.6648, Train Acc: 0.7299
# Val Loss: 0.8392, Val Acc: 0.6507
# Epoch 250/1000
# Train Loss: 0.6665, Train Acc: 0.7315
# Val Loss: 0.8432, Val Acc: 0.6507
# Epoch 255/1000
# Train Loss: 0.6553, Train Acc: 0.7369
# Val Loss: 0.8428, Val Acc: 0.6485
# Epoch 260/1000
# Train Loss: 0.6611, Train Acc: 0.7320
# Val Loss: 0.8439, Val Acc: 0.6397
# Epoch 265/1000
# Train Loss: 0.6479, Train Acc: 0.7495
# Val Loss: 0.8427, Val Acc: 0.6419
# Epoch 270/1000
# Train Loss: 0.6500, Train Acc: 0.7381
# Val Loss: 0.8458, Val Acc: 0.6441
#
# Early stopping triggered at epoch 271
# No improvement in validation accuracy for 100 epochs
#
# Fold 5 Best Results:
# Best Epoch: 170
# Best Validation Accuracy: 0.6681
#
# Fold 6/6
# Epoch 5/1000
# Train Loss: 1.8678, Train Acc: 0.4279
# Val Loss: 1.7314, Val Acc: 0.4694
# Epoch 10/1000
# Train Loss: 1.5007, Train Acc: 0.5122
# Val Loss: 1.4365, Val Acc: 0.5284
# Epoch 15/1000
# Train Loss: 1.3121, Train Acc: 0.5753
# Val Loss: 1.2906, Val Acc: 0.5524
# Epoch 20/1000
# Train Loss: 1.1870, Train Acc: 0.6042
# Val Loss: 1.1994, Val Acc: 0.5873
# Epoch 25/1000
# Train Loss: 1.1087, Train Acc: 0.6177
# Val Loss: 1.1401, Val Acc: 0.6048
# Epoch 30/1000
# Train Loss: 1.0583, Train Acc: 0.6305
# Val Loss: 1.0986, Val Acc: 0.6048
# Epoch 35/1000
# Train Loss: 0.9996, Train Acc: 0.6428
# Val Loss: 1.0679, Val Acc: 0.6157
# Epoch 40/1000
# Train Loss: 0.9843, Train Acc: 0.6439
# Val Loss: 1.0416, Val Acc: 0.6245
# Epoch 45/1000
# Train Loss: 0.9692, Train Acc: 0.6396
# Val Loss: 1.0248, Val Acc: 0.6310
# Epoch 50/1000
# Train Loss: 0.9321, Train Acc: 0.6595
# Val Loss: 1.0093, Val Acc: 0.6266
# Epoch 55/1000
# Train Loss: 0.9126, Train Acc: 0.6699
# Val Loss: 0.9935, Val Acc: 0.6310
# Epoch 60/1000
# Train Loss: 0.9009, Train Acc: 0.6620
# Val Loss: 0.9837, Val Acc: 0.6288
# Epoch 65/1000
# Train Loss: 0.8825, Train Acc: 0.6672
# Val Loss: 0.9746, Val Acc: 0.6332
# Epoch 70/1000
# Train Loss: 0.8670, Train Acc: 0.6627
# Val Loss: 0.9682, Val Acc: 0.6354
# Epoch 75/1000
# Train Loss: 0.8598, Train Acc: 0.6689
# Val Loss: 0.9626, Val Acc: 0.6288
# Epoch 80/1000
# Train Loss: 0.8421, Train Acc: 0.6767
# Val Loss: 0.9564, Val Acc: 0.6332
# Epoch 85/1000
# Train Loss: 0.8369, Train Acc: 0.6799
# Val Loss: 0.9513, Val Acc: 0.6310
# Epoch 90/1000
# Train Loss: 0.8176, Train Acc: 0.6814
# Val Loss: 0.9468, Val Acc: 0.6332
# Epoch 95/1000
# Train Loss: 0.8131, Train Acc: 0.6921
# Val Loss: 0.9451, Val Acc: 0.6310
# Epoch 100/1000
# Train Loss: 0.8014, Train Acc: 0.6750
# Val Loss: 0.9413, Val Acc: 0.6376
# Epoch 105/1000
# Train Loss: 0.7877, Train Acc: 0.6901
# Val Loss: 0.9398, Val Acc: 0.6354
# Epoch 110/1000
# Train Loss: 0.7918, Train Acc: 0.6820
# Val Loss: 0.9382, Val Acc: 0.6376
# Epoch 115/1000
# Train Loss: 0.7725, Train Acc: 0.6937
# Val Loss: 0.9350, Val Acc: 0.6376
# Epoch 120/1000
# Train Loss: 0.7890, Train Acc: 0.6907
# Val Loss: 0.9326, Val Acc: 0.6376
# Epoch 125/1000
# Train Loss: 0.7588, Train Acc: 0.6997
# Val Loss: 0.9311, Val Acc: 0.6266
# Epoch 130/1000
# Train Loss: 0.7632, Train Acc: 0.6993
# Val Loss: 0.9305, Val Acc: 0.6288
# Epoch 135/1000
# Train Loss: 0.7558, Train Acc: 0.6946
# Val Loss: 0.9287, Val Acc: 0.6354
# Epoch 140/1000
# Train Loss: 0.7498, Train Acc: 0.7017
# Val Loss: 0.9270, Val Acc: 0.6376
# Epoch 145/1000
# Train Loss: 0.7540, Train Acc: 0.7051
# Val Loss: 0.9268, Val Acc: 0.6376
# Epoch 150/1000
# Train Loss: 0.7514, Train Acc: 0.7021
# Val Loss: 0.9236, Val Acc: 0.6354
# Epoch 155/1000
# Train Loss: 0.7382, Train Acc: 0.6990
# Val Loss: 0.9259, Val Acc: 0.6332
# Epoch 160/1000
# Train Loss: 0.7444, Train Acc: 0.7029
# Val Loss: 0.9235, Val Acc: 0.6332
# Epoch 165/1000
# Train Loss: 0.7411, Train Acc: 0.7051
# Val Loss: 0.9236, Val Acc: 0.6332
# Epoch 170/1000
# Train Loss: 0.7202, Train Acc: 0.7060
# Val Loss: 0.9265, Val Acc: 0.6332
# Epoch 175/1000
# Train Loss: 0.7125, Train Acc: 0.7175
# Val Loss: 0.9241, Val Acc: 0.6266
# Epoch 180/1000
# Train Loss: 0.7099, Train Acc: 0.7161
# Val Loss: 0.9283, Val Acc: 0.6310
# Epoch 185/1000
# Train Loss: 0.7124, Train Acc: 0.7124
# Val Loss: 0.9247, Val Acc: 0.6245
# Epoch 190/1000
# Train Loss: 0.7092, Train Acc: 0.7139
# Val Loss: 0.9245, Val Acc: 0.6245
# Epoch 195/1000
# Train Loss: 0.7186, Train Acc: 0.7067
# Val Loss: 0.9260, Val Acc: 0.6310
# Epoch 200/1000
# Train Loss: 0.7072, Train Acc: 0.7138
# Val Loss: 0.9236, Val Acc: 0.6288
# Epoch 205/1000
# Train Loss: 0.6983, Train Acc: 0.7083
# Val Loss: 0.9241, Val Acc: 0.6288
# Epoch 210/1000
# Train Loss: 0.6857, Train Acc: 0.7271
# Val Loss: 0.9271, Val Acc: 0.6245
# Epoch 215/1000
# Train Loss: 0.6737, Train Acc: 0.7331
# Val Loss: 0.9298, Val Acc: 0.6223
#
# Early stopping triggered at epoch 218
# No improvement in validation accuracy for 100 epochs
#
# Fold 6 Best Results:
# Best Epoch: 117
# Best Validation Accuracy: 0.6419
#
# Overall Cross-validation results:
# Mean validation accuracy: 0.6540
# Standard deviation: 0.0141
#
# Best model from fold 1 at epoch 59
# Best validation accuracy: 0.6776

# %%
results = evaluate_test_results(test_df, best_model)
# Out:
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# === Model Evaluation on Test Data ===
#
# Overall Test Accuracy: 0.6438
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#            Bengal       0.73      0.92      0.81        24
#            Birman       0.38      0.42      0.40        19
# British Shorthair       0.75      0.35      0.48        17
#         Chartreux       0.00      0.00      0.00         3
#          European       0.58      0.94      0.72       102
#        Maine coon       1.00      1.00      1.00        20
#          No breed       1.00      0.15      0.25        48
#             Other       0.00      0.00      0.00        13
#           Persian       1.00      1.00      1.00        19
#           Ragdoll       0.40      0.45      0.43        22
#          Savannah       0.00      0.00      0.00         2
#           Siamese       1.00      0.17      0.29         6
#            Sphynx       1.00      1.00      1.00         8
#    Turkish angora       0.00      0.00      0.00         3
#
#          accuracy                           0.64       306
#         macro avg       0.56      0.46      0.46       306
#      weighted avg       0.67      0.64      0.58       306
#
#
# Per-Class Metrics:
#
# Bengal:
#   precision: 0.7333
#   recall: 0.9167
#   f1_score: 0.8148
#
# Birman:
#   precision: 0.3810
#   recall: 0.4211
#   f1_score: 0.4000
#
# British Shorthair:
#   precision: 0.7500
#   recall: 0.3529
#   f1_score: 0.4800
#
# Chartreux:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# European:
#   precision: 0.5783
#   recall: 0.9412
#   f1_score: 0.7164
#
# Maine coon:
#   precision: 1.0000
#   recall: 1.0000
#   f1_score: 1.0000
#
# No breed:
#   precision: 1.0000
#   recall: 0.1458
#   f1_score: 0.2545
#
# Other:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Persian:
#   precision: 1.0000
#   recall: 1.0000
#   f1_score: 1.0000
#
# Ragdoll:
#   precision: 0.4000
#   recall: 0.4545
#   f1_score: 0.4255
#
# Savannah:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Siamese:
#   precision: 1.0000
#   recall: 0.1667
#   f1_score: 0.2857
#
# Sphynx:
#   precision: 1.0000
#   recall: 1.0000
#   f1_score: 1.0000
#
# Turkish angora:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000

# %% [markdown]
# > Antrenarea pe setul de date dupa ce au fost eliminati o parte din outliers pentru fiecare rasa si atribut in parte.

# %%
import pandas as pd
import numpy as np

def remove_race_outliers(df, percentage=5):
    """
    Remove outliers for each cat race based on numerical columns.
    Shows distribution of races before and after outlier removal.
    
    Parameters:
    df (pandas.DataFrame): Input dataframe
    percentage (float): Percentage of outliers to remove (default 5%)
    
    Returns:
    pandas.DataFrame: DataFrame with outliers removed
    """
    # Get list of race columns and numerical columns
    race_columns = [col for col in df.columns if col.startswith('Race_')]
    numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
    numerical_cols = [col for col in numerical_cols if not col.startswith('Race_')]
    
    # Calculate initial race distribution
    print("\nInitial Race Distribution:")
    initial_dist = {}
    for race_col in race_columns:
        race_count = df[race_col].sum()
        race_pct = (race_count / len(df)) * 100
        initial_dist[race_col.replace('Race_', '')] = (race_count, race_pct)
        print(f"{race_col.replace('Race_', ''):15} {race_count:5d} cats ({race_pct:5.1f}%)")
    
    # Create mask for final filtering
    final_mask = pd.Series(True, index=df.index)
    
    for race_col in race_columns:
        # Get subset of data for this race
        race_mask = df[race_col]
        race_data = df[race_mask]
        
        if len(race_data) == 0:
            continue
            
        # Calculate outlier scores for each numerical column
        outlier_scores = pd.DataFrame()
        
        for col in numerical_cols:
            if race_data[col].nunique() > 1:  # Only process if there's variation
                Q1 = race_data[col].quantile(0.25)
                Q3 = race_data[col].quantile(0.75)
                IQR = Q3 - Q1
                
                # Calculate z-scores for more robust outlier detection
                z_scores = np.abs((race_data[col] - race_data[col].mean()) / race_data[col].std())
                outlier_scores[col] = z_scores
        
        if not outlier_scores.empty:
            # Calculate mean outlier score across all columns
            mean_outlier_score = outlier_scores.mean(axis=1)
            
            # Calculate threshold for given percentage
            threshold = mean_outlier_score.quantile(1 - percentage/100)
            
            # Update final mask
            race_indices = race_data.index[mean_outlier_score <= threshold]
            final_mask.loc[race_mask] = race_data.index.isin(race_indices)
    
    # Apply final mask to remove outliers
    cleaned_df = df[final_mask].copy()
    
    # Print summary of removed records
    removed_count = len(df) - len(cleaned_df)
    print(f"\nRemoved {removed_count} records ({(removed_count/len(df)*100):.1f}% of total)")
    
    # Calculate final race distribution
    print("\nFinal Race Distribution:")
    print("Race            Initial Count (%)    Final Count (%)    Change")
    print("-" * 65)
    for race_col in race_columns:
        race_name = race_col.replace('Race_', '')
        final_count = cleaned_df[race_col].sum()
        final_pct = (final_count / len(cleaned_df)) * 100
        initial_count, initial_pct = initial_dist[race_name]
        change_pct = final_pct - initial_pct
        print(f"{race_name:15} {initial_count:5d} ({initial_pct:5.1f}%)    {final_count:5d} ({final_pct:5.1f}%)    {change_pct:+5.1f}%")
    
    return cleaned_df

# Assuming your DataFrame is called 'df'
df = remove_race_outliers(df, percentage=5)
# Out:
# Initial Race Distribution:
# Bengal            238 cats (  7.8%)
# Birman            192 cats (  6.3%)
# British Shorthair   166 cats (  5.4%)
# Chartreux          31 cats (  1.0%)
# European         1018 cats ( 33.3%)
# Maine coon        197 cats (  6.4%)
# No breed          482 cats ( 15.8%)
# Other             135 cats (  4.4%)
# Persian           192 cats (  6.3%)
# Ragdoll           216 cats (  7.1%)
# Savannah           26 cats (  0.9%)
# Siamese            58 cats (  1.9%)
# Sphynx             76 cats (  2.5%)
# Turkish angora     28 cats (  0.9%)
#
# Removed 158 records (5.2% of total)
#
# Final Race Distribution:
# Race            Initial Count (%)    Final Count (%)    Change
# -----------------------------------------------------------------
# Bengal            238 (  7.8%)      226 (  7.8%)     +0.0%
# Birman            192 (  6.3%)      182 (  6.3%)     -0.0%
# British Shorthair   166 (  5.4%)      157 (  5.4%)     -0.0%
# Chartreux          31 (  1.0%)       29 (  1.0%)     -0.0%
# European         1018 ( 33.3%)      967 ( 33.4%)     +0.1%
# Maine coon        197 (  6.4%)      187 (  6.5%)     +0.0%
# No breed          482 ( 15.8%)      457 ( 15.8%)     -0.0%
# Other             135 (  4.4%)      128 (  4.4%)     -0.0%
# Persian           192 (  6.3%)      182 (  6.3%)     -0.0%
# Ragdoll           216 (  7.1%)      205 (  7.1%)     +0.0%
# Savannah           26 (  0.9%)       24 (  0.8%)     -0.0%
# Siamese            58 (  1.9%)       55 (  1.9%)     -0.0%
# Sphynx             76 (  2.5%)       72 (  2.5%)     -0.0%
# Turkish angora     28 (  0.9%)       26 (  0.9%)     -0.0%

# %%
# Split the dataset
train_df, test_df = split_cat_dataset(df, test_size=0.1, random_state=42)
# Out:
# Training set size: 2607 (90.0%)
# Test set size: 290 (10.0%)
#
# Race distribution in original dataset:
# European             0.333794
# No breed             0.157749
# Bengal               0.078012
# Ragdoll              0.070763
# Maine coon           0.064550
# Birman               0.062824
# Persian              0.062824
# British Shorthair    0.054194
# Other                0.044184
# Sphynx               0.024853
# Siamese              0.018985
# Chartreux            0.010010
# Turkish angora       0.008975
# Savannah             0.008284
# Name: proportion, dtype: float64
#
# Race distribution in training set:
# European             0.333717
# No breed             0.157652
# Bengal               0.077867
# Ragdoll              0.070963
# Maine coon           0.064442
# Persian              0.062908
# Birman               0.062908
# British Shorthair    0.054085
# Other                0.044112
# Sphynx               0.024933
# Siamese              0.019179
# Chartreux            0.009973
# Turkish angora       0.008822
# Savannah             0.008439
# Name: proportion, dtype: float64
#
# Race distribution in test set:
# European             0.334483
# No breed             0.158621
# Bengal               0.079310
# Ragdoll              0.068966
# Maine coon           0.065517
# Birman               0.062069
# Persian              0.062069
# British Shorthair    0.055172
# Other                0.044828
# Sphynx               0.024138
# Siamese              0.017241
# Turkish angora       0.010345
# Chartreux            0.010345
# Savannah             0.006897
# Name: proportion, dtype: float64

# %%
# Train the model
best_model, accuracies, histories = main(train_df)
# Out:
# Fold 1/6
# Epoch 5/1000
# Train Loss: 1.9437, Train Acc: 0.3969
# Val Loss: 1.7731, Val Acc: 0.4483
# Epoch 10/1000
# Train Loss: 1.5715, Train Acc: 0.5037
# Val Loss: 1.4690, Val Acc: 0.5356
# Epoch 15/1000
# Train Loss: 1.3912, Train Acc: 0.5691
# Val Loss: 1.2907, Val Acc: 0.5655
# Epoch 20/1000
# Train Loss: 1.2686, Train Acc: 0.5927
# Val Loss: 1.1833, Val Acc: 0.5885
# Epoch 25/1000
# Train Loss: 1.1702, Train Acc: 0.5974
# Val Loss: 1.1109, Val Acc: 0.6000
# Epoch 30/1000
# Train Loss: 1.0910, Train Acc: 0.6333
# Val Loss: 1.0606, Val Acc: 0.6161
# Epoch 35/1000
# Train Loss: 1.0494, Train Acc: 0.6281
# Val Loss: 1.0238, Val Acc: 0.6161
# Epoch 40/1000
# Train Loss: 1.0041, Train Acc: 0.6389
# Val Loss: 0.9967, Val Acc: 0.6207
# Epoch 45/1000
# Train Loss: 0.9755, Train Acc: 0.6443
# Val Loss: 0.9750, Val Acc: 0.6184
# Epoch 50/1000
# Train Loss: 0.9474, Train Acc: 0.6498
# Val Loss: 0.9595, Val Acc: 0.6276
# Epoch 55/1000
# Train Loss: 0.9324, Train Acc: 0.6492
# Val Loss: 0.9445, Val Acc: 0.6276
# Epoch 60/1000
# Train Loss: 0.9037, Train Acc: 0.6594
# Val Loss: 0.9341, Val Acc: 0.6299
# Epoch 65/1000
# Train Loss: 0.8737, Train Acc: 0.6634
# Val Loss: 0.9243, Val Acc: 0.6322
# Epoch 70/1000
# Train Loss: 0.8592, Train Acc: 0.6781
# Val Loss: 0.9161, Val Acc: 0.6345
# Epoch 75/1000
# Train Loss: 0.8571, Train Acc: 0.6810
# Val Loss: 0.9091, Val Acc: 0.6322
# Epoch 80/1000
# Train Loss: 0.8376, Train Acc: 0.6883
# Val Loss: 0.9055, Val Acc: 0.6299
# Epoch 85/1000
# Train Loss: 0.8262, Train Acc: 0.6807
# Val Loss: 0.8993, Val Acc: 0.6345
# Epoch 90/1000
# Train Loss: 0.8176, Train Acc: 0.6720
# Val Loss: 0.8945, Val Acc: 0.6345
# Epoch 95/1000
# Train Loss: 0.8034, Train Acc: 0.6897
# Val Loss: 0.8894, Val Acc: 0.6345
# Epoch 100/1000
# Train Loss: 0.7952, Train Acc: 0.6897
# Val Loss: 0.8858, Val Acc: 0.6345
# Epoch 105/1000
# Train Loss: 0.7907, Train Acc: 0.6983
# Val Loss: 0.8836, Val Acc: 0.6345
# Epoch 110/1000
# Train Loss: 0.7984, Train Acc: 0.6835
# Val Loss: 0.8791, Val Acc: 0.6414
# Epoch 115/1000
# Train Loss: 0.7879, Train Acc: 0.6893
# Val Loss: 0.8779, Val Acc: 0.6437
# Epoch 120/1000
# Train Loss: 0.7792, Train Acc: 0.6929
# Val Loss: 0.8759, Val Acc: 0.6460
# Epoch 125/1000
# Train Loss: 0.7597, Train Acc: 0.6852
# Val Loss: 0.8737, Val Acc: 0.6414
# Epoch 130/1000
# Train Loss: 0.7509, Train Acc: 0.6975
# Val Loss: 0.8721, Val Acc: 0.6391
# Epoch 135/1000
# Train Loss: 0.7525, Train Acc: 0.7039
# Val Loss: 0.8696, Val Acc: 0.6483
# Epoch 140/1000
# Train Loss: 0.7455, Train Acc: 0.7132
# Val Loss: 0.8695, Val Acc: 0.6483
# Epoch 145/1000
# Train Loss: 0.7307, Train Acc: 0.7063
# Val Loss: 0.8702, Val Acc: 0.6414
# Epoch 150/1000
# Train Loss: 0.7361, Train Acc: 0.7092
# Val Loss: 0.8684, Val Acc: 0.6483
# Epoch 155/1000
# Train Loss: 0.7407, Train Acc: 0.7067
# Val Loss: 0.8686, Val Acc: 0.6414
# Epoch 160/1000
# Train Loss: 0.7153, Train Acc: 0.7159
# Val Loss: 0.8677, Val Acc: 0.6299
# Epoch 165/1000
# Train Loss: 0.7239, Train Acc: 0.7094
# Val Loss: 0.8667, Val Acc: 0.6391
# Epoch 170/1000
# Train Loss: 0.7315, Train Acc: 0.7099
# Val Loss: 0.8685, Val Acc: 0.6368
# Epoch 175/1000
# Train Loss: 0.7172, Train Acc: 0.7077
# Val Loss: 0.8679, Val Acc: 0.6437
# Epoch 180/1000
# Train Loss: 0.7051, Train Acc: 0.7160
# Val Loss: 0.8680, Val Acc: 0.6437
# Epoch 185/1000
# Train Loss: 0.7003, Train Acc: 0.7252
# Val Loss: 0.8691, Val Acc: 0.6345
# Epoch 190/1000
# Train Loss: 0.6924, Train Acc: 0.7315
# Val Loss: 0.8709, Val Acc: 0.6391
# Epoch 195/1000
# Train Loss: 0.6845, Train Acc: 0.7205
# Val Loss: 0.8704, Val Acc: 0.6368
# Epoch 200/1000
# Train Loss: 0.6917, Train Acc: 0.7197
# Val Loss: 0.8714, Val Acc: 0.6322
# Epoch 205/1000
# Train Loss: 0.6912, Train Acc: 0.7163
# Val Loss: 0.8711, Val Acc: 0.6368
# Epoch 210/1000
# Train Loss: 0.6874, Train Acc: 0.7110
# Val Loss: 0.8725, Val Acc: 0.6368
# Epoch 215/1000
# Train Loss: 0.6622, Train Acc: 0.7336
# Val Loss: 0.8741, Val Acc: 0.6437
# Epoch 220/1000
# Train Loss: 0.6880, Train Acc: 0.7155
# Val Loss: 0.8730, Val Acc: 0.6414
# Epoch 225/1000
# Train Loss: 0.6601, Train Acc: 0.7283
# Val Loss: 0.8748, Val Acc: 0.6414
# Epoch 230/1000
# Train Loss: 0.6744, Train Acc: 0.7361
# Val Loss: 0.8761, Val Acc: 0.6483
# Epoch 235/1000
# Train Loss: 0.6565, Train Acc: 0.7361
# Val Loss: 0.8760, Val Acc: 0.6483
#
# Early stopping triggered at epoch 236
# No improvement in validation accuracy for 100 epochs
#
# Fold 1 Best Results:
# Best Epoch: 135
# Best Validation Accuracy: 0.6506
#
# Fold 2/6
# Epoch 5/1000
# Train Loss: 1.8893, Train Acc: 0.4152
# Val Loss: 1.7524, Val Acc: 0.4506
# Epoch 10/1000
# Train Loss: 1.5364, Train Acc: 0.5055
# Val Loss: 1.4837, Val Acc: 0.5103
# Epoch 15/1000
# Train Loss: 1.3744, Train Acc: 0.5493
# Val Loss: 1.3355, Val Acc: 0.5586
# Epoch 20/1000
# Train Loss: 1.2505, Train Acc: 0.5758
# Val Loss: 1.2364, Val Acc: 0.5931
# Epoch 25/1000
# Train Loss: 1.1659, Train Acc: 0.5990
# Val Loss: 1.1685, Val Acc: 0.6092
# Epoch 30/1000
# Train Loss: 1.1082, Train Acc: 0.6127
# Val Loss: 1.1139, Val Acc: 0.6046
# Epoch 35/1000
# Train Loss: 1.0478, Train Acc: 0.6441
# Val Loss: 1.0745, Val Acc: 0.6046
# Epoch 40/1000
# Train Loss: 0.9946, Train Acc: 0.6329
# Val Loss: 1.0420, Val Acc: 0.6184
# Epoch 45/1000
# Train Loss: 0.9855, Train Acc: 0.6400
# Val Loss: 1.0179, Val Acc: 0.6161
# Epoch 50/1000
# Train Loss: 0.9551, Train Acc: 0.6397
# Val Loss: 0.9958, Val Acc: 0.6207
# Epoch 55/1000
# Train Loss: 0.9235, Train Acc: 0.6577
# Val Loss: 0.9788, Val Acc: 0.6322
# Epoch 60/1000
# Train Loss: 0.8941, Train Acc: 0.6663
# Val Loss: 0.9632, Val Acc: 0.6345
# Epoch 65/1000
# Train Loss: 0.8916, Train Acc: 0.6656
# Val Loss: 0.9515, Val Acc: 0.6299
# Epoch 70/1000
# Train Loss: 0.8677, Train Acc: 0.6655
# Val Loss: 0.9402, Val Acc: 0.6368
# Epoch 75/1000
# Train Loss: 0.8568, Train Acc: 0.6784
# Val Loss: 0.9320, Val Acc: 0.6368
# Epoch 80/1000
# Train Loss: 0.8414, Train Acc: 0.6729
# Val Loss: 0.9267, Val Acc: 0.6437
# Epoch 85/1000
# Train Loss: 0.8342, Train Acc: 0.6819
# Val Loss: 0.9156, Val Acc: 0.6276
# Epoch 90/1000
# Train Loss: 0.8276, Train Acc: 0.6735
# Val Loss: 0.9116, Val Acc: 0.6460
# Epoch 95/1000
# Train Loss: 0.7973, Train Acc: 0.6912
# Val Loss: 0.9068, Val Acc: 0.6552
# Epoch 100/1000
# Train Loss: 0.7966, Train Acc: 0.6878
# Val Loss: 0.9000, Val Acc: 0.6483
# Epoch 105/1000
# Train Loss: 0.8019, Train Acc: 0.6667
# Val Loss: 0.8955, Val Acc: 0.6437
# Epoch 110/1000
# Train Loss: 0.7826, Train Acc: 0.6864
# Val Loss: 0.8926, Val Acc: 0.6575
# Epoch 115/1000
# Train Loss: 0.7662, Train Acc: 0.6947
# Val Loss: 0.8887, Val Acc: 0.6598
# Epoch 120/1000
# Train Loss: 0.7760, Train Acc: 0.6880
# Val Loss: 0.8859, Val Acc: 0.6598
# Epoch 125/1000
# Train Loss: 0.7575, Train Acc: 0.7077
# Val Loss: 0.8837, Val Acc: 0.6552
# Epoch 130/1000
# Train Loss: 0.7640, Train Acc: 0.6916
# Val Loss: 0.8855, Val Acc: 0.6575
# Epoch 135/1000
# Train Loss: 0.7589, Train Acc: 0.6995
# Val Loss: 0.8827, Val Acc: 0.6690
# Epoch 140/1000
# Train Loss: 0.7389, Train Acc: 0.7025
# Val Loss: 0.8797, Val Acc: 0.6506
# Epoch 145/1000
# Train Loss: 0.7278, Train Acc: 0.7088
# Val Loss: 0.8777, Val Acc: 0.6506
# Epoch 150/1000
# Train Loss: 0.7177, Train Acc: 0.7050
# Val Loss: 0.8770, Val Acc: 0.6621
# Epoch 155/1000
# Train Loss: 0.7446, Train Acc: 0.6943
# Val Loss: 0.8780, Val Acc: 0.6713
# Epoch 160/1000
# Train Loss: 0.7215, Train Acc: 0.7062
# Val Loss: 0.8775, Val Acc: 0.6667
# Epoch 165/1000
# Train Loss: 0.7181, Train Acc: 0.7069
# Val Loss: 0.8781, Val Acc: 0.6736
# Epoch 170/1000
# Train Loss: 0.7076, Train Acc: 0.7157
# Val Loss: 0.8775, Val Acc: 0.6713
# Epoch 175/1000
# Train Loss: 0.7003, Train Acc: 0.7218
# Val Loss: 0.8743, Val Acc: 0.6552
# Epoch 180/1000
# Train Loss: 0.7037, Train Acc: 0.7242
# Val Loss: 0.8794, Val Acc: 0.6713
# Epoch 185/1000
# Train Loss: 0.6997, Train Acc: 0.7139
# Val Loss: 0.8815, Val Acc: 0.6713
# Epoch 190/1000
# Train Loss: 0.6971, Train Acc: 0.7195
# Val Loss: 0.8772, Val Acc: 0.6644
# Epoch 195/1000
# Train Loss: 0.6684, Train Acc: 0.7281
# Val Loss: 0.8784, Val Acc: 0.6667
# Epoch 200/1000
# Train Loss: 0.6912, Train Acc: 0.7128
# Val Loss: 0.8780, Val Acc: 0.6598
# Epoch 205/1000
# Train Loss: 0.6803, Train Acc: 0.7235
# Val Loss: 0.8786, Val Acc: 0.6575
# Epoch 210/1000
# Train Loss: 0.6768, Train Acc: 0.7176
# Val Loss: 0.8830, Val Acc: 0.6667
# Epoch 215/1000
# Train Loss: 0.6686, Train Acc: 0.7142
# Val Loss: 0.8802, Val Acc: 0.6598
# Epoch 220/1000
# Train Loss: 0.6675, Train Acc: 0.7375
# Val Loss: 0.8820, Val Acc: 0.6644
# Epoch 225/1000
# Train Loss: 0.6523, Train Acc: 0.7367
# Val Loss: 0.8855, Val Acc: 0.6621
# Epoch 230/1000
# Train Loss: 0.6574, Train Acc: 0.7344
# Val Loss: 0.8826, Val Acc: 0.6575
# Epoch 235/1000
# Train Loss: 0.6682, Train Acc: 0.7342
# Val Loss: 0.8872, Val Acc: 0.6644
# Epoch 240/1000
# Train Loss: 0.6475, Train Acc: 0.7391
# Val Loss: 0.8852, Val Acc: 0.6575
# Epoch 245/1000
# Train Loss: 0.6412, Train Acc: 0.7470
# Val Loss: 0.8874, Val Acc: 0.6483
# Epoch 250/1000
# Train Loss: 0.6552, Train Acc: 0.7402
# Val Loss: 0.8956, Val Acc: 0.6644
# Epoch 255/1000
# Train Loss: 0.6393, Train Acc: 0.7364
# Val Loss: 0.8924, Val Acc: 0.6529
# Epoch 260/1000
# Train Loss: 0.6393, Train Acc: 0.7418
# Val Loss: 0.8884, Val Acc: 0.6506
# Epoch 265/1000
# Train Loss: 0.6311, Train Acc: 0.7474
# Val Loss: 0.8920, Val Acc: 0.6529
#
# Early stopping triggered at epoch 266
# No improvement in validation accuracy for 100 epochs
#
# Fold 2 Best Results:
# Best Epoch: 165
# Best Validation Accuracy: 0.6759
#
# Fold 3/6
# Epoch 5/1000
# Train Loss: 1.8917, Train Acc: 0.4022
# Val Loss: 1.7050, Val Acc: 0.4644
# Epoch 10/1000
# Train Loss: 1.5295, Train Acc: 0.5054
# Val Loss: 1.4170, Val Acc: 0.5517
# Epoch 15/1000
# Train Loss: 1.3319, Train Acc: 0.5655
# Val Loss: 1.2591, Val Acc: 0.5908
# Epoch 20/1000
# Train Loss: 1.2145, Train Acc: 0.5968
# Val Loss: 1.1615, Val Acc: 0.6092
# Epoch 25/1000
# Train Loss: 1.1202, Train Acc: 0.6051
# Val Loss: 1.0958, Val Acc: 0.6253
# Epoch 30/1000
# Train Loss: 1.0513, Train Acc: 0.6318
# Val Loss: 1.0504, Val Acc: 0.6230
# Epoch 35/1000
# Train Loss: 1.0142, Train Acc: 0.6324
# Val Loss: 1.0187, Val Acc: 0.6276
# Epoch 40/1000
# Train Loss: 0.9667, Train Acc: 0.6488
# Val Loss: 0.9966, Val Acc: 0.6322
# Epoch 45/1000
# Train Loss: 0.9456, Train Acc: 0.6536
# Val Loss: 0.9797, Val Acc: 0.6368
# Epoch 50/1000
# Train Loss: 0.9120, Train Acc: 0.6610
# Val Loss: 0.9676, Val Acc: 0.6414
# Epoch 55/1000
# Train Loss: 0.8750, Train Acc: 0.6694
# Val Loss: 0.9543, Val Acc: 0.6391
# Epoch 60/1000
# Train Loss: 0.8722, Train Acc: 0.6536
# Val Loss: 0.9477, Val Acc: 0.6437
# Epoch 65/1000
# Train Loss: 0.8450, Train Acc: 0.6750
# Val Loss: 0.9409, Val Acc: 0.6414
# Epoch 70/1000
# Train Loss: 0.8246, Train Acc: 0.6823
# Val Loss: 0.9366, Val Acc: 0.6437
# Epoch 75/1000
# Train Loss: 0.8316, Train Acc: 0.6812
# Val Loss: 0.9335, Val Acc: 0.6483
# Epoch 80/1000
# Train Loss: 0.8122, Train Acc: 0.6766
# Val Loss: 0.9286, Val Acc: 0.6437
# Epoch 85/1000
# Train Loss: 0.7926, Train Acc: 0.6838
# Val Loss: 0.9267, Val Acc: 0.6368
# Epoch 90/1000
# Train Loss: 0.7941, Train Acc: 0.6825
# Val Loss: 0.9237, Val Acc: 0.6414
# Epoch 95/1000
# Train Loss: 0.7810, Train Acc: 0.6857
# Val Loss: 0.9231, Val Acc: 0.6299
# Epoch 100/1000
# Train Loss: 0.7649, Train Acc: 0.6954
# Val Loss: 0.9217, Val Acc: 0.6345
# Epoch 105/1000
# Train Loss: 0.7651, Train Acc: 0.6993
# Val Loss: 0.9202, Val Acc: 0.6414
# Epoch 110/1000
# Train Loss: 0.7765, Train Acc: 0.6926
# Val Loss: 0.9191, Val Acc: 0.6368
# Epoch 115/1000
# Train Loss: 0.7497, Train Acc: 0.6970
# Val Loss: 0.9188, Val Acc: 0.6391
# Epoch 120/1000
# Train Loss: 0.7285, Train Acc: 0.7170
# Val Loss: 0.9199, Val Acc: 0.6391
# Epoch 125/1000
# Train Loss: 0.7319, Train Acc: 0.7042
# Val Loss: 0.9206, Val Acc: 0.6437
# Epoch 130/1000
# Train Loss: 0.7205, Train Acc: 0.7114
# Val Loss: 0.9195, Val Acc: 0.6391
# Epoch 135/1000
# Train Loss: 0.7202, Train Acc: 0.7002
# Val Loss: 0.9196, Val Acc: 0.6414
# Epoch 140/1000
# Train Loss: 0.7181, Train Acc: 0.7074
# Val Loss: 0.9221, Val Acc: 0.6391
# Epoch 145/1000
# Train Loss: 0.7056, Train Acc: 0.7048
# Val Loss: 0.9222, Val Acc: 0.6345
# Epoch 150/1000
# Train Loss: 0.7119, Train Acc: 0.7099
# Val Loss: 0.9201, Val Acc: 0.6414
# Epoch 155/1000
# Train Loss: 0.6890, Train Acc: 0.7239
# Val Loss: 0.9205, Val Acc: 0.6368
# Epoch 160/1000
# Train Loss: 0.6899, Train Acc: 0.7231
# Val Loss: 0.9213, Val Acc: 0.6368
#
# Early stopping triggered at epoch 161
# No improvement in validation accuracy for 100 epochs
#
# Fold 3 Best Results:
# Best Epoch: 60
# Best Validation Accuracy: 0.6483
#
# Fold 4/6
# Epoch 5/1000
# Train Loss: 2.0520, Train Acc: 0.3457
# Val Loss: 1.9362, Val Acc: 0.3779
# Epoch 10/1000
# Train Loss: 1.7204, Train Acc: 0.4453
# Val Loss: 1.6418, Val Acc: 0.4862
# Epoch 15/1000
# Train Loss: 1.5166, Train Acc: 0.5180
# Val Loss: 1.4590, Val Acc: 0.5576
# Epoch 20/1000
# Train Loss: 1.3637, Train Acc: 0.5559
# Val Loss: 1.3197, Val Acc: 0.6083
# Epoch 25/1000
# Train Loss: 1.2425, Train Acc: 0.5959
# Val Loss: 1.2192, Val Acc: 0.6290
# Epoch 30/1000
# Train Loss: 1.1619, Train Acc: 0.6062
# Val Loss: 1.1477, Val Acc: 0.6382
# Epoch 35/1000
# Train Loss: 1.0935, Train Acc: 0.6157
# Val Loss: 1.0953, Val Acc: 0.6498
# Epoch 40/1000
# Train Loss: 1.0369, Train Acc: 0.6378
# Val Loss: 1.0564, Val Acc: 0.6544
# Epoch 45/1000
# Train Loss: 1.0023, Train Acc: 0.6388
# Val Loss: 1.0266, Val Acc: 0.6567
# Epoch 50/1000
# Train Loss: 0.9483, Train Acc: 0.6449
# Val Loss: 1.0028, Val Acc: 0.6498
# Epoch 55/1000
# Train Loss: 0.9532, Train Acc: 0.6448
# Val Loss: 0.9843, Val Acc: 0.6498
# Epoch 60/1000
# Train Loss: 0.9218, Train Acc: 0.6548
# Val Loss: 0.9684, Val Acc: 0.6475
# Epoch 65/1000
# Train Loss: 0.9121, Train Acc: 0.6612
# Val Loss: 0.9557, Val Acc: 0.6544
# Epoch 70/1000
# Train Loss: 0.8792, Train Acc: 0.6631
# Val Loss: 0.9453, Val Acc: 0.6498
# Epoch 75/1000
# Train Loss: 0.8672, Train Acc: 0.6714
# Val Loss: 0.9382, Val Acc: 0.6613
# Epoch 80/1000
# Train Loss: 0.8449, Train Acc: 0.6785
# Val Loss: 0.9280, Val Acc: 0.6521
# Epoch 85/1000
# Train Loss: 0.8303, Train Acc: 0.6782
# Val Loss: 0.9214, Val Acc: 0.6567
# Epoch 90/1000
# Train Loss: 0.8293, Train Acc: 0.6764
# Val Loss: 0.9158, Val Acc: 0.6613
# Epoch 95/1000
# Train Loss: 0.7931, Train Acc: 0.6920
# Val Loss: 0.9098, Val Acc: 0.6636
# Epoch 100/1000
# Train Loss: 0.8154, Train Acc: 0.6780
# Val Loss: 0.9051, Val Acc: 0.6659
# Epoch 105/1000
# Train Loss: 0.7984, Train Acc: 0.6746
# Val Loss: 0.9030, Val Acc: 0.6636
# Epoch 110/1000
# Train Loss: 0.7909, Train Acc: 0.6968
# Val Loss: 0.8990, Val Acc: 0.6636
# Epoch 115/1000
# Train Loss: 0.7792, Train Acc: 0.7010
# Val Loss: 0.8960, Val Acc: 0.6590
# Epoch 120/1000
# Train Loss: 0.7642, Train Acc: 0.6949
# Val Loss: 0.8934, Val Acc: 0.6613
# Epoch 125/1000
# Train Loss: 0.7641, Train Acc: 0.6985
# Val Loss: 0.8913, Val Acc: 0.6636
# Epoch 130/1000
# Train Loss: 0.7583, Train Acc: 0.6996
# Val Loss: 0.8875, Val Acc: 0.6544
# Epoch 135/1000
# Train Loss: 0.7469, Train Acc: 0.7152
# Val Loss: 0.8874, Val Acc: 0.6636
# Epoch 140/1000
# Train Loss: 0.7502, Train Acc: 0.7136
# Val Loss: 0.8856, Val Acc: 0.6659
# Epoch 145/1000
# Train Loss: 0.7426, Train Acc: 0.7107
# Val Loss: 0.8842, Val Acc: 0.6590
# Epoch 150/1000
# Train Loss: 0.7368, Train Acc: 0.7033
# Val Loss: 0.8812, Val Acc: 0.6636
# Epoch 155/1000
# Train Loss: 0.7256, Train Acc: 0.7137
# Val Loss: 0.8805, Val Acc: 0.6613
# Epoch 160/1000
# Train Loss: 0.7150, Train Acc: 0.7244
# Val Loss: 0.8791, Val Acc: 0.6590
# Epoch 165/1000
# Train Loss: 0.7173, Train Acc: 0.7079
# Val Loss: 0.8798, Val Acc: 0.6613
# Epoch 170/1000
# Train Loss: 0.6998, Train Acc: 0.7234
# Val Loss: 0.8800, Val Acc: 0.6544
# Epoch 175/1000
# Train Loss: 0.7078, Train Acc: 0.7168
# Val Loss: 0.8787, Val Acc: 0.6636
# Epoch 180/1000
# Train Loss: 0.7002, Train Acc: 0.7088
# Val Loss: 0.8797, Val Acc: 0.6613
# Epoch 185/1000
# Train Loss: 0.6855, Train Acc: 0.7319
# Val Loss: 0.8806, Val Acc: 0.6613
# Epoch 190/1000
# Train Loss: 0.6822, Train Acc: 0.7268
# Val Loss: 0.8785, Val Acc: 0.6590
#
# Early stopping triggered at epoch 194
# No improvement in validation accuracy for 100 epochs
#
# Fold 4 Best Results:
# Best Epoch: 93
# Best Validation Accuracy: 0.6682
#
# Fold 5/6
# Epoch 5/1000
# Train Loss: 1.8806, Train Acc: 0.4156
# Val Loss: 1.7096, Val Acc: 0.4862
# Epoch 10/1000
# Train Loss: 1.5501, Train Acc: 0.4986
# Val Loss: 1.4261, Val Acc: 0.5783
# Epoch 15/1000
# Train Loss: 1.3491, Train Acc: 0.5717
# Val Loss: 1.2721, Val Acc: 0.6152
# Epoch 20/1000
# Train Loss: 1.2438, Train Acc: 0.5782
# Val Loss: 1.1707, Val Acc: 0.6313
# Epoch 25/1000
# Train Loss: 1.1447, Train Acc: 0.6100
# Val Loss: 1.1018, Val Acc: 0.6267
# Epoch 30/1000
# Train Loss: 1.0720, Train Acc: 0.6405
# Val Loss: 1.0526, Val Acc: 0.6336
# Epoch 35/1000
# Train Loss: 1.0385, Train Acc: 0.6334
# Val Loss: 1.0152, Val Acc: 0.6406
# Epoch 40/1000
# Train Loss: 0.9998, Train Acc: 0.6379
# Val Loss: 0.9872, Val Acc: 0.6475
# Epoch 45/1000
# Train Loss: 0.9652, Train Acc: 0.6492
# Val Loss: 0.9654, Val Acc: 0.6429
# Epoch 50/1000
# Train Loss: 0.9339, Train Acc: 0.6583
# Val Loss: 0.9479, Val Acc: 0.6521
# Epoch 55/1000
# Train Loss: 0.9268, Train Acc: 0.6550
# Val Loss: 0.9322, Val Acc: 0.6475
# Epoch 60/1000
# Train Loss: 0.8998, Train Acc: 0.6571
# Val Loss: 0.9231, Val Acc: 0.6475
# Epoch 65/1000
# Train Loss: 0.8994, Train Acc: 0.6653
# Val Loss: 0.9139, Val Acc: 0.6567
# Epoch 70/1000
# Train Loss: 0.8673, Train Acc: 0.6722
# Val Loss: 0.9057, Val Acc: 0.6567
# Epoch 75/1000
# Train Loss: 0.8578, Train Acc: 0.6754
# Val Loss: 0.8970, Val Acc: 0.6705
# Epoch 80/1000
# Train Loss: 0.8471, Train Acc: 0.6681
# Val Loss: 0.8930, Val Acc: 0.6659
# Epoch 85/1000
# Train Loss: 0.8334, Train Acc: 0.6834
# Val Loss: 0.8864, Val Acc: 0.6682
# Epoch 90/1000
# Train Loss: 0.8165, Train Acc: 0.6861
# Val Loss: 0.8817, Val Acc: 0.6682
# Epoch 95/1000
# Train Loss: 0.7730, Train Acc: 0.6928
# Val Loss: 0.8790, Val Acc: 0.6636
# Epoch 100/1000
# Train Loss: 0.7971, Train Acc: 0.6805
# Val Loss: 0.8756, Val Acc: 0.6659
# Epoch 105/1000
# Train Loss: 0.7904, Train Acc: 0.6988
# Val Loss: 0.8725, Val Acc: 0.6659
# Epoch 110/1000
# Train Loss: 0.7854, Train Acc: 0.6894
# Val Loss: 0.8723, Val Acc: 0.6636
# Epoch 115/1000
# Train Loss: 0.7786, Train Acc: 0.6980
# Val Loss: 0.8696, Val Acc: 0.6682
# Epoch 120/1000
# Train Loss: 0.7706, Train Acc: 0.7023
# Val Loss: 0.8693, Val Acc: 0.6659
# Epoch 125/1000
# Train Loss: 0.7524, Train Acc: 0.7037
# Val Loss: 0.8665, Val Acc: 0.6682
# Epoch 130/1000
# Train Loss: 0.7614, Train Acc: 0.7038
# Val Loss: 0.8657, Val Acc: 0.6728
# Epoch 135/1000
# Train Loss: 0.7418, Train Acc: 0.7184
# Val Loss: 0.8629, Val Acc: 0.6682
# Epoch 140/1000
# Train Loss: 0.7492, Train Acc: 0.7124
# Val Loss: 0.8628, Val Acc: 0.6659
# Epoch 145/1000
# Train Loss: 0.7462, Train Acc: 0.6999
# Val Loss: 0.8626, Val Acc: 0.6590
# Epoch 150/1000
# Train Loss: 0.7372, Train Acc: 0.7123
# Val Loss: 0.8623, Val Acc: 0.6613
# Epoch 155/1000
# Train Loss: 0.7188, Train Acc: 0.7212
# Val Loss: 0.8635, Val Acc: 0.6682
# Epoch 160/1000
# Train Loss: 0.7174, Train Acc: 0.7078
# Val Loss: 0.8633, Val Acc: 0.6636
# Epoch 165/1000
# Train Loss: 0.7152, Train Acc: 0.7155
# Val Loss: 0.8620, Val Acc: 0.6705
# Epoch 170/1000
# Train Loss: 0.7057, Train Acc: 0.7218
# Val Loss: 0.8622, Val Acc: 0.6590
# Epoch 175/1000
# Train Loss: 0.6998, Train Acc: 0.7220
# Val Loss: 0.8631, Val Acc: 0.6636
# Epoch 180/1000
# Train Loss: 0.7009, Train Acc: 0.7173
# Val Loss: 0.8606, Val Acc: 0.6590
#
# Early stopping triggered at epoch 182
# No improvement in validation accuracy for 100 epochs
#
# Fold 5 Best Results:
# Best Epoch: 81
# Best Validation Accuracy: 0.6728
#
# Fold 6/6
# Epoch 5/1000
# Train Loss: 1.9136, Train Acc: 0.3828
# Val Loss: 1.8081, Val Acc: 0.4240
# Epoch 10/1000
# Train Loss: 1.5687, Train Acc: 0.4952
# Val Loss: 1.4948, Val Acc: 0.5276
# Epoch 15/1000
# Train Loss: 1.3779, Train Acc: 0.5537
# Val Loss: 1.3175, Val Acc: 0.5760
# Epoch 20/1000
# Train Loss: 1.2445, Train Acc: 0.5860
# Val Loss: 1.2020, Val Acc: 0.6060
# Epoch 25/1000
# Train Loss: 1.1693, Train Acc: 0.6072
# Val Loss: 1.1226, Val Acc: 0.6267
# Epoch 30/1000
# Train Loss: 1.0869, Train Acc: 0.6282
# Val Loss: 1.0694, Val Acc: 0.6313
# Epoch 35/1000
# Train Loss: 1.0587, Train Acc: 0.6283
# Val Loss: 1.0295, Val Acc: 0.6406
# Epoch 40/1000
# Train Loss: 1.0092, Train Acc: 0.6514
# Val Loss: 0.9999, Val Acc: 0.6498
# Epoch 45/1000
# Train Loss: 0.9861, Train Acc: 0.6434
# Val Loss: 0.9754, Val Acc: 0.6521
# Epoch 50/1000
# Train Loss: 0.9584, Train Acc: 0.6507
# Val Loss: 0.9547, Val Acc: 0.6567
# Epoch 55/1000
# Train Loss: 0.9232, Train Acc: 0.6676
# Val Loss: 0.9406, Val Acc: 0.6544
# Epoch 60/1000
# Train Loss: 0.9142, Train Acc: 0.6559
# Val Loss: 0.9294, Val Acc: 0.6590
# Epoch 65/1000
# Train Loss: 0.8854, Train Acc: 0.6661
# Val Loss: 0.9188, Val Acc: 0.6590
# Epoch 70/1000
# Train Loss: 0.8867, Train Acc: 0.6651
# Val Loss: 0.9099, Val Acc: 0.6567
# Epoch 75/1000
# Train Loss: 0.8670, Train Acc: 0.6737
# Val Loss: 0.9015, Val Acc: 0.6567
# Epoch 80/1000
# Train Loss: 0.8622, Train Acc: 0.6745
# Val Loss: 0.8947, Val Acc: 0.6613
# Epoch 85/1000
# Train Loss: 0.8396, Train Acc: 0.6779
# Val Loss: 0.8885, Val Acc: 0.6613
# Epoch 90/1000
# Train Loss: 0.8116, Train Acc: 0.6852
# Val Loss: 0.8855, Val Acc: 0.6544
# Epoch 95/1000
# Train Loss: 0.8153, Train Acc: 0.6921
# Val Loss: 0.8807, Val Acc: 0.6567
# Epoch 100/1000
# Train Loss: 0.7964, Train Acc: 0.6858
# Val Loss: 0.8779, Val Acc: 0.6567
# Epoch 105/1000
# Train Loss: 0.7862, Train Acc: 0.6954
# Val Loss: 0.8740, Val Acc: 0.6544
# Epoch 110/1000
# Train Loss: 0.7916, Train Acc: 0.6902
# Val Loss: 0.8753, Val Acc: 0.6636
# Epoch 115/1000
# Train Loss: 0.7760, Train Acc: 0.6907
# Val Loss: 0.8744, Val Acc: 0.6659
# Epoch 120/1000
# Train Loss: 0.7792, Train Acc: 0.6935
# Val Loss: 0.8700, Val Acc: 0.6636
# Epoch 125/1000
# Train Loss: 0.7794, Train Acc: 0.6906
# Val Loss: 0.8660, Val Acc: 0.6636
# Epoch 130/1000
# Train Loss: 0.7546, Train Acc: 0.6995
# Val Loss: 0.8642, Val Acc: 0.6659
# Epoch 135/1000
# Train Loss: 0.7620, Train Acc: 0.7046
# Val Loss: 0.8657, Val Acc: 0.6705
# Epoch 140/1000
# Train Loss: 0.7569, Train Acc: 0.6973
# Val Loss: 0.8625, Val Acc: 0.6659
# Epoch 145/1000
# Train Loss: 0.7486, Train Acc: 0.6885
# Val Loss: 0.8625, Val Acc: 0.6636
# Epoch 150/1000
# Train Loss: 0.7353, Train Acc: 0.7031
# Val Loss: 0.8629, Val Acc: 0.6705
# Epoch 155/1000
# Train Loss: 0.7412, Train Acc: 0.7118
# Val Loss: 0.8597, Val Acc: 0.6728
# Epoch 160/1000
# Train Loss: 0.7237, Train Acc: 0.7185
# Val Loss: 0.8604, Val Acc: 0.6613
# Epoch 165/1000
# Train Loss: 0.7223, Train Acc: 0.7220
# Val Loss: 0.8623, Val Acc: 0.6636
# Epoch 170/1000
# Train Loss: 0.7195, Train Acc: 0.7175
# Val Loss: 0.8618, Val Acc: 0.6636
# Epoch 175/1000
# Train Loss: 0.6989, Train Acc: 0.7194
# Val Loss: 0.8640, Val Acc: 0.6705
# Epoch 180/1000
# Train Loss: 0.7035, Train Acc: 0.7118
# Val Loss: 0.8620, Val Acc: 0.6659
# Epoch 185/1000
# Train Loss: 0.7063, Train Acc: 0.7232
# Val Loss: 0.8615, Val Acc: 0.6705
# Epoch 190/1000
# Train Loss: 0.6956, Train Acc: 0.7224
# Val Loss: 0.8605, Val Acc: 0.6590
# Epoch 195/1000
# Train Loss: 0.6870, Train Acc: 0.7260
# Val Loss: 0.8622, Val Acc: 0.6636
# Epoch 200/1000
# Train Loss: 0.6950, Train Acc: 0.7249
# Val Loss: 0.8610, Val Acc: 0.6728
# Epoch 205/1000
# Train Loss: 0.6816, Train Acc: 0.7350
# Val Loss: 0.8636, Val Acc: 0.6705
# Epoch 210/1000
# Train Loss: 0.6755, Train Acc: 0.7268
# Val Loss: 0.8637, Val Acc: 0.6613
# Epoch 215/1000
# Train Loss: 0.6770, Train Acc: 0.7308
# Val Loss: 0.8659, Val Acc: 0.6751
# Epoch 220/1000
# Train Loss: 0.6839, Train Acc: 0.7295
# Val Loss: 0.8652, Val Acc: 0.6728
# Epoch 225/1000
# Train Loss: 0.6790, Train Acc: 0.7266
# Val Loss: 0.8661, Val Acc: 0.6705
# Epoch 230/1000
# Train Loss: 0.6694, Train Acc: 0.7291
# Val Loss: 0.8640, Val Acc: 0.6613
# Epoch 235/1000
# Train Loss: 0.6662, Train Acc: 0.7400
# Val Loss: 0.8655, Val Acc: 0.6636
# Epoch 240/1000
# Train Loss: 0.6682, Train Acc: 0.7284
# Val Loss: 0.8671, Val Acc: 0.6636
# Epoch 245/1000
# Train Loss: 0.6542, Train Acc: 0.7409
# Val Loss: 0.8685, Val Acc: 0.6544
# Epoch 250/1000
# Train Loss: 0.6526, Train Acc: 0.7274
# Val Loss: 0.8755, Val Acc: 0.6659
# Epoch 255/1000
# Train Loss: 0.6476, Train Acc: 0.7350
# Val Loss: 0.8745, Val Acc: 0.6728
#
# Early stopping triggered at epoch 256
# No improvement in validation accuracy for 100 epochs
#
# Fold 6 Best Results:
# Best Epoch: 155
# Best Validation Accuracy: 0.6774
#
# Overall Cross-validation results:
# Mean validation accuracy: 0.6655
# Standard deviation: 0.0118
#
# Best model from fold 6 at epoch 155
# Best validation accuracy: 0.6774

# %%
results = evaluate_test_results(test_df, best_model)
# Out:
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\mihai\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# === Model Evaluation on Test Data ===
#
# Overall Test Accuracy: 0.6241
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#            Bengal       0.57      0.87      0.69        23
#            Birman       0.39      0.39      0.39        18
# British Shorthair       0.00      0.00      0.00        16
#         Chartreux       0.00      0.00      0.00         3
#          European       0.59      0.86      0.70        97
#        Maine coon       0.90      1.00      0.95        19
#          No breed       0.81      0.28      0.42        46
#             Other       0.00      0.00      0.00        13
#           Persian       1.00      1.00      1.00        18
#           Ragdoll       0.54      0.65      0.59        20
#          Savannah       0.00      0.00      0.00         2
#           Siamese       1.00      0.20      0.33         5
#            Sphynx       1.00      1.00      1.00         7
#    Turkish angora       0.00      0.00      0.00         3
#
#          accuracy                           0.62       290
#         macro avg       0.49      0.45      0.43       290
#      weighted avg       0.60      0.62      0.57       290
#
#
# Per-Class Metrics:
#
# Bengal:
#   precision: 0.5714
#   recall: 0.8696
#   f1_score: 0.6897
#
# Birman:
#   precision: 0.3889
#   recall: 0.3889
#   f1_score: 0.3889
#
# British Shorthair:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Chartreux:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# European:
#   precision: 0.5929
#   recall: 0.8557
#   f1_score: 0.7004
#
# Maine coon:
#   precision: 0.9048
#   recall: 1.0000
#   f1_score: 0.9500
#
# No breed:
#   precision: 0.8125
#   recall: 0.2826
#   f1_score: 0.4194
#
# Other:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Persian:
#   precision: 1.0000
#   recall: 1.0000
#   f1_score: 1.0000
#
# Ragdoll:
#   precision: 0.5417
#   recall: 0.6500
#   f1_score: 0.5909
#
# Savannah:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000
#
# Siamese:
#   precision: 1.0000
#   recall: 0.2000
#   f1_score: 0.3333
#
# Sphynx:
#   precision: 1.0000
#   recall: 1.0000
#   f1_score: 1.0000
#
# Turkish angora:
#   precision: 0.0000
#   recall: 0.0000
#   f1_score: 0.0000

# %% [markdown]
# > Training a model using a dataset wich is balanced using SMOTE

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from collections import Counter

def balance_dataset_smote(df, race_counts_dict):
    """
    Balance the dataset using SMOTE according to custom counts for each race.
    
    Parameters:
    df (pandas.DataFrame): Input DataFrame
    race_counts_dict (dict): Dictionary with races as keys and desired counts as values
                            Example: {'European': 500, 'Sphynx': 100, ...}
    
    Returns:
    pandas.DataFrame: Balanced dataset with specified counts for each race
    """
    # Get all race columns
    race_columns = [col for col in df.columns if col.startswith('Race_')]
    
    # Create feature matrix X (excluding race columns)
    feature_columns = [col for col in df.columns if not col.startswith('Race_')]
    X = df[feature_columns]
    
    # Process each race separately
    balanced_dfs = []
    
    for race in race_counts_dict.keys():
        race_col = f'Race_{race}'
        
        if race_col not in df.columns:
            print(f"Warning: {race} not found in dataset. Skipping...")
            continue
            
        # Create binary classification problem for current race
        y = df[race_col].astype(int)
        
        # Calculate sampling strategy
        current_counts = Counter(y)
        desired_count = race_counts_dict[race]
        
        # Only apply SMOTE if we need more samples and have at least one positive sample
        if desired_count > current_counts[1] and current_counts[1] > 0:
            # Calculate ratio to achieve desired count
            sampling_strategy = {1: desired_count}
            
            try:
                # Apply SMOTE
                smote = SMOTE(sampling_strategy=sampling_strategy, random_state=42)
                X_resampled, y_resampled = smote.fit_resample(X, y)
                
                # Create temporary DataFrame with features
                temp_df = pd.DataFrame(X_resampled, columns=feature_columns)
                
                # Add race columns (all False by default)
                for rc in race_columns:
                    temp_df[rc] = False
                
                # Set current race to True where y_resampled is 1
                temp_df[race_col] = y_resampled == 1
                
                # Only keep positive samples
                temp_df = temp_df[temp_df[race_col]]
                
            except ValueError as e:
                print(f"Warning: SMOTE failed for {race}, using random oversampling instead")
                # Fallback to random oversampling
                temp_df = df[df[race_col]].sample(n=desired_count, replace=True, random_state=42)
                
        else:
            # If we want fewer samples, randomly select without replacement
            n_samples = min(desired_count, current_counts[1])
            temp_df = df[df[race_col]].sample(n=n_samples, random_state=42)
        
        balanced_dfs.append(temp_df)
    
    # Combine all balanced samples
    balanced_df = pd.concat(balanced_dfs, ignore_index=True)
    
    # Print summary of new race distribution
    print("\nNew race distribution:")
    for race in race_counts_dict.keys():
        race_col = f'Race_{race}'
        if race_col in balanced_df.columns:
            count = balanced_df[race_col].sum()
            print(f"{race}: {int(count)}")
    
    return balanced_df

# Example usage:
# Define your desired counts for each race
desired_counts = {
    'European': 800,
    'No breed': 600,
    'Bengal': 500,
    'Ragdoll': 400,
    'Maine coon': 350,
    'Birman': 300,
    'Persian': 300,
    'British Shorthair': 300,
    'Other': 300,
    'Sphynx': 150,
    'Siamese': 100,
    'Chartreux': 60,
    'Turkish angora': 60,
    'Savannah': 50
}

# Balance the dataset
df = balance_dataset_smote(df, desired_counts)
# Out:
# New race distribution:
# European: 800
# No breed: 600
# Bengal: 500
# Ragdoll: 400
# Maine coon: 350
# Birman: 300
# Persian: 300
# British Shorthair: 300
# Other: 300
# Sphynx: 150
# Siamese: 100
# Chartreux: 60
# Turkish angora: 60
# Savannah: 50

# %%
# Split the dataset
train_df, test_df = split_cat_dataset(df, test_size=0.1, random_state=42)
# Out:
# Training set size: 3843 (90.0%)
# Test set size: 427 (10.0%)
#
# Race distribution in original dataset:
# European             0.187354
# No breed             0.140515
# Bengal               0.117096
# Ragdoll              0.093677
# Maine coon           0.081967
# Birman               0.070258
# Persian              0.070258
# British Shorthair    0.070258
# Other                0.070258
# Sphynx               0.035129
# Siamese              0.023419
# Chartreux            0.014052
# Turkish angora       0.014052
# Savannah             0.011710
# Name: proportion, dtype: float64
#
# Race distribution in training set:
# European             0.187354
# No breed             0.140515
# Bengal               0.117096
# Ragdoll              0.093677
# Maine coon           0.081967
# British Shorthair    0.070258
# Other                0.070258
# Birman               0.070258
# Persian              0.070258
# Sphynx               0.035129
# Siamese              0.023419
# Turkish angora       0.014052
# Chartreux            0.014052
# Savannah             0.011710
# Name: proportion, dtype: float64
#
# Race distribution in test set:
# European             0.187354
# No breed             0.140515
# Bengal               0.117096
# Ragdoll              0.093677
# Maine coon           0.081967
# Other                0.070258
# British Shorthair    0.070258
# Persian              0.070258
# Birman               0.070258
# Sphynx               0.035129
# Siamese              0.023419
# Turkish angora       0.014052
# Chartreux            0.014052
# Savannah             0.011710
# Name: proportion, dtype: float64

# %%
# Train the model
best_model, accuracies, histories = main(train_df)
# Out:
# Fold 1/6
# Epoch 5/1000
# Train Loss: 1.8978, Train Acc: 0.3948
# Val Loss: 1.7798, Val Acc: 0.4477
# Epoch 10/1000
# Train Loss: 1.4454, Train Acc: 0.5365
# Val Loss: 1.3582, Val Acc: 0.5663
# Epoch 15/1000
# Train Loss: 1.2295, Train Acc: 0.5777
# Val Loss: 1.1465, Val Acc: 0.5959
# Epoch 20/1000
# Train Loss: 1.0614, Train Acc: 0.6151
# Val Loss: 1.0304, Val Acc: 0.6053
# Epoch 25/1000
# Train Loss: 0.9737, Train Acc: 0.6420
# Val Loss: 0.9491, Val Acc: 0.6349
# Epoch 30/1000
# Train Loss: 0.9459, Train Acc: 0.6544
# Val Loss: 0.8967, Val Acc: 0.6412
# Epoch 35/1000
# Train Loss: 0.8815, Train Acc: 0.6736
# Val Loss: 0.8580, Val Acc: 0.6599
# Epoch 40/1000
# Train Loss: 0.8299, Train Acc: 0.6838
# Val Loss: 0.8276, Val Acc: 0.6755
# Epoch 45/1000
# Train Loss: 0.8120, Train Acc: 0.6906
# Val Loss: 0.8061, Val Acc: 0.6911
# Epoch 50/1000
# Train Loss: 0.7918, Train Acc: 0.6986
# Val Loss: 0.7900, Val Acc: 0.6864
# Epoch 55/1000
# Train Loss: 0.7682, Train Acc: 0.7079
# Val Loss: 0.7757, Val Acc: 0.6942
# Epoch 60/1000
# Train Loss: 0.7618, Train Acc: 0.7014
# Val Loss: 0.7623, Val Acc: 0.6989
# Epoch 65/1000
# Train Loss: 0.7226, Train Acc: 0.7188
# Val Loss: 0.7532, Val Acc: 0.6927
# Epoch 70/1000
# Train Loss: 0.7168, Train Acc: 0.7246
# Val Loss: 0.7444, Val Acc: 0.7129
# Epoch 75/1000
# Train Loss: 0.7183, Train Acc: 0.7188
# Val Loss: 0.7369, Val Acc: 0.7176
# Epoch 80/1000
# Train Loss: 0.6982, Train Acc: 0.7246
# Val Loss: 0.7317, Val Acc: 0.7051
# Epoch 85/1000
# Train Loss: 0.6855, Train Acc: 0.7314
# Val Loss: 0.7272, Val Acc: 0.7114
# Epoch 90/1000
# Train Loss: 0.6700, Train Acc: 0.7339
# Val Loss: 0.7224, Val Acc: 0.7192
# Epoch 95/1000
# Train Loss: 0.6798, Train Acc: 0.7355
# Val Loss: 0.7173, Val Acc: 0.7114
# Epoch 100/1000
# Train Loss: 0.6607, Train Acc: 0.7348
# Val Loss: 0.7147, Val Acc: 0.7161
# Epoch 105/1000
# Train Loss: 0.6424, Train Acc: 0.7432
# Val Loss: 0.7085, Val Acc: 0.7161
# Epoch 110/1000
# Train Loss: 0.6530, Train Acc: 0.7361
# Val Loss: 0.7078, Val Acc: 0.7129
# Epoch 115/1000
# Train Loss: 0.6307, Train Acc: 0.7494
# Val Loss: 0.7054, Val Acc: 0.7207
# Epoch 120/1000
# Train Loss: 0.6484, Train Acc: 0.7432
# Val Loss: 0.7008, Val Acc: 0.7161
# Epoch 125/1000
# Train Loss: 0.6306, Train Acc: 0.7568
# Val Loss: 0.7001, Val Acc: 0.7207
# Epoch 130/1000
# Train Loss: 0.6077, Train Acc: 0.7602
# Val Loss: 0.6969, Val Acc: 0.7207
# Epoch 135/1000
# Train Loss: 0.5992, Train Acc: 0.7602
# Val Loss: 0.6946, Val Acc: 0.7254
# Epoch 140/1000
# Train Loss: 0.5921, Train Acc: 0.7571
# Val Loss: 0.6930, Val Acc: 0.7223
# Epoch 145/1000
# Train Loss: 0.5955, Train Acc: 0.7587
# Val Loss: 0.6921, Val Acc: 0.7176
# Epoch 150/1000
# Train Loss: 0.5915, Train Acc: 0.7670
# Val Loss: 0.6908, Val Acc: 0.7176
# Epoch 155/1000
# Train Loss: 0.5883, Train Acc: 0.7676
# Val Loss: 0.6881, Val Acc: 0.7254
# Epoch 160/1000
# Train Loss: 0.5798, Train Acc: 0.7689
# Val Loss: 0.6865, Val Acc: 0.7223
# Epoch 165/1000
# Train Loss: 0.5678, Train Acc: 0.7744
# Val Loss: 0.6862, Val Acc: 0.7223
# Epoch 170/1000
# Train Loss: 0.5637, Train Acc: 0.7757
# Val Loss: 0.6861, Val Acc: 0.7301
# Epoch 175/1000
# Train Loss: 0.5602, Train Acc: 0.7837
# Val Loss: 0.6843, Val Acc: 0.7239
# Epoch 180/1000
# Train Loss: 0.5490, Train Acc: 0.7859
# Val Loss: 0.6845, Val Acc: 0.7317
# Epoch 185/1000
# Train Loss: 0.5530, Train Acc: 0.7769
# Val Loss: 0.6837, Val Acc: 0.7317
# Epoch 190/1000
# Train Loss: 0.5410, Train Acc: 0.7828
# Val Loss: 0.6838, Val Acc: 0.7332
# Epoch 195/1000
# Train Loss: 0.5398, Train Acc: 0.7890
# Val Loss: 0.6831, Val Acc: 0.7332
# Epoch 200/1000
# Train Loss: 0.5407, Train Acc: 0.7871
# Val Loss: 0.6811, Val Acc: 0.7363
# Epoch 205/1000
# Train Loss: 0.5258, Train Acc: 0.7915
# Val Loss: 0.6800, Val Acc: 0.7395
# Epoch 210/1000
# Train Loss: 0.5184, Train Acc: 0.7958
# Val Loss: 0.6797, Val Acc: 0.7395
# Epoch 215/1000
# Train Loss: 0.5373, Train Acc: 0.7871
# Val Loss: 0.6819, Val Acc: 0.7379
# Epoch 220/1000
# Train Loss: 0.5193, Train Acc: 0.7924
# Val Loss: 0.6787, Val Acc: 0.7426
# Epoch 225/1000
# Train Loss: 0.5200, Train Acc: 0.7936
# Val Loss: 0.6786, Val Acc: 0.7363
# Epoch 230/1000
# Train Loss: 0.5018, Train Acc: 0.8032
# Val Loss: 0.6771, Val Acc: 0.7379
# Epoch 235/1000
# Train Loss: 0.5256, Train Acc: 0.7831
# Val Loss: 0.6763, Val Acc: 0.7441
# Epoch 240/1000
# Train Loss: 0.5325, Train Acc: 0.7884
# Val Loss: 0.6748, Val Acc: 0.7426
# Epoch 245/1000
# Train Loss: 0.5029, Train Acc: 0.8075
# Val Loss: 0.6738, Val Acc: 0.7426
# Epoch 250/1000
# Train Loss: 0.4962, Train Acc: 0.8079
# Val Loss: 0.6752, Val Acc: 0.7441
# Epoch 255/1000
# Train Loss: 0.4913, Train Acc: 0.8004
# Val Loss: 0.6761, Val Acc: 0.7395
# Epoch 260/1000
# Train Loss: 0.4936, Train Acc: 0.8020
# Val Loss: 0.6757, Val Acc: 0.7410
# Epoch 265/1000
# Train Loss: 0.4835, Train Acc: 0.8140
# Val Loss: 0.6762, Val Acc: 0.7410
# Epoch 270/1000
# Train Loss: 0.4761, Train Acc: 0.8051
# Val Loss: 0.6759, Val Acc: 0.7410
# Epoch 275/1000
# Train Loss: 0.4929, Train Acc: 0.8041
# Val Loss: 0.6748, Val Acc: 0.7457
# Epoch 280/1000
# Train Loss: 0.4815, Train Acc: 0.8048
# Val Loss: 0.6760, Val Acc: 0.7410
# Epoch 285/1000
# Train Loss: 0.4803, Train Acc: 0.8038
# Val Loss: 0.6770, Val Acc: 0.7426
# Epoch 290/1000
# Train Loss: 0.4643, Train Acc: 0.8131
# Val Loss: 0.6758, Val Acc: 0.7457
# Epoch 295/1000
# Train Loss: 0.4657, Train Acc: 0.8162
# Val Loss: 0.6768, Val Acc: 0.7473
# Epoch 300/1000
# Train Loss: 0.4627, Train Acc: 0.8113
# Val Loss: 0.6761, Val Acc: 0.7457
# Epoch 305/1000
# Train Loss: 0.4795, Train Acc: 0.8057
# Val Loss: 0.6759, Val Acc: 0.7426
# Epoch 310/1000
# Train Loss: 0.4499, Train Acc: 0.8202
# Val Loss: 0.6752, Val Acc: 0.7488
# Epoch 315/1000
# Train Loss: 0.4475, Train Acc: 0.8233
# Val Loss: 0.6764, Val Acc: 0.7441
# Epoch 320/1000
# Train Loss: 0.4423, Train Acc: 0.8283
# Val Loss: 0.6756, Val Acc: 0.7488
# Epoch 325/1000
# Train Loss: 0.4483, Train Acc: 0.8218
# Val Loss: 0.6761, Val Acc: 0.7426
# Epoch 330/1000
# Train Loss: 0.4578, Train Acc: 0.8181
# Val Loss: 0.6750, Val Acc: 0.7410
# Epoch 335/1000
# Train Loss: 0.4344, Train Acc: 0.8357
# Val Loss: 0.6776, Val Acc: 0.7363
# Epoch 340/1000
# Train Loss: 0.4349, Train Acc: 0.8246
# Val Loss: 0.6768, Val Acc: 0.7441
# Epoch 345/1000
# Train Loss: 0.4312, Train Acc: 0.8342
# Val Loss: 0.6786, Val Acc: 0.7457
# Epoch 350/1000
# Train Loss: 0.4403, Train Acc: 0.8267
# Val Loss: 0.6778, Val Acc: 0.7426
# Epoch 355/1000
# Train Loss: 0.4269, Train Acc: 0.8357
# Val Loss: 0.6795, Val Acc: 0.7379
# Epoch 360/1000
# Train Loss: 0.4277, Train Acc: 0.8246
# Val Loss: 0.6841, Val Acc: 0.7410
# Epoch 365/1000
# Train Loss: 0.4243, Train Acc: 0.8388
# Val Loss: 0.6797, Val Acc: 0.7473
# Epoch 370/1000
# Train Loss: 0.4227, Train Acc: 0.8329
# Val Loss: 0.6804, Val Acc: 0.7426
# Epoch 375/1000
# Train Loss: 0.4265, Train Acc: 0.8354
# Val Loss: 0.6799, Val Acc: 0.7504
# Epoch 380/1000
# Train Loss: 0.4154, Train Acc: 0.8397
# Val Loss: 0.6826, Val Acc: 0.7441
# Epoch 385/1000
# Train Loss: 0.4227, Train Acc: 0.8391
# Val Loss: 0.6824, Val Acc: 0.7426
# Epoch 390/1000
# Train Loss: 0.4182, Train Acc: 0.8326
# Val Loss: 0.6801, Val Acc: 0.7441
# Epoch 395/1000
# Train Loss: 0.4091, Train Acc: 0.8345
# Val Loss: 0.6843, Val Acc: 0.7441
# Epoch 400/1000
# Train Loss: 0.4115, Train Acc: 0.8425
# Val Loss: 0.6849, Val Acc: 0.7457
#
# Early stopping triggered at epoch 403
# No improvement in validation accuracy for 100 epochs
#
# Fold 1 Best Results:
# Best Epoch: 302
# Best Validation Accuracy: 0.7504
#
# Fold 2/6
# Epoch 5/1000
# Train Loss: 1.8776, Train Acc: 0.3951
# Val Loss: 1.6788, Val Acc: 0.4977
# Epoch 10/1000
# Train Loss: 1.4355, Train Acc: 0.5319
# Val Loss: 1.2815, Val Acc: 0.6100
# Epoch 15/1000
# Train Loss: 1.2132, Train Acc: 0.5916
# Val Loss: 1.0813, Val Acc: 0.6583
# Epoch 20/1000
# Train Loss: 1.0714, Train Acc: 0.6300
# Val Loss: 0.9681, Val Acc: 0.6724
# Epoch 25/1000
# Train Loss: 1.0057, Train Acc: 0.6399
# Val Loss: 0.8993, Val Acc: 0.6849
# Epoch 30/1000
# Train Loss: 0.9181, Train Acc: 0.6637
# Val Loss: 0.8520, Val Acc: 0.6880
# Epoch 35/1000
# Train Loss: 0.8854, Train Acc: 0.6603
# Val Loss: 0.8198, Val Acc: 0.7036
# Epoch 40/1000
# Train Loss: 0.8650, Train Acc: 0.6686
# Val Loss: 0.7961, Val Acc: 0.7036
# Epoch 45/1000
# Train Loss: 0.8203, Train Acc: 0.6785
# Val Loss: 0.7769, Val Acc: 0.7114
# Epoch 50/1000
# Train Loss: 0.7878, Train Acc: 0.6962
# Val Loss: 0.7624, Val Acc: 0.7083
# Epoch 55/1000
# Train Loss: 0.7724, Train Acc: 0.7051
# Val Loss: 0.7527, Val Acc: 0.7083
# Epoch 60/1000
# Train Loss: 0.7428, Train Acc: 0.7064
# Val Loss: 0.7411, Val Acc: 0.7161
# Epoch 65/1000
# Train Loss: 0.7423, Train Acc: 0.7104
# Val Loss: 0.7337, Val Acc: 0.7161
# Epoch 70/1000
# Train Loss: 0.7242, Train Acc: 0.7234
# Val Loss: 0.7295, Val Acc: 0.7129
# Epoch 75/1000
# Train Loss: 0.7214, Train Acc: 0.7157
# Val Loss: 0.7232, Val Acc: 0.7161
# Epoch 80/1000
# Train Loss: 0.6965, Train Acc: 0.7277
# Val Loss: 0.7171, Val Acc: 0.7176
# Epoch 85/1000
# Train Loss: 0.6884, Train Acc: 0.7348
# Val Loss: 0.7160, Val Acc: 0.7161
# Epoch 90/1000
# Train Loss: 0.6735, Train Acc: 0.7358
# Val Loss: 0.7119, Val Acc: 0.7192
# Epoch 95/1000
# Train Loss: 0.6652, Train Acc: 0.7392
# Val Loss: 0.7084, Val Acc: 0.7161
# Epoch 100/1000
# Train Loss: 0.6491, Train Acc: 0.7506
# Val Loss: 0.7057, Val Acc: 0.7239
# Epoch 105/1000
# Train Loss: 0.6399, Train Acc: 0.7460
# Val Loss: 0.7052, Val Acc: 0.7192
# Epoch 110/1000
# Train Loss: 0.6413, Train Acc: 0.7494
# Val Loss: 0.7026, Val Acc: 0.7161
# Epoch 115/1000
# Train Loss: 0.6406, Train Acc: 0.7376
# Val Loss: 0.6995, Val Acc: 0.7192
# Epoch 120/1000
# Train Loss: 0.6272, Train Acc: 0.7463
# Val Loss: 0.6984, Val Acc: 0.7239
# Epoch 125/1000
# Train Loss: 0.6240, Train Acc: 0.7531
# Val Loss: 0.6981, Val Acc: 0.7254
# Epoch 130/1000
# Train Loss: 0.6215, Train Acc: 0.7587
# Val Loss: 0.6963, Val Acc: 0.7192
# Epoch 135/1000
# Train Loss: 0.6110, Train Acc: 0.7627
# Val Loss: 0.6961, Val Acc: 0.7192
# Epoch 140/1000
# Train Loss: 0.6058, Train Acc: 0.7512
# Val Loss: 0.6957, Val Acc: 0.7254
# Epoch 145/1000
# Train Loss: 0.5976, Train Acc: 0.7658
# Val Loss: 0.6924, Val Acc: 0.7192
# Epoch 150/1000
# Train Loss: 0.5919, Train Acc: 0.7608
# Val Loss: 0.6930, Val Acc: 0.7207
# Epoch 155/1000
# Train Loss: 0.5815, Train Acc: 0.7661
# Val Loss: 0.6928, Val Acc: 0.7176
# Epoch 160/1000
# Train Loss: 0.6039, Train Acc: 0.7611
# Val Loss: 0.6924, Val Acc: 0.7207
# Epoch 165/1000
# Train Loss: 0.5736, Train Acc: 0.7713
# Val Loss: 0.6915, Val Acc: 0.7223
# Epoch 170/1000
# Train Loss: 0.5742, Train Acc: 0.7729
# Val Loss: 0.6931, Val Acc: 0.7270
# Epoch 175/1000
# Train Loss: 0.5780, Train Acc: 0.7676
# Val Loss: 0.6918, Val Acc: 0.7223
# Epoch 180/1000
# Train Loss: 0.5483, Train Acc: 0.7828
# Val Loss: 0.6907, Val Acc: 0.7317
# Epoch 185/1000
# Train Loss: 0.5634, Train Acc: 0.7763
# Val Loss: 0.6925, Val Acc: 0.7207
# Epoch 190/1000
# Train Loss: 0.5671, Train Acc: 0.7751
# Val Loss: 0.6900, Val Acc: 0.7317
# Epoch 195/1000
# Train Loss: 0.5542, Train Acc: 0.7775
# Val Loss: 0.6912, Val Acc: 0.7285
# Epoch 200/1000
# Train Loss: 0.5469, Train Acc: 0.7843
# Val Loss: 0.6921, Val Acc: 0.7332
# Epoch 205/1000
# Train Loss: 0.5341, Train Acc: 0.7946
# Val Loss: 0.6936, Val Acc: 0.7317
# Epoch 210/1000
# Train Loss: 0.5260, Train Acc: 0.7908
# Val Loss: 0.6907, Val Acc: 0.7348
# Epoch 215/1000
# Train Loss: 0.5323, Train Acc: 0.7862
# Val Loss: 0.6921, Val Acc: 0.7379
# Epoch 220/1000
# Train Loss: 0.5241, Train Acc: 0.7946
# Val Loss: 0.6949, Val Acc: 0.7317
# Epoch 225/1000
# Train Loss: 0.5177, Train Acc: 0.7967
# Val Loss: 0.6940, Val Acc: 0.7301
# Epoch 230/1000
# Train Loss: 0.5220, Train Acc: 0.7958
# Val Loss: 0.6959, Val Acc: 0.7285
# Epoch 235/1000
# Train Loss: 0.5006, Train Acc: 0.8004
# Val Loss: 0.6937, Val Acc: 0.7317
# Epoch 240/1000
# Train Loss: 0.5178, Train Acc: 0.7955
# Val Loss: 0.6949, Val Acc: 0.7348
# Epoch 245/1000
# Train Loss: 0.5068, Train Acc: 0.8004
# Val Loss: 0.6937, Val Acc: 0.7301
# Epoch 250/1000
# Train Loss: 0.5019, Train Acc: 0.7958
# Val Loss: 0.6940, Val Acc: 0.7332
# Epoch 255/1000
# Train Loss: 0.5003, Train Acc: 0.8051
# Val Loss: 0.6945, Val Acc: 0.7285
# Epoch 260/1000
# Train Loss: 0.5018, Train Acc: 0.7986
# Val Loss: 0.6958, Val Acc: 0.7317
# Epoch 265/1000
# Train Loss: 0.4896, Train Acc: 0.8075
# Val Loss: 0.6938, Val Acc: 0.7223
# Epoch 270/1000
# Train Loss: 0.4832, Train Acc: 0.8122
# Val Loss: 0.6960, Val Acc: 0.7332
# Epoch 275/1000
# Train Loss: 0.4893, Train Acc: 0.8134
# Val Loss: 0.6968, Val Acc: 0.7317
# Epoch 280/1000
# Train Loss: 0.4891, Train Acc: 0.8060
# Val Loss: 0.6979, Val Acc: 0.7301
# Epoch 285/1000
# Train Loss: 0.4814, Train Acc: 0.8063
# Val Loss: 0.6983, Val Acc: 0.7301
# Epoch 290/1000
# Train Loss: 0.4801, Train Acc: 0.8196
# Val Loss: 0.6980, Val Acc: 0.7207
# Epoch 295/1000
# Train Loss: 0.4637, Train Acc: 0.8168
# Val Loss: 0.6997, Val Acc: 0.7332
# Epoch 300/1000
# Train Loss: 0.4720, Train Acc: 0.8079
# Val Loss: 0.6992, Val Acc: 0.7285
# Epoch 305/1000
# Train Loss: 0.4577, Train Acc: 0.8246
# Val Loss: 0.7017, Val Acc: 0.7223
# Epoch 310/1000
# Train Loss: 0.4531, Train Acc: 0.8255
# Val Loss: 0.7021, Val Acc: 0.7239
#
# Early stopping triggered at epoch 315
# No improvement in validation accuracy for 100 epochs
#
# Fold 2 Best Results:
# Best Epoch: 214
# Best Validation Accuracy: 0.7379
#
# Fold 3/6
# Epoch 5/1000
# Train Loss: 1.6882, Train Acc: 0.4579
# Val Loss: 1.5327, Val Acc: 0.5195
# Epoch 10/1000
# Train Loss: 1.3186, Train Acc: 0.5585
# Val Loss: 1.2155, Val Acc: 0.5835
# Epoch 15/1000
# Train Loss: 1.1391, Train Acc: 0.5975
# Val Loss: 1.0599, Val Acc: 0.5991
# Epoch 20/1000
# Train Loss: 1.0296, Train Acc: 0.6275
# Val Loss: 0.9675, Val Acc: 0.6225
# Epoch 25/1000
# Train Loss: 0.9456, Train Acc: 0.6556
# Val Loss: 0.9048, Val Acc: 0.6349
# Epoch 30/1000
# Train Loss: 0.9130, Train Acc: 0.6575
# Val Loss: 0.8617, Val Acc: 0.6474
# Epoch 35/1000
# Train Loss: 0.8569, Train Acc: 0.6696
# Val Loss: 0.8308, Val Acc: 0.6568
# Epoch 40/1000
# Train Loss: 0.8286, Train Acc: 0.6791
# Val Loss: 0.8094, Val Acc: 0.6693
# Epoch 45/1000
# Train Loss: 0.7915, Train Acc: 0.6934
# Val Loss: 0.7923, Val Acc: 0.6708
# Epoch 50/1000
# Train Loss: 0.7871, Train Acc: 0.7014
# Val Loss: 0.7776, Val Acc: 0.6817
# Epoch 55/1000
# Train Loss: 0.7768, Train Acc: 0.6949
# Val Loss: 0.7649, Val Acc: 0.6817
# Epoch 60/1000
# Train Loss: 0.7338, Train Acc: 0.7064
# Val Loss: 0.7561, Val Acc: 0.6817
# Epoch 65/1000
# Train Loss: 0.7300, Train Acc: 0.7104
# Val Loss: 0.7471, Val Acc: 0.6802
# Epoch 70/1000
# Train Loss: 0.7048, Train Acc: 0.7262
# Val Loss: 0.7406, Val Acc: 0.6942
# Epoch 75/1000
# Train Loss: 0.7149, Train Acc: 0.7160
# Val Loss: 0.7334, Val Acc: 0.6973
# Epoch 80/1000
# Train Loss: 0.6998, Train Acc: 0.7268
# Val Loss: 0.7298, Val Acc: 0.6911
# Epoch 85/1000
# Train Loss: 0.6764, Train Acc: 0.7317
# Val Loss: 0.7257, Val Acc: 0.6958
# Epoch 90/1000
# Train Loss: 0.6786, Train Acc: 0.7311
# Val Loss: 0.7218, Val Acc: 0.7020
# Epoch 95/1000
# Train Loss: 0.6611, Train Acc: 0.7274
# Val Loss: 0.7198, Val Acc: 0.7005
# Epoch 100/1000
# Train Loss: 0.6508, Train Acc: 0.7410
# Val Loss: 0.7155, Val Acc: 0.7098
# Epoch 105/1000
# Train Loss: 0.6461, Train Acc: 0.7410
# Val Loss: 0.7128, Val Acc: 0.7098
# Epoch 110/1000
# Train Loss: 0.6461, Train Acc: 0.7333
# Val Loss: 0.7106, Val Acc: 0.7145
# Epoch 115/1000
# Train Loss: 0.6229, Train Acc: 0.7494
# Val Loss: 0.7080, Val Acc: 0.7129
# Epoch 120/1000
# Train Loss: 0.6156, Train Acc: 0.7485
# Val Loss: 0.7076, Val Acc: 0.7098
# Epoch 125/1000
# Train Loss: 0.6509, Train Acc: 0.7472
# Val Loss: 0.7061, Val Acc: 0.7161
# Epoch 130/1000
# Train Loss: 0.6088, Train Acc: 0.7686
# Val Loss: 0.7043, Val Acc: 0.7176
# Epoch 135/1000
# Train Loss: 0.6157, Train Acc: 0.7528
# Val Loss: 0.7021, Val Acc: 0.7207
# Epoch 140/1000
# Train Loss: 0.6132, Train Acc: 0.7528
# Val Loss: 0.7001, Val Acc: 0.7285
# Epoch 145/1000
# Train Loss: 0.6132, Train Acc: 0.7621
# Val Loss: 0.7010, Val Acc: 0.7098
# Epoch 150/1000
# Train Loss: 0.5871, Train Acc: 0.7630
# Val Loss: 0.6984, Val Acc: 0.7207
# Epoch 155/1000
# Train Loss: 0.5835, Train Acc: 0.7720
# Val Loss: 0.6980, Val Acc: 0.7161
# Epoch 160/1000
# Train Loss: 0.6062, Train Acc: 0.7605
# Val Loss: 0.6966, Val Acc: 0.7129
# Epoch 165/1000
# Train Loss: 0.5779, Train Acc: 0.7704
# Val Loss: 0.6962, Val Acc: 0.7239
# Epoch 170/1000
# Train Loss: 0.5728, Train Acc: 0.7670
# Val Loss: 0.6938, Val Acc: 0.7285
# Epoch 175/1000
# Train Loss: 0.5859, Train Acc: 0.7596
# Val Loss: 0.6940, Val Acc: 0.7161
# Epoch 180/1000
# Train Loss: 0.5552, Train Acc: 0.7775
# Val Loss: 0.6944, Val Acc: 0.7239
# Epoch 185/1000
# Train Loss: 0.5692, Train Acc: 0.7720
# Val Loss: 0.6940, Val Acc: 0.7301
# Epoch 190/1000
# Train Loss: 0.5368, Train Acc: 0.7877
# Val Loss: 0.6922, Val Acc: 0.7332
# Epoch 195/1000
# Train Loss: 0.5439, Train Acc: 0.7828
# Val Loss: 0.6928, Val Acc: 0.7254
# Epoch 200/1000
# Train Loss: 0.5420, Train Acc: 0.7862
# Val Loss: 0.6912, Val Acc: 0.7301
# Epoch 205/1000
# Train Loss: 0.5458, Train Acc: 0.7877
# Val Loss: 0.6923, Val Acc: 0.7317
# Epoch 210/1000
# Train Loss: 0.5213, Train Acc: 0.7970
# Val Loss: 0.6924, Val Acc: 0.7285
# Epoch 215/1000
# Train Loss: 0.5327, Train Acc: 0.7834
# Val Loss: 0.6931, Val Acc: 0.7270
# Epoch 220/1000
# Train Loss: 0.5280, Train Acc: 0.7893
# Val Loss: 0.6909, Val Acc: 0.7285
# Epoch 225/1000
# Train Loss: 0.5185, Train Acc: 0.7970
# Val Loss: 0.6904, Val Acc: 0.7285
# Epoch 230/1000
# Train Loss: 0.5145, Train Acc: 0.7983
# Val Loss: 0.6907, Val Acc: 0.7239
# Epoch 235/1000
# Train Loss: 0.5142, Train Acc: 0.8001
# Val Loss: 0.6932, Val Acc: 0.7223
# Epoch 240/1000
# Train Loss: 0.5103, Train Acc: 0.7989
# Val Loss: 0.6913, Val Acc: 0.7285
# Epoch 245/1000
# Train Loss: 0.5239, Train Acc: 0.7952
# Val Loss: 0.6911, Val Acc: 0.7239
# Epoch 250/1000
# Train Loss: 0.5092, Train Acc: 0.8004
# Val Loss: 0.6918, Val Acc: 0.7207
# Epoch 255/1000
# Train Loss: 0.5086, Train Acc: 0.7893
# Val Loss: 0.6908, Val Acc: 0.7239
# Epoch 260/1000
# Train Loss: 0.5066, Train Acc: 0.7946
# Val Loss: 0.6912, Val Acc: 0.7207
# Epoch 265/1000
# Train Loss: 0.4897, Train Acc: 0.8063
# Val Loss: 0.6919, Val Acc: 0.7254
# Epoch 270/1000
# Train Loss: 0.4909, Train Acc: 0.8128
# Val Loss: 0.6905, Val Acc: 0.7301
# Epoch 275/1000
# Train Loss: 0.4793, Train Acc: 0.8134
# Val Loss: 0.6936, Val Acc: 0.7270
# Epoch 280/1000
# Train Loss: 0.4764, Train Acc: 0.8017
# Val Loss: 0.6907, Val Acc: 0.7254
# Epoch 285/1000
# Train Loss: 0.4553, Train Acc: 0.8190
# Val Loss: 0.6914, Val Acc: 0.7254
# Epoch 290/1000
# Train Loss: 0.4969, Train Acc: 0.8103
# Val Loss: 0.6915, Val Acc: 0.7254
# Epoch 295/1000
# Train Loss: 0.4824, Train Acc: 0.7992
# Val Loss: 0.6960, Val Acc: 0.7207
# Epoch 300/1000
# Train Loss: 0.4570, Train Acc: 0.8323
# Val Loss: 0.6948, Val Acc: 0.7254
# Epoch 305/1000
# Train Loss: 0.4757, Train Acc: 0.8057
# Val Loss: 0.6929, Val Acc: 0.7270
#
# Early stopping triggered at epoch 309
# No improvement in validation accuracy for 100 epochs
#
# Fold 3 Best Results:
# Best Epoch: 208
# Best Validation Accuracy: 0.7348
#
# Fold 4/6
# Epoch 5/1000
# Train Loss: 1.8202, Train Acc: 0.3944
# Val Loss: 1.6476, Val Acc: 0.4641
# Epoch 10/1000
# Train Loss: 1.3801, Train Acc: 0.5429
# Val Loss: 1.2789, Val Acc: 0.5719
# Epoch 15/1000
# Train Loss: 1.1793, Train Acc: 0.5971
# Val Loss: 1.1066, Val Acc: 0.6172
# Epoch 20/1000
# Train Loss: 1.0606, Train Acc: 0.6334
# Val Loss: 1.0083, Val Acc: 0.6266
# Epoch 25/1000
# Train Loss: 0.9874, Train Acc: 0.6481
# Val Loss: 0.9462, Val Acc: 0.6422
# Epoch 30/1000
# Train Loss: 0.9200, Train Acc: 0.6610
# Val Loss: 0.9018, Val Acc: 0.6375
# Epoch 35/1000
# Train Loss: 0.8953, Train Acc: 0.6673
# Val Loss: 0.8700, Val Acc: 0.6484
# Epoch 40/1000
# Train Loss: 0.8517, Train Acc: 0.6745
# Val Loss: 0.8469, Val Acc: 0.6625
# Epoch 45/1000
# Train Loss: 0.8231, Train Acc: 0.6979
# Val Loss: 0.8292, Val Acc: 0.6656
# Epoch 50/1000
# Train Loss: 0.7897, Train Acc: 0.6971
# Val Loss: 0.8159, Val Acc: 0.6781
# Epoch 55/1000
# Train Loss: 0.7811, Train Acc: 0.7073
# Val Loss: 0.8020, Val Acc: 0.6719
# Epoch 60/1000
# Train Loss: 0.7629, Train Acc: 0.7094
# Val Loss: 0.7880, Val Acc: 0.6750
# Epoch 65/1000
# Train Loss: 0.7329, Train Acc: 0.7197
# Val Loss: 0.7821, Val Acc: 0.6766
# Epoch 70/1000
# Train Loss: 0.7209, Train Acc: 0.7222
# Val Loss: 0.7752, Val Acc: 0.6750
# Epoch 75/1000
# Train Loss: 0.7257, Train Acc: 0.7189
# Val Loss: 0.7691, Val Acc: 0.6813
# Epoch 80/1000
# Train Loss: 0.7053, Train Acc: 0.7195
# Val Loss: 0.7623, Val Acc: 0.6875
# Epoch 85/1000
# Train Loss: 0.6929, Train Acc: 0.7228
# Val Loss: 0.7553, Val Acc: 0.6906
# Epoch 90/1000
# Train Loss: 0.6875, Train Acc: 0.7355
# Val Loss: 0.7520, Val Acc: 0.6875
# Epoch 95/1000
# Train Loss: 0.6706, Train Acc: 0.7346
# Val Loss: 0.7512, Val Acc: 0.6969
# Epoch 100/1000
# Train Loss: 0.6497, Train Acc: 0.7382
# Val Loss: 0.7464, Val Acc: 0.6937
# Epoch 105/1000
# Train Loss: 0.6638, Train Acc: 0.7426
# Val Loss: 0.7412, Val Acc: 0.6922
# Epoch 110/1000
# Train Loss: 0.6595, Train Acc: 0.7465
# Val Loss: 0.7395, Val Acc: 0.6922
# Epoch 115/1000
# Train Loss: 0.6493, Train Acc: 0.7495
# Val Loss: 0.7412, Val Acc: 0.6953
# Epoch 120/1000
# Train Loss: 0.6383, Train Acc: 0.7501
# Val Loss: 0.7378, Val Acc: 0.6953
# Epoch 125/1000
# Train Loss: 0.6246, Train Acc: 0.7532
# Val Loss: 0.7338, Val Acc: 0.6984
# Epoch 130/1000
# Train Loss: 0.6209, Train Acc: 0.7601
# Val Loss: 0.7335, Val Acc: 0.7000
# Epoch 135/1000
# Train Loss: 0.6039, Train Acc: 0.7568
# Val Loss: 0.7328, Val Acc: 0.6984
# Epoch 140/1000
# Train Loss: 0.6059, Train Acc: 0.7628
# Val Loss: 0.7308, Val Acc: 0.6984
# Epoch 145/1000
# Train Loss: 0.6015, Train Acc: 0.7693
# Val Loss: 0.7315, Val Acc: 0.7000
# Epoch 150/1000
# Train Loss: 0.5871, Train Acc: 0.7692
# Val Loss: 0.7310, Val Acc: 0.7047
# Epoch 155/1000
# Train Loss: 0.5831, Train Acc: 0.7698
# Val Loss: 0.7295, Val Acc: 0.7063
# Epoch 160/1000
# Train Loss: 0.5813, Train Acc: 0.7735
# Val Loss: 0.7286, Val Acc: 0.6937
# Epoch 165/1000
# Train Loss: 0.5995, Train Acc: 0.7613
# Val Loss: 0.7274, Val Acc: 0.7000
# Epoch 170/1000
# Train Loss: 0.5762, Train Acc: 0.7701
# Val Loss: 0.7260, Val Acc: 0.7047
# Epoch 175/1000
# Train Loss: 0.5702, Train Acc: 0.7735
# Val Loss: 0.7245, Val Acc: 0.7016
# Epoch 180/1000
# Train Loss: 0.5513, Train Acc: 0.7825
# Val Loss: 0.7259, Val Acc: 0.7063
# Epoch 185/1000
# Train Loss: 0.5546, Train Acc: 0.7800
# Val Loss: 0.7244, Val Acc: 0.7031
# Epoch 190/1000
# Train Loss: 0.5548, Train Acc: 0.7819
# Val Loss: 0.7260, Val Acc: 0.7047
# Epoch 195/1000
# Train Loss: 0.5493, Train Acc: 0.7856
# Val Loss: 0.7265, Val Acc: 0.7047
# Epoch 200/1000
# Train Loss: 0.5394, Train Acc: 0.7909
# Val Loss: 0.7257, Val Acc: 0.6953
# Epoch 205/1000
# Train Loss: 0.5494, Train Acc: 0.7737
# Val Loss: 0.7281, Val Acc: 0.7031
# Epoch 210/1000
# Train Loss: 0.5384, Train Acc: 0.7869
# Val Loss: 0.7284, Val Acc: 0.7063
# Epoch 215/1000
# Train Loss: 0.5371, Train Acc: 0.7851
# Val Loss: 0.7264, Val Acc: 0.7047
# Epoch 220/1000
# Train Loss: 0.5397, Train Acc: 0.7807
# Val Loss: 0.7302, Val Acc: 0.7016
# Epoch 225/1000
# Train Loss: 0.5187, Train Acc: 0.7925
# Val Loss: 0.7239, Val Acc: 0.6969
# Epoch 230/1000
# Train Loss: 0.5237, Train Acc: 0.7902
# Val Loss: 0.7251, Val Acc: 0.6969
# Epoch 235/1000
# Train Loss: 0.5108, Train Acc: 0.8033
# Val Loss: 0.7264, Val Acc: 0.7000
# Epoch 240/1000
# Train Loss: 0.5050, Train Acc: 0.8011
# Val Loss: 0.7245, Val Acc: 0.6953
# Epoch 245/1000
# Train Loss: 0.5023, Train Acc: 0.8017
# Val Loss: 0.7270, Val Acc: 0.7016
# Epoch 250/1000
# Train Loss: 0.5114, Train Acc: 0.8026
# Val Loss: 0.7283, Val Acc: 0.6984
# Epoch 255/1000
# Train Loss: 0.4938, Train Acc: 0.8060
# Val Loss: 0.7216, Val Acc: 0.6984
# Epoch 260/1000
# Train Loss: 0.4946, Train Acc: 0.8041
# Val Loss: 0.7244, Val Acc: 0.7016
# Epoch 265/1000
# Train Loss: 0.4893, Train Acc: 0.8086
# Val Loss: 0.7222, Val Acc: 0.7031
# Epoch 270/1000
# Train Loss: 0.4879, Train Acc: 0.8051
# Val Loss: 0.7233, Val Acc: 0.7000
#
# Early stopping triggered at epoch 271
# No improvement in validation accuracy for 100 epochs
#
# Fold 4 Best Results:
# Best Epoch: 170
# Best Validation Accuracy: 0.7078
#
# Fold 5/6
# Epoch 5/1000
# Train Loss: 1.7934, Train Acc: 0.4244
# Val Loss: 1.5987, Val Acc: 0.4969
# Epoch 10/1000
# Train Loss: 1.3546, Train Acc: 0.5534
# Val Loss: 1.2028, Val Acc: 0.6031
# Epoch 15/1000
# Train Loss: 1.1337, Train Acc: 0.6061
# Val Loss: 1.0274, Val Acc: 0.6516
# Epoch 20/1000
# Train Loss: 1.0363, Train Acc: 0.6391
# Val Loss: 0.9368, Val Acc: 0.6672
# Epoch 25/1000
# Train Loss: 0.9511, Train Acc: 0.6524
# Val Loss: 0.8823, Val Acc: 0.6859
# Epoch 30/1000
# Train Loss: 0.9166, Train Acc: 0.6611
# Val Loss: 0.8482, Val Acc: 0.6937
# Epoch 35/1000
# Train Loss: 0.8746, Train Acc: 0.6812
# Val Loss: 0.8214, Val Acc: 0.7016
# Epoch 40/1000
# Train Loss: 0.8372, Train Acc: 0.6820
# Val Loss: 0.8018, Val Acc: 0.7000
# Epoch 45/1000
# Train Loss: 0.8083, Train Acc: 0.6966
# Val Loss: 0.7888, Val Acc: 0.7063
# Epoch 50/1000
# Train Loss: 0.8052, Train Acc: 0.6913
# Val Loss: 0.7771, Val Acc: 0.7078
# Epoch 55/1000
# Train Loss: 0.7692, Train Acc: 0.7079
# Val Loss: 0.7681, Val Acc: 0.7141
# Epoch 60/1000
# Train Loss: 0.7610, Train Acc: 0.7031
# Val Loss: 0.7607, Val Acc: 0.7172
# Epoch 65/1000
# Train Loss: 0.7518, Train Acc: 0.7080
# Val Loss: 0.7563, Val Acc: 0.7156
# Epoch 70/1000
# Train Loss: 0.7312, Train Acc: 0.7172
# Val Loss: 0.7498, Val Acc: 0.7172
# Epoch 75/1000
# Train Loss: 0.7164, Train Acc: 0.7194
# Val Loss: 0.7453, Val Acc: 0.7172
# Epoch 80/1000
# Train Loss: 0.7092, Train Acc: 0.7321
# Val Loss: 0.7411, Val Acc: 0.7203
# Epoch 85/1000
# Train Loss: 0.7043, Train Acc: 0.7257
# Val Loss: 0.7377, Val Acc: 0.7203
# Epoch 90/1000
# Train Loss: 0.6906, Train Acc: 0.7272
# Val Loss: 0.7326, Val Acc: 0.7219
# Epoch 95/1000
# Train Loss: 0.6759, Train Acc: 0.7293
# Val Loss: 0.7310, Val Acc: 0.7234
# Epoch 100/1000
# Train Loss: 0.6794, Train Acc: 0.7322
# Val Loss: 0.7291, Val Acc: 0.7156
# Epoch 105/1000
# Train Loss: 0.6645, Train Acc: 0.7423
# Val Loss: 0.7262, Val Acc: 0.7250
# Epoch 110/1000
# Train Loss: 0.6580, Train Acc: 0.7371
# Val Loss: 0.7251, Val Acc: 0.7250
# Epoch 115/1000
# Train Loss: 0.6531, Train Acc: 0.7454
# Val Loss: 0.7227, Val Acc: 0.7234
# Epoch 120/1000
# Train Loss: 0.6382, Train Acc: 0.7436
# Val Loss: 0.7230, Val Acc: 0.7281
# Epoch 125/1000
# Train Loss: 0.6419, Train Acc: 0.7405
# Val Loss: 0.7186, Val Acc: 0.7281
# Epoch 130/1000
# Train Loss: 0.6198, Train Acc: 0.7568
# Val Loss: 0.7165, Val Acc: 0.7328
# Epoch 135/1000
# Train Loss: 0.6201, Train Acc: 0.7525
# Val Loss: 0.7164, Val Acc: 0.7328
# Epoch 140/1000
# Train Loss: 0.6183, Train Acc: 0.7568
# Val Loss: 0.7144, Val Acc: 0.7234
# Epoch 145/1000
# Train Loss: 0.6139, Train Acc: 0.7593
# Val Loss: 0.7139, Val Acc: 0.7281
# Epoch 150/1000
# Train Loss: 0.6032, Train Acc: 0.7606
# Val Loss: 0.7116, Val Acc: 0.7297
# Epoch 155/1000
# Train Loss: 0.6046, Train Acc: 0.7591
# Val Loss: 0.7110, Val Acc: 0.7266
# Epoch 160/1000
# Train Loss: 0.6011, Train Acc: 0.7634
# Val Loss: 0.7101, Val Acc: 0.7281
# Epoch 165/1000
# Train Loss: 0.5811, Train Acc: 0.7667
# Val Loss: 0.7095, Val Acc: 0.7172
# Epoch 170/1000
# Train Loss: 0.5854, Train Acc: 0.7652
# Val Loss: 0.7082, Val Acc: 0.7234
# Epoch 175/1000
# Train Loss: 0.5787, Train Acc: 0.7695
# Val Loss: 0.7082, Val Acc: 0.7234
# Epoch 180/1000
# Train Loss: 0.5752, Train Acc: 0.7680
# Val Loss: 0.7080, Val Acc: 0.7203
# Epoch 185/1000
# Train Loss: 0.5723, Train Acc: 0.7707
# Val Loss: 0.7050, Val Acc: 0.7297
# Epoch 190/1000
# Train Loss: 0.5642, Train Acc: 0.7810
# Val Loss: 0.7070, Val Acc: 0.7250
# Epoch 195/1000
# Train Loss: 0.5614, Train Acc: 0.7773
# Val Loss: 0.7052, Val Acc: 0.7188
# Epoch 200/1000
# Train Loss: 0.5574, Train Acc: 0.7745
# Val Loss: 0.7043, Val Acc: 0.7219
# Epoch 205/1000
# Train Loss: 0.5716, Train Acc: 0.7699
# Val Loss: 0.7045, Val Acc: 0.7266
# Epoch 210/1000
# Train Loss: 0.5527, Train Acc: 0.7790
# Val Loss: 0.7050, Val Acc: 0.7172
# Epoch 215/1000
# Train Loss: 0.5420, Train Acc: 0.7915
# Val Loss: 0.7038, Val Acc: 0.7234
# Epoch 220/1000
# Train Loss: 0.5381, Train Acc: 0.7862
# Val Loss: 0.7043, Val Acc: 0.7156
# Epoch 225/1000
# Train Loss: 0.5491, Train Acc: 0.7872
# Val Loss: 0.7033, Val Acc: 0.7188
# Epoch 230/1000
# Train Loss: 0.5327, Train Acc: 0.7891
# Val Loss: 0.7032, Val Acc: 0.7188
#
# Early stopping triggered at epoch 234
# No improvement in validation accuracy for 100 epochs
#
# Fold 5 Best Results:
# Best Epoch: 133
# Best Validation Accuracy: 0.7344
#
# Fold 6/6
# Epoch 5/1000
# Train Loss: 1.7679, Train Acc: 0.4546
# Val Loss: 1.6126, Val Acc: 0.5281
# Epoch 10/1000
# Train Loss: 1.3782, Train Acc: 0.5584
# Val Loss: 1.2511, Val Acc: 0.6078
# Epoch 15/1000
# Train Loss: 1.1692, Train Acc: 0.5976
# Val Loss: 1.0822, Val Acc: 0.6297
# Epoch 20/1000
# Train Loss: 1.0477, Train Acc: 0.6340
# Val Loss: 0.9871, Val Acc: 0.6469
# Epoch 25/1000
# Train Loss: 0.9671, Train Acc: 0.6409
# Val Loss: 0.9242, Val Acc: 0.6547
# Epoch 30/1000
# Train Loss: 0.9201, Train Acc: 0.6593
# Val Loss: 0.8825, Val Acc: 0.6672
# Epoch 35/1000
# Train Loss: 0.8796, Train Acc: 0.6684
# Val Loss: 0.8520, Val Acc: 0.6766
# Epoch 40/1000
# Train Loss: 0.8492, Train Acc: 0.6731
# Val Loss: 0.8276, Val Acc: 0.6937
# Epoch 45/1000
# Train Loss: 0.8215, Train Acc: 0.6842
# Val Loss: 0.8089, Val Acc: 0.7000
# Epoch 50/1000
# Train Loss: 0.7932, Train Acc: 0.6910
# Val Loss: 0.7945, Val Acc: 0.7031
# Epoch 55/1000
# Train Loss: 0.7884, Train Acc: 0.6933
# Val Loss: 0.7847, Val Acc: 0.6922
# Epoch 60/1000
# Train Loss: 0.7643, Train Acc: 0.7010
# Val Loss: 0.7762, Val Acc: 0.6984
# Epoch 65/1000
# Train Loss: 0.7433, Train Acc: 0.7116
# Val Loss: 0.7644, Val Acc: 0.7047
# Epoch 70/1000
# Train Loss: 0.7325, Train Acc: 0.7116
# Val Loss: 0.7604, Val Acc: 0.7016
# Epoch 75/1000
# Train Loss: 0.7197, Train Acc: 0.7099
# Val Loss: 0.7525, Val Acc: 0.7063
# Epoch 80/1000
# Train Loss: 0.7003, Train Acc: 0.7120
# Val Loss: 0.7453, Val Acc: 0.7125
# Epoch 85/1000
# Train Loss: 0.6978, Train Acc: 0.7182
# Val Loss: 0.7388, Val Acc: 0.7063
# Epoch 90/1000
# Train Loss: 0.7067, Train Acc: 0.7174
# Val Loss: 0.7343, Val Acc: 0.7063
# Epoch 95/1000
# Train Loss: 0.6797, Train Acc: 0.7293
# Val Loss: 0.7310, Val Acc: 0.7109
# Epoch 100/1000
# Train Loss: 0.6745, Train Acc: 0.7290
# Val Loss: 0.7281, Val Acc: 0.7063
# Epoch 105/1000
# Train Loss: 0.6588, Train Acc: 0.7318
# Val Loss: 0.7241, Val Acc: 0.7094
# Epoch 110/1000
# Train Loss: 0.6546, Train Acc: 0.7420
# Val Loss: 0.7206, Val Acc: 0.7109
# Epoch 115/1000
# Train Loss: 0.6481, Train Acc: 0.7411
# Val Loss: 0.7173, Val Acc: 0.7109
# Epoch 120/1000
# Train Loss: 0.6437, Train Acc: 0.7383
# Val Loss: 0.7130, Val Acc: 0.7156
# Epoch 125/1000
# Train Loss: 0.6331, Train Acc: 0.7486
# Val Loss: 0.7116, Val Acc: 0.7063
# Epoch 130/1000
# Train Loss: 0.6259, Train Acc: 0.7507
# Val Loss: 0.7086, Val Acc: 0.7125
# Epoch 135/1000
# Train Loss: 0.6261, Train Acc: 0.7421
# Val Loss: 0.7074, Val Acc: 0.7141
# Epoch 140/1000
# Train Loss: 0.6145, Train Acc: 0.7506
# Val Loss: 0.7057, Val Acc: 0.7109
# Epoch 145/1000
# Train Loss: 0.6129, Train Acc: 0.7486
# Val Loss: 0.7048, Val Acc: 0.7109
# Epoch 150/1000
# Train Loss: 0.6151, Train Acc: 0.7558
# Val Loss: 0.7025, Val Acc: 0.7141
# Epoch 155/1000
# Train Loss: 0.5980, Train Acc: 0.7575
# Val Loss: 0.7011, Val Acc: 0.7125
# Epoch 160/1000
# Train Loss: 0.5926, Train Acc: 0.7631
# Val Loss: 0.6998, Val Acc: 0.7141
# Epoch 165/1000
# Train Loss: 0.5902, Train Acc: 0.7628
# Val Loss: 0.6982, Val Acc: 0.7188
# Epoch 170/1000
# Train Loss: 0.5916, Train Acc: 0.7636
# Val Loss: 0.6976, Val Acc: 0.7125
# Epoch 175/1000
# Train Loss: 0.5831, Train Acc: 0.7602
# Val Loss: 0.6976, Val Acc: 0.7125
# Epoch 180/1000
# Train Loss: 0.5718, Train Acc: 0.7650
# Val Loss: 0.6958, Val Acc: 0.7125
# Epoch 185/1000
# Train Loss: 0.5719, Train Acc: 0.7717
# Val Loss: 0.6948, Val Acc: 0.7125
# Epoch 190/1000
# Train Loss: 0.5639, Train Acc: 0.7769
# Val Loss: 0.6924, Val Acc: 0.7172
# Epoch 195/1000
# Train Loss: 0.5574, Train Acc: 0.7711
# Val Loss: 0.6905, Val Acc: 0.7141
# Epoch 200/1000
# Train Loss: 0.5521, Train Acc: 0.7810
# Val Loss: 0.6904, Val Acc: 0.7156
# Epoch 205/1000
# Train Loss: 0.5510, Train Acc: 0.7775
# Val Loss: 0.6914, Val Acc: 0.7141
# Epoch 210/1000
# Train Loss: 0.5590, Train Acc: 0.7818
# Val Loss: 0.6917, Val Acc: 0.7156
# Epoch 215/1000
# Train Loss: 0.5380, Train Acc: 0.7838
# Val Loss: 0.6895, Val Acc: 0.7141
# Epoch 220/1000
# Train Loss: 0.5367, Train Acc: 0.7928
# Val Loss: 0.6912, Val Acc: 0.7125
# Epoch 225/1000
# Train Loss: 0.5244, Train Acc: 0.7877
# Val Loss: 0.6894, Val Acc: 0.7063
# Epoch 230/1000
# Train Loss: 0.5407, Train Acc: 0.7874
# Val Loss: 0.6879, Val Acc: 0.7141
# Epoch 235/1000
# Train Loss: 0.5308, Train Acc: 0.7835
# Val Loss: 0.6868, Val Acc: 0.7125
# Epoch 240/1000
# Train Loss: 0.5252, Train Acc: 0.7857
# Val Loss: 0.6888, Val Acc: 0.7109
# Epoch 245/1000
# Train Loss: 0.5287, Train Acc: 0.7893
# Val Loss: 0.6868, Val Acc: 0.7141
# Epoch 250/1000
# Train Loss: 0.5164, Train Acc: 0.7897
# Val Loss: 0.6899, Val Acc: 0.7109
# Epoch 255/1000
# Train Loss: 0.5034, Train Acc: 0.8032
# Val Loss: 0.6920, Val Acc: 0.7125
# Epoch 260/1000
# Train Loss: 0.5027, Train Acc: 0.8012
# Val Loss: 0.6884, Val Acc: 0.7172
# Epoch 265/1000
# Train Loss: 0.5183, Train Acc: 0.7913
# Val Loss: 0.6903, Val Acc: 0.7109
# Epoch 270/1000
# Train Loss: 0.4970, Train Acc: 0.7986
# Val Loss: 0.6891, Val Acc: 0.7109
# Epoch 275/1000
# Train Loss: 0.4953, Train Acc: 0.8007
# Val Loss: 0.6912, Val Acc: 0.7063
# Epoch 280/1000
# Train Loss: 0.4925, Train Acc: 0.7978
# Val Loss: 0.6910, Val Acc: 0.7063
# Epoch 285/1000
# Train Loss: 0.4873, Train Acc: 0.8103
# Val Loss: 0.6909, Val Acc: 0.7078
# Epoch 290/1000
# Train Loss: 0.5225, Train Acc: 0.7949
# Val Loss: 0.6903, Val Acc: 0.7203
# Epoch 295/1000
# Train Loss: 0.4915, Train Acc: 0.8110
# Val Loss: 0.6921, Val Acc: 0.7172
# Epoch 300/1000
# Train Loss: 0.4933, Train Acc: 0.8089
# Val Loss: 0.6920, Val Acc: 0.7125
# Epoch 305/1000
# Train Loss: 0.4787, Train Acc: 0.8018
# Val Loss: 0.6922, Val Acc: 0.7156
# Epoch 310/1000
# Train Loss: 0.4791, Train Acc: 0.8051
# Val Loss: 0.6943, Val Acc: 0.7125
# Epoch 315/1000
# Train Loss: 0.4700, Train Acc: 0.8099
# Val Loss: 0.6929, Val Acc: 0.7203
# Epoch 320/1000
# Train Loss: 0.4738, Train Acc: 0.8074
# Val Loss: 0.6951, Val Acc: 0.7188
# Epoch 325/1000
# Train Loss: 0.4656, Train Acc: 0.8156
# Val Loss: 0.6944, Val Acc: 0.7156
# Epoch 330/1000
# Train Loss: 0.4503, Train Acc: 0.8267
# Val Loss: 0.6947, Val Acc: 0.7141
# Epoch 335/1000
# Train Loss: 0.4508, Train Acc: 0.8196
# Val Loss: 0.6975, Val Acc: 0.7141
#
# Early stopping triggered at epoch 336
# No improvement in validation accuracy for 100 epochs
#
# Fold 6 Best Results:
# Best Epoch: 235
# Best Validation Accuracy: 0.7219
#
# Overall Cross-validation results:
# Mean validation accuracy: 0.7312
# Standard deviation: 0.0134
#
# Best model from fold 1 at epoch 302
# Best validation accuracy: 0.7504

# %%
results = evaluate_test_results(test_df, best_model)
# Out:
# === Model Evaluation on Test Data ===
#
# Overall Test Accuracy: 0.7541
#
# Classification Report:
#                    precision    recall  f1-score   support
#
#            Bengal       0.71      0.90      0.80        50
#            Birman       0.71      0.57      0.63        30
# British Shorthair       0.65      0.67      0.66        30
#         Chartreux       0.62      0.83      0.71         6
#          European       0.67      0.70      0.68        80
#        Maine coon       0.97      1.00      0.99        35
#          No breed       0.70      0.53      0.60        60
#             Other       0.66      0.63      0.64        30
#           Persian       1.00      1.00      1.00        30
#           Ragdoll       0.73      0.82      0.78        40
#          Savannah       1.00      0.20      0.33         5
#           Siamese       0.91      1.00      0.95        10
#            Sphynx       1.00      1.00      1.00        15
#    Turkish angora       1.00      0.67      0.80         6
#
#          accuracy                           0.75       427
#         macro avg       0.81      0.75      0.76       427
#      weighted avg       0.76      0.75      0.75       427
#
#
# Per-Class Metrics:
#
# Bengal:
#   precision: 0.7143
#   recall: 0.9000
#   f1_score: 0.7965
#
# Birman:
#   precision: 0.7083
#   recall: 0.5667
#   f1_score: 0.6296
#
# British Shorthair:
#   precision: 0.6452
#   recall: 0.6667
#   f1_score: 0.6557
#
# Chartreux:
#   precision: 0.6250
#   recall: 0.8333
#   f1_score: 0.7143
#
# European:
#   precision: 0.6667
#   recall: 0.7000
#   f1_score: 0.6829
#
# Maine coon:
#   precision: 0.9722
#   recall: 1.0000
#   f1_score: 0.9859
#
# No breed:
#   precision: 0.6957
#   recall: 0.5333
#   f1_score: 0.6038
#
# Other:
#   precision: 0.6552
#   recall: 0.6333
#   f1_score: 0.6441
#
# Persian:
#   precision: 1.0000
#   recall: 1.0000
#   f1_score: 1.0000
#
# Ragdoll:
#   precision: 0.7333
#   recall: 0.8250
#   f1_score: 0.7765
#
# Savannah:
#   precision: 1.0000
#   recall: 0.2000
#   f1_score: 0.3333
#
# Siamese:
#   precision: 0.9091
#   recall: 1.0000
#   f1_score: 0.9524
#
# Sphynx:
#   precision: 1.0000
#   recall: 1.0000
#   f1_score: 1.0000
#
# Turkish angora:
#   precision: 1.0000
#   recall: 0.6667
#   f1_score: 0.8000
